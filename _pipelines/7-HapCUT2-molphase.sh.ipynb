# %% [markdown]
# # HapCUT2 phasing for samples
#
# **Date:** 2023-Oct-06
# **last update:** 2023-Oct-20

# %% [markdown]
# Molecular phasing is performed individually on all samples with hapCut2, generally following the steps below -
#
# 1. generate two temporary VCF files - one with only heterozygous sites, and the other one with all sites
# 2. HAPCUT2 pipeline, with basically three steps:
#     - Parse the bam file for reads that correspond to the heterozygous sites for HAPCUT2 using the extractHAIRs utility with the 10X flag on to generate a BX-tagged, unlinked fragment file
#     - Link the fragments using HAPCUT2's LinkFragments.py utility.
#     - Run HAPCUT2 proper, with VCF output option
# 3. Perform some basic data extraction from the HAPCUT2 output
# 4. Merge the full VCF file with the HAPCUT2-derived VCF files and annotating the INFO and FORMAT fields accordingly
# 5. Clean-up

# %%
module load htslib/1.18 bcftools/1.18 samtools/1.18
unset $PYTHONPATH
export PYTHONPATH=$PYTHONPATH:~/.local/lib/python3.9/site-packages
export PATH=$PATH:~/_softwares/HapCUT2/build
export PATH=$PATH:~/_softwares/HapCUT2/utilities

module list

# %% [markdown]
# [HapCUT2](https://github.com/vibansal/HapCUT2/tree/master#readme) is for diploid organisms only and can assemble haplotypes for one individual at a time. VCF input should contain variants and genotypes for a single diploid individual.

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase
grep -w 'High' ~/snap_hap/sample_info/samples_Amajus_SnapHap_LastUpdate-2023-10.txt > samples_gt5x.list
grep -w 'Low' ~/snap_hap/sample_info/samples_Amajus_SnapHap_LastUpdate-2023-10.txt > samples_lt5x.list

# %% [markdown]
# ## Molecular phasing 1 sample

# %%
grep -w "10xNEW-Plate10-80_Am_Pla_pb3432_v3.5" ~/snap_hap/variants/molphase/samples_gt5x.list | head -1
# Out:
# PB3432	pb3432	2x-N710-76_Am_Pla_pb3432	10xNEW-Plate10-80_Am_Pla_pb3432_v3.5	10xNEW	10xNEW_PB3432	PB3432_10xNEW	Am	Pla	5.1464	34.7223	35.73	40.9774	183	895	791	High	42.32448359	2.064860881	1216.624	YF1	NA	/nfs/scistore18/bartogrp/apal/snap_hap/bams/v3.5/bams_merged_2023/10xNEW-Plate10-75_Am_Pla_pb3400_v3.5.sorted.BXnum.merged.bam

# %% [markdown]
# ### Initiate variables

# %%
chrom=Chr6
baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}/indv-molphase
sampleList=~/snap_hap/variants/molphase/samples_gt5x.list
bamList=~/snap_hap/sample_info/bam_info/bams_Am_all.txt
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz
threshold=10

# sample=$(tail +2 $sampleList | cut -f4 | sed -n "${SLURM_ARRAY_TASK_ID}p")
sample=10xNEW-Plate10-80_Am_Pla_pb3432_v3.5
bam=$(cat $bamList | grep $sample)

# coverage=$(tail +2 $sampleList | cut -f2 | sed -n "${SLURM_ARRAY_TASK_ID}p")
if [ ! -d $baseDIR/${chrom}_${sample} ]; then mkdir -p $baseDIR/${chrom}_${sample}; fi
sampleDIR=$baseDIR/${chrom}_${sample}

sampleHetVCF=${chrom}_${sample}
sampleHomVCF=${chrom}_${sample}

unLinkedFragments=${chrom}_${sample}
LinkedFragments=${chrom}_${sample}

outPhased=${chrom}_${sample}_thres${threshold}.hapcut2.output

cd $sampleDIR
echo sampleDIR: $sampleDIR
echo chrom: $chrom
echo sample: $sample
# echo coverage: $coverage
echo BAM: $bam
echo VCF: $vcf
echo sample HET VCF: $sampleHetVCF
echo hapcut2 output: $outPhased
# Out:
# sampleDIR: /nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/Chr6/indv-molphase/Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5
# chrom: Chr6
# sample: 10xNEW-Plate10-80_Am_Pla_pb3432_v3.5
# BAM: /nfs/scistore18/bartogrp/apal/snap_hap/bams/v3.5/bams_merged_2023/10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.sorted.BXnum.merged.bam
# VCF: /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr6/Am_all_stitch_Chr6_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz
# sample HET VCF: Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5
# hapcut2 output: Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5_thres10.hapcut2.output

# %% [markdown]
# ### Preprocessing

# %%
# time bcftools view -s $sample -r $chrom $vcf | awk '/^#/;/Chr/ {OFS="\t"}; !/^#/ && $10~/^0\/1/' > ${sampleHetVCF}.het.vcf
time bcftools view -s $sample -r Chr6:1000000-1100000 $vcf | awk '/^#/;/Chr/ {OFS="\t"}; !/^#/ && $10~/^0\/1/' > ${sampleHetVCF}.het.vcf
echo -e 'No of variants in Chr6:1000000-1100000:' $(bcftools view -H ${sampleHetVCF}.het.vcf | wc -l)
# Out:
# real	0m2.929s
# user	0m2.880s
# sys	0m0.053s
# No of variants in Chr6:1000000-1100000: 1008

# %% [markdown]
# ### HapCUT2

# %%
# Extract unlinked fragments
time extractHAIRS --10X 1 --bam $bam --VCF ${sampleHetVCF}.het.vcf --region $chrom --out ${unLinkedFragments}.unlinked.fragments
echo -e "\nNo. of unlinked fragments:" $(wc -l ${unLinkedFragments}.unlinked.fragments)'\n'

# Convert unlinked to linked fragments
time python3 ~/_softwares/HapCUT2/utilities/LinkFragments.py  --bam $bam --VCF ${sampleHetVCF}.het.vcf --fragments ${unLinkedFragments}.unlinked.fragments --out ${LinkedFragments}.linked.fragments -d 50000
echo -e "\nNo. of linked fragments" $(wc -l ${LinkedFragments}.linked.fragments)'\n'

# Phase with HapCUT2
time HAPCUT2 --fragments ${LinkedFragments}.linked.fragments --VCF ${sampleHetVCF}.het.vcf --out ${outPhased} --nf 1 --threshold $threshold --error_analysis_mode 1 --call_homozygous 1 --outvcf 1  --v 0
echo -e "\nNo. of total variants" $(bcftools view -H $outPhased.phased.VCF | wc -l)
echo -e "\nNo. of phased variants" $(bcftools view -H $outPhased.phased.VCF | grep -vc "0/1")
echo -e "\nNo. of unphased variants" $(bcftools view -H $outPhased.phased.VCF | grep -c "0/1")
# Out:
# Extracting haplotype informative reads from bamfiles /nfs/scistore18/bartogrp/apal/snap_hap/bams/v3.5/bams_merged_2023/10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.sorted.BXnum.merged.bam minQV 13 minMQ 20 maxIS 1000
#
# VCF file Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.het.vcf has 1008 variants
# adding chrom Chr6 to index
# vcffile Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.het.vcf chromosomes 1 hetvariants 1008 variants 1008
# detected 0 variants with two non-reference alleles, these variants will not be phased
# reading sorted bamfile /nfs/scistore18/bartogrp/apal/snap_hap/bams/v3.5/bams_merged_2023/10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.sorted.BXnum.merged.bam
# processing reads mapped to chrom "Chr6"
# processed 2000000 reads
# final cleanup of fragment list: 1392 current chrom 0 prev 0
#
# real	0m4.264s
# user	0m4.152s
# sys	0m0.081s
#
# No. of unlinked fragments: 896 Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.unlinked.fragments
#
# Linking 10X fragments on chromosome: Chr6
#   reading bedfile...
#   generating new fragments for HAIRs in boundaries...
#
# real	0m22.847s
# user	0m22.389s
# sys	0m0.400s
#
# No. of linked fragments 371 Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.linked.fragments
#
#
#
# [2023:10:09 19:36:41] input fragment file: Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.linked.fragments
# [2023:10:09 19:36:41] input variantfile (VCF format):Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.het.vcf
# [2023:10:09 19:36:41] haplotypes will be output to file: Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5_thres10.hapcut2.output
# [2023:10:09 19:36:41] solution convergence cutoff: 5
# [2023:10:09 19:36:41] read 1008 variants from Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5.het.vcf file
# [2023:10:09 19:36:41] read fragment file and variant file: fragments 371 variants 1008
# mean number of variants per read is 8.51
# [2023:10:09 19:36:41] building read-variant graph for phasing
# Number of non-trivial connected components 6 max-Degree 33 connected variants 949 coverage-per-variant 3.325606
# [2023:10:09 19:36:41] fragments 371 snps 1008 component(blocks) 6
# [2023:10:09 19:36:41] starting Max-Likelihood-Cut based haplotype assembly algorithm
# [2023:10:09 19:36:41] starting to post-process phased haplotypes to further improve accuracy
# [2023:10:09 19:36:41] starting to output phased haplotypes
# [2023:10:09 19:36:41] OUTPUTTING PRUNED HAPLOTYPE ASSEMBLY TO FILE Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5_thres10.hapcut2.output
# [2023:10:09 19:36:41] N50 haplotype length is 98.03 kilobases
# [2023:10:09 19:36:41] OUTPUTTING PHASED VCF TO FILE Chr6_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5_thres10.hapcut2.output.phased.VCF
#
# real	0m0.233s
# user	0m0.155s
# sys	0m0.024s
#
# No. of total variants 1008
#
# No. of phased variants 949
#
# No. of unphased variants 59

# %%
head -50 $outPhased
# Out:
# BLOCK: offset: 1 len: 2 phased: 2 SPAN: 9 fragments 1
# 1	0	1	Chr6	1000020	G	A	0/1:./.:0.441,0.547,0.012:0.571:1,0,17	0	100.00	29.99	1
# 2	1	0	Chr6	1000029	G	T	0/1:./.:0.127,0.847,0.026:0.899:8,0,15	0	29.99	29.99	1
# ********
# BLOCK: offset: 4 len: 1005 phased: 933 SPAN: 98032 fragments 364
# 4	0	1	Chr6	1000090	T	C	0/1:./.:0.269,0.724,0.006:0.737:4,0,21	0	100.00	36.99	1
# 5	0	1	Chr6	1000092	C	T	0/1:./.:0.253,0.72,0.027:0.775:5,0,14	0	37.00	36.99	1
# 6	0	1	Chr6	1000107	C	T	0/1:./.:0.214,0.775,0.011:0.797:6,0,18	0	74.00	36.99	1
# 7	0	1	Chr6	1000116	C	T	0/1:./.:0.244,0.741,0.015:0.771:5,0,17	0	100.00	36.99	1
# 8	1	0	Chr6	1000176	C	T	0/1:./.:0.184,0.56,0.256:1.072:5,0,3	0	100.00	36.99	1
# 9	0	1	Chr6	1000205	A	G	0/1:./.:0.388,0.501,0.11:0.722:1,0,7	0	100.00	100.00	2
# 10	0	1	Chr6	1000259	G	A	0/1:./.:0.223,0.522,0.254:1.031:4,0,3	0	100.00	100.00	2
# 11	0	1	Chr6	1000262	G	A	0/1:./.:0.458,0.541,0.001:0.543:1,0,27	0	100.00	3.01	2
# 12	1	0	Chr6	1000266	G	A	0/1:./.:0.37,0.625,0.004:0.634:2,0,22	0	37.00	25.00	3
# 13	1	0	Chr6	1000278	T	C	0/1:./.:0.056,0.548,0.396:1.34:10,0,1	0	100.00	100.00	3
# 14	0	1	Chr6	1000310	A	T	0/1:./.:0.437,0.558,0.005:0.568:1,0,20	0	100.00	36.99	3
# 15	0	1	Chr6	1000311	G	T	0/1:./.:0.434,0.564,0.002:0.569:1,0,25	0	100.00	36.99	3
# 16	1	0	Chr6	1000367	C	T	0/1:./.:0.206,0.778,0.017:0.811:6,0,17	0	100.00	100.00	3
# 17	1	0	Chr6	1000381	C	T	0/1:./.:0.21,0.774,0.016:0.806:6,0,17	0	100.00	100.00	3
# 18	1	0	Chr6	1000424	A	G	0/1:./.:0.2,0.74,0.06:0.86:6,0,11	0	100.00	100.00	2
# 26	0	1	Chr6	1000579	G	A	0/1:./.:0.358,0.624,0.018:0.66:2,0,15	0	100.00	36.95	1
# 27	0	1	Chr6	1000596	A	G	0/1:./.:0.102,0.819,0.079:0.976:9,0,10	0	100.00	100.00	2
# 28	0	1	Chr6	1000600	C	T	0/1:./.:0.446,0.545,0.009:0.564:1,0,18	0	100.00	100.00	2
# 29	0	1	Chr6	1000681	A	G	0/1:./.:0.242,0.728,0.03:0.788:5,0,14	0	100.00	100.00	2
# 30	0	1	Chr6	1000704	T	G	0/1:./.:0.124,0.839,0.037:0.913:8,0,14	0	100.00	37.00	1
# 31	0	1	Chr6	1000735	T	C	0/1:./.:0.428,0.559,0.014:0.586:1,0,16	0	100.00	37.00	1
# 32	0	1	Chr6	1000738	T	C	0/1:./.:0.244,0.723,0.033:0.788:5,0,13	0	100.00	37.00	1
# 33	0	1	Chr6	1000777	A	G	0/1:./.:0.438,0.549,0.013:0.575:1,0,16	0	100.00	33.99	1
# 34	0	1	Chr6	1000821	A	G	0/1:./.:0.07,0.774,0.156:1.085:10,0,7	0	100.00	100.00	4
# 35	0	1	Chr6	1000936	A	T	0/1:./.:0.422,0.538,0.04:0.618:1,0,11	0	100.00	100.00	4
# 36	1	0	Chr6	1000981	A	G	0/1:./.:0.393,0.546,0.061:0.668:1,0,10	0	100.00	100.00	2
# 37	1	0	Chr6	1001255	A	T	0/1:./.:0.333,0.658,0.01:0.677:3,0,18	0	100.00	59.59	2
# 38	1	0	Chr6	1001260	G	A	0/1:./.:0.049,0.841,0.11:1.061:12,0,9	0	100.00	100.00	2
# 39	1	0	Chr6	1001331	T	A	0/1:./.:0.181,0.781,0.038:0.856:6,0,13	0	100.00	100.00	6
# 40	1	0	Chr6	1001354	A	C	0/1:./.:0.174,0.776,0.05:0.877:6,0,12	0	100.00	100.00	5
# 41	1	0	Chr6	1001488	G	A	0/1:./.:0.143,0.838,0.018:0.875:8,0,17	0	100.00	100.00	5
# 42	1	0	Chr6	1001491	T	C	0/1:./.:0.035,0.881,0.084:1.05:14,0,10	0	100.00	100.00	5
# 43	1	0	Chr6	1001496	T	C	0/1:./.:0.125,0.856,0.019:0.894:8,0,17	0	100.00	100.00	5
# 44	1	0	Chr6	1001531	T	C	0/1:./.:0.068,0.85,0.082:1.013:11,0,10	0	100.00	100.00	4
# 45	1	0	Chr6	1001532	G	A	0/1:./.:0.114,0.841,0.045:0.932:9,0,13	0	100.00	100.00	4
# 46	1	0	Chr6	1001543	T	C	0/1:./.:0.208,0.751,0.041:0.833:6,0,13	0	100.00	100.00	4
# 47	1	0	Chr6	1001580	G	T	0/1:./.:0.321,0.66,0.019:0.698:3,0,15	0	100.00	38.00	3
# 48	1	0	Chr6	1001644	G	A	0/1:./.:0.197,0.718,0.085:0.888:6,0,9	0	100.00	100.00	3
# 49	1	0	Chr6	1001657	A	G	0/1:./.:0.317,0.657,0.026:0.709:3,0,14	0	100.00	100.00	3
# 50	1	0	Chr6	1001661	A	G	0/1:./.:0.167,0.726,0.107:0.94:6,0,8	0	100.00	100.00	4
# 51	1	0	Chr6	1001673	A	G	0/1:./.:0.208,0.725,0.067:0.858:5,0,10	0	100.00	100.00	3
# 54	1	0	Chr6	1001877	C	T	0/1:./.:0.329,0.661,0.01:0.681:3,0,18	0	100.00	62.09	2
# 55	1	0	Chr6	1001945	A	G	0/1:./.:0.191,0.774,0.035:0.845:6,0,13	0	100.00	100.00	3
# 56	1	0	Chr6	1001977	A	G	0/1:./.:0.41,0.58,0.01:0.601:2,0,18	0	100.00	100.00	3
# 57	1	0	Chr6	1002013	G	A	0/1:./.:0.347,0.633,0.02:0.673:3,0,15	0	100.00	37.00	1

# %%
bcftools view -h $outPhased.phased.VCF | cut -f1-2,4-5,8-10 |  tail -1
bcftools view -H $outPhased.phased.VCF | head -15 | cut -f1-2,4-5,8-10
# Out:
# #CHROM	POS	REF	ALT	INFO	FORMAT	10xNEW-Plate10-80_Am_Pla_pb3432_v3.5
# [main_vcfview] Error: cannot write to (null)
# Chr6	1000020	G	A	EAF=0.45818;INFO_SCORE=0.49317;HWE=5.37e-23;ERC=985.466;EAC=1082.5;PAF=0.47654;AC=1;AN=2	GT:PQ:PD:PS	1|0:30:1:1000020
# Chr6	1000029	G	T	EAF=0.04558;INFO_SCORE=0.3758;HWE=1;ERC=83.7223;EAC=1920.45;PAF=0.04177;AC=1;AN=2	GT:PQ:PD:PS	0|1:30:1:1000020
# Chr6	1000077	C	T	EAF=0.04814;INFO_SCORE=0.28625;HWE=1;ERC=39.2469;EAC=1506.91;PAF=0.02538;AC=1;AN=2	GT:PG:GP:DS:PL:PS	0/1:./.:0.238,0.754,0.008:0.77:5,0,20:.
# Chr6	1000090	T	C	EAF=0.04413;INFO_SCORE=0.28503;HWE=1;ERC=40.2703;EAC=1515.87;PAF=0.02588;AC=1;AN=2	GT:PQ:PD:PS	1|0:37:1:1000090
# Chr6	1000092	C	T	EAF=0.13937;INFO_SCORE=0.28352;HWE=0.00298;ERC=123.963;EAC=1396.21;PAF=0.08155;AC=1;AN=2	GT:PQ:PD:PS	1|0:37:1:1000090
# Chr6	1000107	C	T	EAF=0.0991;INFO_SCORE=0.35638;HWE=0.0827;ERC=85.0538;EAC=1438.16;PAF=0.05584;AC=1;AN=2	GT:PQ:PD:PS	1|0:37:1:1000090
# Chr6	1000116	C	T	EAF=0.14335;INFO_SCORE=0.37598;HWE=0.00171;ERC=114.943;EAC=1447.27;PAF=0.07358;AC=1;AN=2	GT:PQ:PD:PS	1|0:37:1:1000090
# Chr6	1000176	C	T	EAF=0.52038;INFO_SCORE=0.52496;HWE=9.13e-17;ERC=956.504;EAC=789.512;PAF=0.54782;AC=1;AN=2	GT:PQ:PD:PS	0|1:37:1:1000090
# Chr6	1000205	A	G	EAF=0.27489;INFO_SCORE=0.44698;HWE=1.66e-20;ERC=297.552;EAC=1409.56;PAF=0.1743;AC=1;AN=2	GT:PQ:PD:PS	1|0:100:2:1000090
# Chr6	1000259	G	A	EAF=0.25139;INFO_SCORE=0.49889;HWE=1.51e-12;ERC=288.92;EAC=1715.29;PAF=0.14416;AC=1;AN=2	GT:PQ:PD:PS	1|0:100:2:1000090
# Chr6	1000262	G	A	EAF=0.02455;INFO_SCORE=0.27058;HWE=1;ERC=23.3414;EAC=1999.86;PAF=0.01154;AC=1;AN=2	GT:PQ:PD:PS	1|0:3:2:1000090
# Chr6	1000266	G	A	EAF=0.07373;INFO_SCORE=0.54908;HWE=0.0281;ERC=153.16;EAC=1926.83;PAF=0.07363;AC=1;AN=2	GT:PQ:PD:PS	0|1:25:3:1000090
# Chr6	1000278	T	C	EAF=0.72945;INFO_SCORE=0.63124;HWE=4.95e-07;ERC=1519.05;EAC=681.042;PAF=0.69045;AC=1;AN=2	GT:PQ:PD:PS	0|1:100:3:1000090
# Chr6	1000310	A	T	EAF=0.05084;INFO_SCORE=0.62293;HWE=0.718;ERC=113.507;EAC=2232.35;PAF=0.04839;AC=1;AN=2	GT:PQ:PD:PS	1|0:37:3:1000090
# Chr6	1000311	G	T	EAF=0.05046;INFO_SCORE=0.62073;HWE=0.718;ERC=112.451;EAC=2256.52;PAF=0.04747;AC=1;AN=2	GT:PQ:PD:PS	1|0:37:3:1000090

# %%
python3 ~/_softwares/HapCUT2/utilities/calculate_haplotype_statistics.py -v1 $outPhased.phased.VCF
# Out:
# ERROR: Missing required arguments.
# --vcf1 and --vcf2 options are required
# : 1

# %% [markdown]
# ## Cluster implementation

# %% [markdown]
# ### Chr6

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/molphase_allSamples
chrom=Chr6
stitchRun=stitchRun1
baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}/indv-molphase
bamList=~/snap_hap/sample_info/bam_info/bams_Am_all.txt
# vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_${stitchRun}_${chrom}.final.vcf.gz
threshold=10
headerFile=~/snap_hap/variants/molphase/molphase.header

# %%
cat $headerFile
# Out:
# ##INFO=<ID=HAPCUT,Number=1,Type=String,Description="HapCUT2 Phase">
# ##FORMAT=<ID=GX,Number=1,Type=String,Description="HapCUT2 Phased Genotype">
# ##FORMAT=<ID=PS,Number=1,Type=Integer,Description="ID of Phase Set for Variant">
# ##FORMAT=<ID=PQ,Number=1,Type=Integer,Description="Phred QV indicating probability that this variant is incorrectly phased relative to the haplotype">
# ##FORMAT=<ID=PD,Number=1,Type=Integer,Description="phased Read Depth">

# %% [markdown]
# #### Individual Molphase:  >5x coverage

# %%
sampleList=~/snap_hap/variants/molphase/samples_gt5x.list
sbatch --array=1-180 -J molphase_Chr6_gt5x ~/snap_hap/_scripts/sbatch/phase/job-molphase_allSamples.sbatch $chrom $baseDIR $sampleList $bamList $vcf $threshold
# ##Postprocessing 
# ##NB: Ideally, both molphase and postprocesing would be run altogether.
# sbatch --array=1-180 -J postPhase_Chr6_gt5x ~/snap_hap/_scripts/sbatch/phase/job-molphase_allSamples.sbatch.sh $chrom $baseDIR $sampleList $bamList $vcf $threshold

# %% [markdown]
# ```
# #SBATCH --partition=defaultp
# #SBATCH --time=48:00:00
# #SBATCH --ntasks=1
# #SBATCH --ntasks-per-node=1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem-per-cpu=16G
# ```

# %% [markdown]
# #### Individual Molphase:  <5x coverage

# %%
sampleList=~/snap_hap/variants/molphase/samples_lt5x.list
sbatch --array=1-894 -J molphase_Chr6_lt5x ~/snap_hap/_scripts/sbatch/phase/job-molphase_allSamples.sbatch $chrom $baseDIR $sampleList $bamList $vcf $threshold
# ##Postprocessing 
# ##NB: Ideally, both molphase and postprocesing would be run altogether.
# sbatch --array=1-894 -J postPhase_Chr6_lt5x ~/snap_hap/_scripts/sbatch/phase/job-molphase_allSamples.sbatch.sh $chrom $baseDIR $sampleList $bamList $vcf $threshold

# %% [markdown]
# ```
# #SBATCH --partition=defaultp
# #SBATCH --time=03:00:00
# #SBATCH --ntasks=1
# #SBATCH --ntasks-per-node=1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem-per-cpu=8G
# ```

# %% [markdown]
# ### For all chromosomes

# %%
for chrom in Chr{1..8}
do
    echo $chrom
    if [ ! -d ~/snap_hap/variants/jobs/molphase_allSamples/${chrom} ]; then mkdir -p ~/snap_hap/variants/jobs/molphase_allSamples/$chrom; fi

    stitchRun=stitchRun1
    baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}/indv-molphase
    bamList=~/snap_hap/sample_info/bam_info/bams_Am_all.txt
    vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_${stitchRun}_${chrom}.final.vcf.gz
    threshold=10
    headerFile=~/snap_hap/variants/molphase/molphase.header

    cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/molphase_allSamples/$chrom
    
    sampleList_highCov=~/snap_hap/variants/molphase/samples_gt5x.list
    sbatch --array=1-180 -J ${chrom}_gt5x ~/snap_hap/_scripts/sbatch/phase/job-molphase_allSamples.sbatch.sh $chrom $baseDIR \
            $sampleList_highCov $bamList $vcf $threshold

    sampleList_lowCov=~/snap_hap/variants/molphase/samples_lt5x.list
    sbatch --array=1-894 -J ${chrom}_lt5x ~/snap_hap/_scripts/sbatch/phase/job-molphase_allSamples.sbatch.sh $chrom $baseDIR \
            $sampleList_lowCov $bamList $vcf $threshold
done

# %% [markdown]
# -----

# %% [markdown]
# #### Merge all individual molphase VCFs

# %%
## Merge VCFs
echo -e '\nMerging sample VCFs'
srun time bcftools merge --threads ${SLURM_CPUS_PER_TASK} -Oz -o $outVCF -l $sampleVcfList 
tabix -f $outVCF
## Create GT file
srun time bcftools query -f '%CHROM\t%POS[\t%GT]\n' $vcf > Am_all_molphased_Chr6.gt

# %%
## Merge all combined sample VCF (cluster implementation)
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/molphase_allSamples/mergeVcfs_Chr6
chrom=Chr6
baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}
realpath ${baseDIR}/indv-molphase/*/*combined.vcf.gz > ${baseDIR}/molphaseVcfs.list
sampleVcfList=${baseDIR}/molphaseVcfs.list

sbatch -J postPhase-mergeVcfs_${chrom} ~/snap_hap/_scripts/sbatch/phase/job-molphase_mergeVcfs.sbatch $chrom $baseDIR $sampleVcfList

# %%
### For all chromosomes (cluster implementation)
for chrom in Chr{1..8}
do
    echo $chrom
    
    if [ ! -d ~/snap_hap/variants/jobs/molphase_allSamples/${chrom}_mergeVCFs ]; 
    then 
        mkdir -p ~/snap_hap/variants/jobs/molphase_allSamples/${chrom}_mergeVCFs; 
    fi

    cd ~/snap_hap/variants/jobs/molphase_allSamples/${chrom}_mergeVCFs
    
    stitchRun=stitchRun1
    baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}
    realpath ${baseDIR}/indv-molphase/*/*combined.vcf.gz > ${baseDIR}/molphaseVcfs.list
    sampleVcfList=${baseDIR}/molphaseVcfs.list
    
    sbatch -J ${chrom}_merge ~/snap_hap/_scripts/sbatch/phase/job-molphase_mergeVcfs.sbatch.sh \
        $chrom $baseDIR $sampleVcfList
done

# %% [markdown]
# Merging takes around ~3-4 hrs.

# %% [markdown]
# ----

# %%
vcf=~/snap_hap/variants/molphase/Chr6/Am_all_stitchRun1_Chr6.molphased.vcf.gz
TotalSites=$(bcftools view -H $vcf | wc -l)
echo -e "Total no. of variant sites in Chr6:" $TotalSites

# %%
### For all chromosomes
echo -e "Total no. of variant sites\n"
for chrom in Chr{1..8}
do
    vcf=~/snap_hap/variants/molphase/${chrom}/Am_all_stitchRun1_${chrom}.molphased.vcf.gz
    # TotalSites=$(bcftools view -H $vcf | wc -l)
    TotalSites=$(zgrep -c ^Chr $vcf)  
    echo -e $chrom':' $TotalSites
done

# %% [raw]
# Total no. of variant sites
#
# Chr1: 2940701
# Chr2: 3301920
# Chr3: 2600018
# Chr4: 2317799
# Chr5: 3277515
# Chr6: 2533823
# Chr7: 2358818
# Chr8: 2765149

# %% [markdown]
# #### Get summary

# %%
## Chr6
cd ~/snap_hap/variants/molphase/Chr6
paste <(head -1 ~/snap_hap/sample_info/samples_Amajus_SnapHap_LastUpdate-2023-10.txt) <(echo -e "sampleFolder\tunLinkedFragments\tLinkedFragments\tTotalHetSites\tPhasedSites\tunPhasedSites") > phaseVal_Chr6.txt

for sampleFolder in /nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/Chr6/indv-molphase/*;
do 
    
    sample=`basename $sampleFolder | cut -f3- -d_`
    grep -w $sample ~/snap_hap/sample_info/samples_Amajus_SnapHap_LastUpdate-2023-10.txt > tmpSample.txt
    
    unLinkedFragments=`cat $sampleFolder/*.unlinked.fragments | wc -l`
    LinkedFragments=`cat $sampleFolder/*.linked.fragments | wc -l`

    TotalHetSites=$(bcftools view -H $sampleFolder/*.het.vcf | wc -l)
    PhasedSites=$(bcftools view -H $sampleFolder/*.phased.VCF | grep -vc "0/1")
    unPhasedSites=$(bcftools view -H $sampleFolder/**.phased.VCF | grep -c "0/1")

    paste tmpSample.txt <(echo -e "$(basename $sampleFolder)\t$unLinkedFragments\t$LinkedFragments\t$TotalHetSites\t$PhasedSites\t$unPhasedSites") >> phaseVal_Chr6.txt
    echo `basename $sampleFolder` -> Done
    rm tmpSample.txt
done

# %%
### For all chromosomes

for chrom in Chr{1..8}
do
    echo $chrom
    baseDIR=~/snap_hap/variants/molphase/${chrom}
    cd $baseDIR

    paste <(head -1 ~/snap_hap/sample_info/samples_Amajus_SnapHap_LastUpdate-2023-10.txt) \
        <(echo -e "sampleFolder\tunLinkedFragments\tLinkedFragments\tTotalHetSites\tPhasedSites\tunPhasedSites") \
        > ./phaseVal_${chrom}.txt

    for sampleFolder in $baseDIR/indv-molphase/*;
    do
        sample=`basename $sampleFolder | cut -f3- -d_`
        grep -w $sample ~/snap_hap/sample_info/samples_Amajus_SnapHap_LastUpdate-2023-10.txt > tmpSample.txt

        unLinkedFragments=`cat $sampleFolder/*.unlinked.fragments | wc -l`
        LinkedFragments=`cat $sampleFolder/*.linked.fragments | wc -l`

        TotalHetSites=$(grep -c ^Chr $sampleFolder/*.het.vcf)
        PhasedSites=$(grep ^Chr  $sampleFolder/*.phased.VCF | grep -vc "0/1")
        unPhasedSites=$(grep ^Chr  $sampleFolder/*.phased.VCF | grep -c "0/1")

        paste tmpSample.txt <(echo -e "$(basename $sampleFolder)\t$unLinkedFragments\t$LinkedFragments\t$TotalHetSites\t$PhasedSites\t$unPhasedSites") >> phaseVal_${chrom}.txt
        echo -e `basename $sampleFolder` "-> Done"
        
        rm tmpSample.txt
    done
done
# Out:
# Chr1
# Chr1_covHigh_10x-10_Am_Pla_pb3403_v3.5 -> Done
# Chr1_covHigh_10x-11_Am_Pla_pb4318_v3.5 -> Done
# Chr1_covHigh_10x-12_Am_Pla_pb4563_v3.5 -> Done
# Chr1_covHigh_10x-1_Am_Pla_pb0174_v3.5 -> Done
# Chr1_covHigh_10x2-13_Am_Pla_pb1196_v3.5 -> Done
# Chr1_covHigh_10x2-14_Am_Pla_pb1008_v3.5 -> Done
# Chr1_covHigh_10x2-15_Am_Pla_pb1253_v3.5 -> Done
# Chr1_covHigh_10x2-16_Am_Pla_pb1682_v3.5 -> Done
# Chr1_covHigh_10x2-17_Am_Pla_pb2190_v3.5 -> Done
# Chr1_covHigh_10x2-18_Am_Pla_pb1687_v3.5 -> Done
# Chr1_covHigh_10x-2_Am_Pla_pb0216_v3.5 -> Done
# Chr1_covHigh_10x-3_Am_Pla_pb0294_v3.5 -> Done
# Chr1_covHigh_10x-4_Am_Pla_pb0349_v3.5 -> Done
# Chr1_covHigh_10x-5_Am_Pla_pb0403_v3.5 -> Done
# Chr1_covHigh_10x-6_Am_Pla_pb0458_v3.5 -> Done
# Chr1_covHigh_10x-7_Am_Pla_pb0407_v3.5 -> Done
# Chr1_covHigh_10x-8_Am_Pla_pb0768_v3.5 -> Done
# Chr1_covHigh_10x-9_Am_Pla_pb2333_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-10_Am_Pla_pb0952_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-11_Am_Pla_pb0960_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-12_Am_Pla_pb1085_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-13_Am_Pla_pb1088_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-14_Am_Pla_pb1092_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-15_Am_Pla_pb1093_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-16_Am_Pla_pb1164_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-17_Am_Pla_pb1166_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-18_Am_Pla_pb1172_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-19_Am_Pla_pb1179_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-1_Am_Pla_pa1499_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-20_Am_Pla_pb1654_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-21_Am_Pla_pb1656_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-22_Am_Pla_pb1658_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-23_Am_Pla_pb1662_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-24_Am_Pla_pb1664_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-25_Am_Pla_pb1665_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-26_Am_Pla_pb1672_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-27_Am_Pla_pb1677_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-28_Am_Pla_pb1681_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-2_Am_Pla_pb0875_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-30_Am_Pla_pb1684_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-31_Am_Pla_pb1686_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-33_Am_Pla_pb1691_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-34_Am_Pla_pb1692_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-35_Am_Pla_pb1693_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-36_Am_Pla_pb1694_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-37_Am_Pla_pb1695_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-39_Am_Pla_pb1699_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-3_Am_Pla_pb0876_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-40_Am_Pla_pb1700_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-41_Am_Pla_pb1915_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-42_Am_Pla_pb2182_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-44_Am_Pla_pb2191_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-45_Am_Pla_pb2194_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-46_Am_Pla_pb2197_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-47_Am_Pla_pb2198_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-48_Am_Pla_pb2295_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-49_Am_Pla_pb2303_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-4_Am_Pla_pb0883_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-50_Am_Pla_pb2307_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-51_Am_Pla_pb2311_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-52_Am_Pla_pb2312_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-53_Am_Pla_pb2313_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-54_Am_Pla_pb2316_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-55_Am_Pla_pb2318_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-56_Am_Pla_pb2319_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-57_Am_Pla_pb2320_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-58_Am_Pla_pb2342_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-59_Am_Pla_pb2352_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-5_Am_Pla_pb0888_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-60_Am_Pla_pb2360_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-61_Am_Pla_pb2410_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-62_Am_Pla_pb2414_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-63_Am_Pla_pb2417_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-64_Am_Pla_pb3320_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-65_Am_Pla_pb3363_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-66_Am_Pla_pb3368_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-67_Am_Pla_pb3370_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-68_Am_Pla_pb3373_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-69_Am_Pla_pb3378_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-6_Am_Pla_pb0893_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-70_Am_Pla_pb3382_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-71_Am_Pla_pb3386_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-72_Am_Pla_pb3388_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-73_Am_Pla_pb3391_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-74_Am_Pla_pb3393_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-75_Am_Pla_pb3400_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-76_Am_Pla_pb3424_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-77_Am_Pla_pb3425_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-78_Am_Pla_pb3426_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-79_Am_Pla_pb3430_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-80_Am_Pla_pb3432_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-81_Am_Pla_pb3434_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-82_Am_Pla_pb3489_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-83_Am_Pla_pb3490_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-84_Am_Pla_pb3497_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-85_Am_Pla_pb3675_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-86_Am_Pla_pb3677_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-87_Am_Pla_pb3845_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-88_Am_Pla_pb3850_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-89_Am_Pla_pb4144_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-8_Am_Pla_pb0900_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-90_Am_Pla_pb4169_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-91_Am_Pla_pb4170_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-92_Am_Pla_pb4180_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-93_Am_Pla_pb4214_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-94_Am_Pla_pb4593_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-95_Am_Pla_z1970_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-96_Am_Pla_z3987_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate10-9_Am_Pla_pb0912_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-10_Am_Pla_pb0873_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-11_Am_Pla_pb0881_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-12_Am_Pla_pb0894_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-13_Am_Pla_pb1000_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-15_Am_Pla_pb1009_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-16_Am_Pla_pb1014_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-18_Am_Pla_pb1046_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-19_Am_Pla_pb1047_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-1_Am_Pla_pb0810_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-20_Am_Pla_pb1048_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-21_Am_Pla_pb1053_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-22_Am_Pla_pb1060_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-23_Am_Pla_pb1188_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-24_Am_Pla_pb1191_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-25_Am_Pla_pb1192_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-29_Am_Pla_pb1469_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-2_Am_Pla_pb0836_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-30_Am_Pla_pb1470_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-31_Am_Pla_pb1512_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-32_Am_Pla_pb1522_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-33_Am_Pla_pb1561_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-34_Am_Pla_pb1569_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-35_Am_Pla_pb1591_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-36_Am_Pla_pb1602_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-37_Am_Pla_pb1606_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-38_Am_Pla_pb1705_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-39_Am_Pla_pb1706_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-3_Am_Pla_pb0854_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-40_Am_Pla_pb1720_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-41_Am_Pla_pb1843_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-42_Am_Pla_pb1844_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-43_Am_Pla_pb1846_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-44_Am_Pla_pb1847_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-45_Am_Pla_pb1848_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-46_Am_Pla_pb1850_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-47_Am_Pla_pb1857_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-48_Am_Pla_pb1860_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-49_Am_Pla_pb1914_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-4_Am_Pla_pb0860_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-50_Am_Pla_pb2943_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-51_Am_Pla_pb2944_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-52_Am_Pla_pb2945_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-53_Am_Pla_pb2946_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-54_Am_Pla_pb2948_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-55_Am_Pla_pb3303_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-56_Am_Pla_pb3304_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-57_Am_Pla_pb3306_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-58_Am_Pla_pb3308_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-59_Am_Pla_pb3311_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-5_Am_Pla_pb0861_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-60_Am_Pla_pb3312_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-61_Am_Pla_pb3313_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-62_Am_Pla_pb3316_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-63_Am_Pla_pb3317_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-6_Am_Pla_pb0866_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-7_Am_Pla_pb0868_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-8_Am_Pla_pb0869_v3.5 -> Done
# Chr1_covHigh_10xNEW-Plate9-9_Am_Pla_pb0871_v3.5 -> Done
# Chr1_covHigh_60x-1_Am_Pla_pb0464_v3.5 -> Done
# Chr1_covHigh_60x2-Plate10-7_Am_Pla_pb0898_v3.5 -> Done
# Chr1_covHigh_60x2-Plate9-17_Am_Pla_pb1042_v3.5 -> Done
# Chr1_covHigh_TRIO-10_Am_GH_D10_v3.5 -> Done
# Chr1_covHigh_TRIO-11_Am_GH_D7_v3.5 -> Done
# Chr1_covHigh_TRIO-12_Am_GH_D8_v3.5 -> Done
# Chr1_covHigh_TRIO-12_Am_Pla_T0082_v3.5 -> Done
# Chr1_covHigh_TRIO-13_Am_GH_D9_v3.5 -> Done
# Chr1_covHigh_TRIO-13_Am_Pla_T0281_v3.5 -> Done
# Chr1_covHigh_TRIO-14_Am_Pla_T1352_v3.5 -> Done
# Chr1_covHigh_TRIO-4_Am_GH_D01_v3.5 -> Done
# Chr1_covHigh_TRIO-5_Am_GH_D02_v3.5 -> Done
# Chr1_covHigh_TRIO-6_Am_GH_D03_v3.5 -> Done
# Chr1_covLow_10xNEW-Plate10-38_Am_Pla_pb1697_v3.5 -> Done
# Chr1_covLow_10xNEW-Plate9-26_Am_Pla_pb1195_v3.5 -> Done
# Chr1_covLow_10xNEW-Plate9-64_Am_Pla_pb3318_v3.5 -> Done
# Chr1_covLow_2x-N701-10_Am_Pla_pb0108_v3.5 -> Done
# Chr1_covLow_2x-N701-11_Am_Pla_pb0109_v3.5 -> Done
# Chr1_covLow_2x-N701-12_Am_Pla_pb0110_v3.5 -> Done
# Chr1_covLow_2x-N701-13_Am_Pla_pb0111_v3.5 -> Done
# Chr1_covLow_2x-N701-14_Am_Pla_pb0112_v3.5 -> Done
# Chr1_covLow_2x-N701-15_Am_Pla_pb0113_v3.5 -> Done
# Chr1_covLow_2x-N701-16_Am_Pla_pb0114_v3.5 -> Done
# Chr1_covLow_2x-N701-17_Am_Pla_pb0115_v3.5 -> Done
# Chr1_covLow_2x-N701-18_Am_Pla_pb0116_v3.5 -> Done
# Chr1_covLow_2x-N701-19_Am_Pla_pb0117_v3.5 -> Done
# Chr1_covLow_2x-N701-1_Am_Pla_pb0099_v3.5 -> Done
# Chr1_covLow_2x-N701-20_Am_Pla_pb0118_v3.5 -> Done
# Chr1_covLow_2x-N701-21_Am_Pla_pb0119_v3.5 -> Done
# Chr1_covLow_2x-N701-22_Am_Pla_pb0120_v3.5 -> Done
# Chr1_covLow_2x-N701-23_Am_Pla_pb0121_v3.5 -> Done
# Chr1_covLow_2x-N701-24_Am_Pla_pb0122_v3.5 -> Done
# Chr1_covLow_2x-N701-25_Am_Pla_pb0123_v3.5 -> Done
# Chr1_covLow_2x-N701-26_Am_Pla_pb0124_v3.5 -> Done
# Chr1_covLow_2x-N701-27_Am_Pla_pb0125_v3.5 -> Done
# Chr1_covLow_2x-N701-28_Am_Pla_pb0126_v3.5 -> Done
# Chr1_covLow_2x-N701-29_Am_Pla_pb0127_v3.5 -> Done
# Chr1_covLow_2x-N701-2_Am_Pla_pb0100_v3.5 -> Done
# Chr1_covLow_2x-N701-30_Am_Pla_pb0128_v3.5 -> Done
# Chr1_covLow_2x-N701-31_Am_Pla_pb0129_v3.5 -> Done
# Chr1_covLow_2x-N701-32_Am_Pla_pb0130_v3.5 -> Done
# Chr1_covLow_2x-N701-33_Am_Pla_pb0131_v3.5 -> Done
# Chr1_covLow_2x-N701-34_Am_Pla_pb0132_v3.5 -> Done
# Chr1_covLow_2x-N701-35_Am_Pla_pb0133_v3.5 -> Done
# Chr1_covLow_2x-N701-36_Am_Pla_pb0134_v3.5 -> Done
# Chr1_covLow_2x-N701-37_Am_Pla_pb0135_v3.5 -> Done
# Chr1_covLow_2x-N701-38_Am_Pla_pb0136_v3.5 -> Done
# Chr1_covLow_2x-N701-39_Am_Pla_pb0137_v3.5 -> Done
# Chr1_covLow_2x-N701-3_Am_Pla_pb0101_v3.5 -> Done
# Chr1_covLow_2x-N701-40_Am_Pla_pb0138_v3.5 -> Done
# Chr1_covLow_2x-N701-41_Am_Pla_pb0139_v3.5 -> Done
# Chr1_covLow_2x-N701-42_Am_Pla_pb0140_v3.5 -> Done
# Chr1_covLow_2x-N701-43_Am_Pla_pb0141_v3.5 -> Done
# Chr1_covLow_2x-N701-44_Am_Pla_pb0143_v3.5 -> Done
# Chr1_covLow_2x-N701-45_Am_Pla_pb0144_v3.5 -> Done
# Chr1_covLow_2x-N701-46_Am_Pla_pb0145_v3.5 -> Done
# Chr1_covLow_2x-N701-47_Am_Pla_pb0146_v3.5 -> Done
# Chr1_covLow_2x-N701-48_Am_Pla_pb0147_v3.5 -> Done
# Chr1_covLow_2x-N701-49_Am_Pla_pb0148_v3.5 -> Done
# Chr1_covLow_2x-N701-4_Am_Pla_pb0102_v3.5 -> Done
# Chr1_covLow_2x-N701-50_Am_Pla_pb0149_v3.5 -> Done
# Chr1_covLow_2x-N701-51_Am_Pla_pb0150_v3.5 -> Done
# Chr1_covLow_2x-N701-52_Am_Pla_pb0151_v3.5 -> Done
# Chr1_covLow_2x-N701-53_Am_Pla_pb0152_v3.5 -> Done
# Chr1_covLow_2x-N701-54_Am_Pla_pb0153_v3.5 -> Done
# Chr1_covLow_2x-N701-55_Am_Pla_pb0154_v3.5 -> Done
# Chr1_covLow_2x-N701-56_Am_Pla_pb0155_v3.5 -> Done
# Chr1_covLow_2x-N701-57_Am_Pla_pb0156_v3.5 -> Done
# Chr1_covLow_2x-N701-58_Am_Pla_pb0157_v3.5 -> Done
# Chr1_covLow_2x-N701-59_Am_Pla_pb0158_v3.5 -> Done
# Chr1_covLow_2x-N701-5_Am_Pla_pb0103_v3.5 -> Done
# Chr1_covLow_2x-N701-60_Am_Pla_pb0159_v3.5 -> Done
# Chr1_covLow_2x-N701-61_Am_Pla_pb0160_v3.5 -> Done
# Chr1_covLow_2x-N701-62_Am_Pla_pb0161_v3.5 -> Done
# Chr1_covLow_2x-N701-63_Am_Pla_pb0162_v3.5 -> Done
# Chr1_covLow_2x-N701-64_Am_Pla_pb0163_v3.5 -> Done
# Chr1_covLow_2x-N701-65_Am_Pla_pb0164_v3.5 -> Done
# Chr1_covLow_2x-N701-66_Am_Pla_pb0165_v3.5 -> Done
# Chr1_covLow_2x-N701-67_Am_Pla_pb0166_v3.5 -> Done
# Chr1_covLow_2x-N701-68_Am_Pla_pb0168_v3.5 -> Done
# Chr1_covLow_2x-N701-69_Am_Pla_pb0169_v3.5 -> Done
# Chr1_covLow_2x-N701-6_Am_Pla_pb0104_v3.5 -> Done
# Chr1_covLow_2x-N701-70_Am_Pla_pb0170_v3.5 -> Done
# Chr1_covLow_2x-N701-71_Am_Pla_pb0171_v3.5 -> Done
# Chr1_covLow_2x-N701-72_Am_Pla_pb0172_v3.5 -> Done
# Chr1_covLow_2x-N701-73_Am_Pla_pb0173_v3.5 -> Done
# Chr1_covLow_2x-N701-74_Am_Pla_pb0175_v3.5 -> Done
# Chr1_covLow_2x-N701-75_Am_Pla_pb0176_v3.5 -> Done
# Chr1_covLow_2x-N701-76_Am_Pla_pb0177_v3.5 -> Done
# Chr1_covLow_2x-N701-77_Am_Pla_pb0178_v3.5 -> Done
# Chr1_covLow_2x-N701-78_Am_Pla_pb0179_v3.5 -> Done
# Chr1_covLow_2x-N701-79_Am_Pla_pb0180_v3.5 -> Done
# Chr1_covLow_2x-N701-7_Am_Pla_pb0105_v3.5 -> Done
# Chr1_covLow_2x-N701-80_Am_Pla_pb0181_v3.5 -> Done
# Chr1_covLow_2x-N701-81_Am_Pla_pb0182_v3.5 -> Done
# Chr1_covLow_2x-N701-82_Am_Pla_pb0183_v3.5 -> Done
# Chr1_covLow_2x-N701-83_Am_Pla_pb0184_v3.5 -> Done
# Chr1_covLow_2x-N701-84_Am_Pla_pb0185_v3.5 -> Done
# Chr1_covLow_2x-N701-85_Am_Pla_pb0186_v3.5 -> Done
# Chr1_covLow_2x-N701-86_Am_Pla_pb0187_v3.5 -> Done
# Chr1_covLow_2x-N701-87_Am_Pla_pb0188_v3.5 -> Done
# Chr1_covLow_2x-N701-88_Am_Pla_pb0189_v3.5 -> Done
# Chr1_covLow_2x-N701-89_Am_Pla_pb0190_v3.5 -> Done
# Chr1_covLow_2x-N701-8_Am_Pla_pb0106_v3.5 -> Done
# Chr1_covLow_2x-N701-90_Am_Pla_pb0191_v3.5 -> Done
# Chr1_covLow_2x-N701-91_Am_Pla_pb0192_v3.5 -> Done
# Chr1_covLow_2x-N701-92_Am_Pla_pb0193_v3.5 -> Done
# Chr1_covLow_2x-N701-93_Am_Pla_pb0194_v3.5 -> Done
# Chr1_covLow_2x-N701-94_Am_Pla_pb0195_v3.5 -> Done
# Chr1_covLow_2x-N701-95_Am_Pla_pb0196_v3.5 -> Done
# Chr1_covLow_2x-N701-9_Am_Pla_pb0107_v3.5 -> Done
# Chr1_covLow_2x-N702-10_Am_Pla_pb0010_v3.5 -> Done
# Chr1_covLow_2x-N702-11_Am_Pla_pb0011_v3.5 -> Done
# Chr1_covLow_2x-N702-12_Am_Pla_pb0012_v3.5 -> Done
# Chr1_covLow_2x-N702-13_Am_Pla_pb0013_v3.5 -> Done
# Chr1_covLow_2x-N702-14_Am_Pla_pb0014_v3.5 -> Done
# Chr1_covLow_2x-N702-15_Am_Pla_pb0015_v3.5 -> Done
# Chr1_covLow_2x-N702-16_Am_Pla_pb0016_v3.5 -> Done
# Chr1_covLow_2x-N702-17_Am_Pla_pb0017_v3.5 -> Done
# Chr1_covLow_2x-N702-18_Am_Pla_pb0018_v3.5 -> Done
# Chr1_covLow_2x-N702-19_Am_Pla_pb0019_v3.5 -> Done
# Chr1_covLow_2x-N702-1_Am_Pla_pb0001_v3.5 -> Done
# Chr1_covLow_2x-N702-20_Am_Pla_pb0020_v3.5 -> Done
# Chr1_covLow_2x-N702-21_Am_Pla_pb0021_v3.5 -> Done
# Chr1_covLow_2x-N702-22_Am_Pla_pb0022_v3.5 -> Done
# Chr1_covLow_2x-N702-23_Am_Pla_pb0023_v3.5 -> Done
# Chr1_covLow_2x-N702-24_Am_Pla_pb0024_v3.5 -> Done
# Chr1_covLow_2x-N702-25_Am_Pla_pb0025_v3.5 -> Done
# Chr1_covLow_2x-N702-26_Am_Pla_pb0026_v3.5 -> Done
# Chr1_covLow_2x-N702-27_Am_Pla_pb0027_v3.5 -> Done
# Chr1_covLow_2x-N702-28_Am_Pla_pb0028_v3.5 -> Done
# Chr1_covLow_2x-N702-29_Am_Pla_pb0029_v3.5 -> Done
# Chr1_covLow_2x-N702-2_Am_Pla_pb0002_v3.5 -> Done
# Chr1_covLow_2x-N702-30_Am_Pla_pb0030_v3.5 -> Done
# Chr1_covLow_2x-N702-31_Am_Pla_pb0031_v3.5 -> Done
# Chr1_covLow_2x-N702-32_Am_Pla_pb0032_v3.5 -> Done
# Chr1_covLow_2x-N702-33_Am_Pla_pb0033_v3.5 -> Done
# Chr1_covLow_2x-N702-34_Am_Pla_pb0034_v3.5 -> Done
# Chr1_covLow_2x-N702-35_Am_Pla_pb0035_v3.5 -> Done
# Chr1_covLow_2x-N702-36_Am_Pla_pb0036_v3.5 -> Done
# Chr1_covLow_2x-N702-37_Am_Pla_pb0037_v3.5 -> Done
# Chr1_covLow_2x-N702-38_Am_Pla_pb0038_v3.5 -> Done
# Chr1_covLow_2x-N702-39_Am_Pla_pb0039_v3.5 -> Done
# Chr1_covLow_2x-N702-3_Am_Pla_pb0003_v3.5 -> Done
# Chr1_covLow_2x-N702-40_Am_Pla_pb0040_v3.5 -> Done
# Chr1_covLow_2x-N702-41_Am_Pla_pb0041_v3.5 -> Done
# Chr1_covLow_2x-N702-42_Am_Pla_pb0042_v3.5 -> Done
# Chr1_covLow_2x-N702-43_Am_Pla_pb0043_v3.5 -> Done
# Chr1_covLow_2x-N702-44_Am_Pla_pb0044_v3.5 -> Done
# Chr1_covLow_2x-N702-45_Am_Pla_pb0045_v3.5 -> Done
# Chr1_covLow_2x-N702-46_Am_Pla_pb0046_v3.5 -> Done
# Chr1_covLow_2x-N702-47_Am_Pla_pb0047_v3.5 -> Done
# Chr1_covLow_2x-N702-48_Am_Pla_pb0048_v3.5 -> Done
# Chr1_covLow_2x-N702-49_Am_Pla_pb0049_v3.5 -> Done
# Chr1_covLow_2x-N702-4_Am_Pla_pb0004_v3.5 -> Done
# Chr1_covLow_2x-N702-50_Am_Pla_pb0051_v3.5 -> Done
# Chr1_covLow_2x-N702-51_Am_Pla_pb0052_v3.5 -> Done
# Chr1_covLow_2x-N702-52_Am_Pla_pb0053_v3.5 -> Done
# Chr1_covLow_2x-N702-53_Am_Pla_pb0054_v3.5 -> Done
# Chr1_covLow_2x-N702-54_Am_Pla_pb0055_v3.5 -> Done
# Chr1_covLow_2x-N702-55_Am_Pla_pb0056_v3.5 -> Done
# Chr1_covLow_2x-N702-56_Am_Pla_pb0057_v3.5 -> Done
# Chr1_covLow_2x-N702-57_Am_Pla_pb0058_v3.5 -> Done
# Chr1_covLow_2x-N702-58_Am_Pla_pb0060_v3.5 -> Done
# Chr1_covLow_2x-N702-59_Am_Pla_pb0061_v3.5 -> Done
# Chr1_covLow_2x-N702-5_Am_Pla_pb0005_v3.5 -> Done
# Chr1_covLow_2x-N702-60_Am_Pla_pb0062_v3.5 -> Done
# Chr1_covLow_2x-N702-61_Am_Pla_pb0063_v3.5 -> Done
# Chr1_covLow_2x-N702-62_Am_Pla_pb0064_v3.5 -> Done
# Chr1_covLow_2x-N702-63_Am_Pla_pb0065_v3.5 -> Done
# Chr1_covLow_2x-N702-64_Am_Pla_pb0066_v3.5 -> Done
# Chr1_covLow_2x-N702-65_Am_Pla_pb0067_v3.5 -> Done
# Chr1_covLow_2x-N702-66_Am_Pla_pb0068_v3.5 -> Done
# Chr1_covLow_2x-N702-67_Am_Pla_pb0069_v3.5 -> Done
# Chr1_covLow_2x-N702-68_Am_Pla_pb0070_v3.5 -> Done
# Chr1_covLow_2x-N702-69_Am_Pla_pb0071_v3.5 -> Done
# Chr1_covLow_2x-N702-6_Am_Pla_pb0006_v3.5 -> Done
# Chr1_covLow_2x-N702-70_Am_Pla_pb0072_v3.5 -> Done
# Chr1_covLow_2x-N702-71_Am_Pla_pb0073_v3.5 -> Done
# Chr1_covLow_2x-N702-72_Am_Pla_pb0074_v3.5 -> Done
# Chr1_covLow_2x-N702-73_Am_Pla_pb0075_v3.5 -> Done
# Chr1_covLow_2x-N702-74_Am_Pla_pb0076_v3.5 -> Done
# Chr1_covLow_2x-N702-75_Am_Pla_pb0077_v3.5 -> Done
# Chr1_covLow_2x-N702-76_Am_Pla_pb0078_v3.5 -> Done
# Chr1_covLow_2x-N702-77_Am_Pla_pb0079_v3.5 -> Done
# Chr1_covLow_2x-N702-78_Am_Pla_pb0080_v3.5 -> Done
# Chr1_covLow_2x-N702-79_Am_Pla_pb0081_v3.5 -> Done
# Chr1_covLow_2x-N702-7_Am_Pla_pb0007_v3.5 -> Done
# Chr1_covLow_2x-N702-80_Am_Pla_pb0082_v3.5 -> Done
# Chr1_covLow_2x-N702-81_Am_Pla_pb0083_v3.5 -> Done
# Chr1_covLow_2x-N702-82_Am_Pla_pb0084_v3.5 -> Done
# Chr1_covLow_2x-N702-83_Am_Pla_pb0085_v3.5 -> Done
# Chr1_covLow_2x-N702-84_Am_Pla_pb0086_v3.5 -> Done
# Chr1_covLow_2x-N702-85_Am_Pla_pb0087_v3.5 -> Done
# Chr1_covLow_2x-N702-86_Am_Pla_pb0088_v3.5 -> Done
# Chr1_covLow_2x-N702-87_Am_Pla_pb0089_v3.5 -> Done
# Chr1_covLow_2x-N702-88_Am_Pla_pb0090_v3.5 -> Done
# Chr1_covLow_2x-N702-89_Am_Pla_pb0091_v3.5 -> Done
# Chr1_covLow_2x-N702-8_Am_Pla_pb0008_v3.5 -> Done
# Chr1_covLow_2x-N702-90_Am_Pla_pb0092_v3.5 -> Done
# Chr1_covLow_2x-N702-91_Am_Pla_pb0093_v3.5 -> Done
# Chr1_covLow_2x-N702-92_Am_Pla_pb0094_v3.5 -> Done
# Chr1_covLow_2x-N702-93_Am_Pla_pb0095_v3.5 -> Done
# Chr1_covLow_2x-N702-94_Am_Pla_pb0096_v3.5 -> Done
# Chr1_covLow_2x-N702-95_Am_Pla_pb0097_v3.5 -> Done
# Chr1_covLow_2x-N702-96_Am_Pla_pb0098_v3.5 -> Done
# Chr1_covLow_2x-N702-9_Am_Pla_pb0009_v3.5 -> Done
# Chr1_covLow_2x-N703-10_Am_Pla_pb0206_v3.5 -> Done
# Chr1_covLow_2x-N703-11_Am_Pla_pb0207_v3.5 -> Done
# Chr1_covLow_2x-N703-12_Am_Pla_pb0209_v3.5 -> Done
# Chr1_covLow_2x-N703-13_Am_Pla_pb0210_v3.5 -> Done
# Chr1_covLow_2x-N703-14_Am_Pla_pb0211_v3.5 -> Done
# Chr1_covLow_2x-N703-15_Am_Pla_pb0213_v3.5 -> Done
# Chr1_covLow_2x-N703-16_Am_Pla_pb0214_v3.5 -> Done
# Chr1_covLow_2x-N703-17_Am_Pla_pb0215_v3.5 -> Done
# Chr1_covLow_2x-N703-18_Am_Pla_pb0217_v3.5 -> Done
# Chr1_covLow_2x-N703-19_Am_Pla_pb0218_v3.5 -> Done
# Chr1_covLow_2x-N703-1_Am_Pla_pb0197_v3.5 -> Done
# Chr1_covLow_2x-N703-20_Am_Pla_pb0219_v3.5 -> Done
# Chr1_covLow_2x-N703-21_Am_Pla_pb0220_v3.5 -> Done
# Chr1_covLow_2x-N703-22_Am_Pla_pb0221_v3.5 -> Done
# Chr1_covLow_2x-N703-23_Am_Pla_pb0222_v3.5 -> Done
# Chr1_covLow_2x-N703-24_Am_Pla_pb0223_v3.5 -> Done
# Chr1_covLow_2x-N703-25_Am_Pla_pb0224_v3.5 -> Done
# Chr1_covLow_2x-N703-26_Am_Pla_pb0225_v3.5 -> Done
# Chr1_covLow_2x-N703-27_Am_Pla_pb0226_v3.5 -> Done
# Chr1_covLow_2x-N703-28_Am_Pla_pb0227_v3.5 -> Done
# Chr1_covLow_2x-N703-29_Am_Pla_pb0228_v3.5 -> Done
# Chr1_covLow_2x-N703-2_Am_Pla_pb0198_v3.5 -> Done
# Chr1_covLow_2x-N703-30_Am_Pla_pb0229_v3.5 -> Done
# Chr1_covLow_2x-N703-31_Am_Pla_pb0230_v3.5 -> Done
# Chr1_covLow_2x-N703-32_Am_Pla_pb0231_v3.5 -> Done
# Chr1_covLow_2x-N703-33_Am_Pla_pb0232_v3.5 -> Done
# Chr1_covLow_2x-N703-34_Am_Pla_pb0233_v3.5 -> Done
# Chr1_covLow_2x-N703-35_Am_Pla_pb0234_v3.5 -> Done
# Chr1_covLow_2x-N703-36_Am_Pla_pb0235_v3.5 -> Done
# Chr1_covLow_2x-N703-37_Am_Pla_pb0236_v3.5 -> Done
# Chr1_covLow_2x-N703-38_Am_Pla_pb0237_v3.5 -> Done
# Chr1_covLow_2x-N703-39_Am_Pla_pb0238_v3.5 -> Done
# Chr1_covLow_2x-N703-3_Am_Pla_pb0199_v3.5 -> Done
# Chr1_covLow_2x-N703-40_Am_Pla_pb0239_v3.5 -> Done
# Chr1_covLow_2x-N703-41_Am_Pla_pb0240_v3.5 -> Done
# Chr1_covLow_2x-N703-42_Am_Pla_pb0241_v3.5 -> Done
# Chr1_covLow_2x-N703-43_Am_Pla_pb0242_v3.5 -> Done
# Chr1_covLow_2x-N703-44_Am_Pla_pb0243_v3.5 -> Done
# Chr1_covLow_2x-N703-45_Am_Pla_pb0244_v3.5 -> Done
# Chr1_covLow_2x-N703-46_Am_Pla_pb0245_v3.5 -> Done
# Chr1_covLow_2x-N703-47_Am_Pla_pb0246_v3.5 -> Done
# Chr1_covLow_2x-N703-48_Am_Pla_pb0247_v3.5 -> Done
# Chr1_covLow_2x-N703-49_Am_Pla_pb0248_v3.5 -> Done
# Chr1_covLow_2x-N703-4_Am_Pla_pb0200_v3.5 -> Done
# Chr1_covLow_2x-N703-50_Am_Pla_pb0249_v3.5 -> Done
# Chr1_covLow_2x-N703-51_Am_Pla_pb0250_v3.5 -> Done
# Chr1_covLow_2x-N703-52_Am_Pla_pb0251_v3.5 -> Done
# Chr1_covLow_2x-N703-53_Am_Pla_pb0252_v3.5 -> Done
# Chr1_covLow_2x-N703-54_Am_Pla_pb0253_v3.5 -> Done
# Chr1_covLow_2x-N703-55_Am_Pla_pb0254_v3.5 -> Done
# Chr1_covLow_2x-N703-56_Am_Pla_pb0256_v3.5 -> Done
# Chr1_covLow_2x-N703-57_Am_Pla_pb0257_v3.5 -> Done
# Chr1_covLow_2x-N703-58_Am_Pla_pb0258_v3.5 -> Done
# Chr1_covLow_2x-N703-59_Am_Pla_pb0259_v3.5 -> Done
# Chr1_covLow_2x-N703-5_Am_Pla_pb0201_v3.5 -> Done
# Chr1_covLow_2x-N703-60_Am_Pla_pb0260_v3.5 -> Done
# Chr1_covLow_2x-N703-61_Am_Pla_pb0261_v3.5 -> Done
# Chr1_covLow_2x-N703-62_Am_Pla_pb0262_v3.5 -> Done
# Chr1_covLow_2x-N703-63_Am_Pla_pb0263_v3.5 -> Done
# Chr1_covLow_2x-N703-64_Am_Pla_pb0264_v3.5 -> Done
# Chr1_covLow_2x-N703-65_Am_Pla_pb0265_v3.5 -> Done
# Chr1_covLow_2x-N703-66_Am_Pla_pb0266_v3.5 -> Done
# Chr1_covLow_2x-N703-67_Am_Pla_pb0267_v3.5 -> Done
# Chr1_covLow_2x-N703-68_Am_Pla_pb0268_v3.5 -> Done
# Chr1_covLow_2x-N703-69_Am_Pla_pb0269_v3.5 -> Done
# Chr1_covLow_2x-N703-6_Am_Pla_pb0202_v3.5 -> Done
# Chr1_covLow_2x-N703-70_Am_Pla_pb0270_v3.5 -> Done
# Chr1_covLow_2x-N703-71_Am_Pla_pb0271_v3.5 -> Done
# Chr1_covLow_2x-N703-72_Am_Pla_pb0272_v3.5 -> Done
# Chr1_covLow_2x-N703-73_Am_Pla_pb0273_v3.5 -> Done
# Chr1_covLow_2x-N703-74_Am_Pla_pb0274_v3.5 -> Done
# Chr1_covLow_2x-N703-75_Am_Pla_pb0275_v3.5 -> Done
# Chr1_covLow_2x-N703-76_Am_Pla_pb0276_v3.5 -> Done
# Chr1_covLow_2x-N703-77_Am_Pla_pb0277_v3.5 -> Done
# Chr1_covLow_2x-N703-78_Am_Pla_pb0278_v3.5 -> Done
# Chr1_covLow_2x-N703-79_Am_Pla_pb0279_v3.5 -> Done
# Chr1_covLow_2x-N703-7_Am_Pla_pb0203_v3.5 -> Done
# Chr1_covLow_2x-N703-80_Am_Pla_pb0280_v3.5 -> Done
# Chr1_covLow_2x-N703-81_Am_Pla_pb0281_v3.5 -> Done
# Chr1_covLow_2x-N703-82_Am_Pla_pb0282_v3.5 -> Done
# Chr1_covLow_2x-N703-83_Am_Pla_pb0283_v3.5 -> Done
# Chr1_covLow_2x-N703-84_Am_Pla_pb0284_v3.5 -> Done
# Chr1_covLow_2x-N703-85_Am_Pla_pb0285_v3.5 -> Done
# Chr1_covLow_2x-N703-86_Am_Pla_pb0286_v3.5 -> Done
# Chr1_covLow_2x-N703-87_Am_Pla_pb0287_v3.5 -> Done
# Chr1_covLow_2x-N703-88_Am_Pla_pb0288_v3.5 -> Done
# Chr1_covLow_2x-N703-89_Am_Pla_pb0289_v3.5 -> Done
# Chr1_covLow_2x-N703-8_Am_Pla_pb0204_v3.5 -> Done
# Chr1_covLow_2x-N703-90_Am_Pla_pb0290_v3.5 -> Done
# Chr1_covLow_2x-N703-91_Am_Pla_pb0291_v3.5 -> Done
# Chr1_covLow_2x-N703-92_Am_Pla_pb0292a_v3.5 -> Done
# Chr1_covLow_2x-N703-93_Am_Pla_pb0293_v3.5 -> Done
# Chr1_covLow_2x-N703-94_Am_Pla_pb0295_v3.5 -> Done
# Chr1_covLow_2x-N703-9_Am_Pla_pb0205_v3.5 -> Done
# Chr1_covLow_2x-N704-10_Am_Pla_pb0308_v3.5 -> Done
# Chr1_covLow_2x-N704-11_Am_Pla_pb0309_v3.5 -> Done
# Chr1_covLow_2x-N704-12_Am_Pla_pb0310_v3.5 -> Done
# Chr1_covLow_2x-N704-13_Am_Pla_pb0311_v3.5 -> Done
# Chr1_covLow_2x-N704-14_Am_Pla_pb0312_v3.5 -> Done
# Chr1_covLow_2x-N704-15_Am_Pla_pb0313_v3.5 -> Done
# Chr1_covLow_2x-N704-16_Am_Pla_pb0314_v3.5 -> Done
# Chr1_covLow_2x-N704-17_Am_Pla_pb0315_v3.5 -> Done
# Chr1_covLow_2x-N704-18_Am_Pla_pb0316_v3.5 -> Done
# Chr1_covLow_2x-N704-19_Am_Pla_pb0317_v3.5 -> Done
# Chr1_covLow_2x-N704-1_Am_Pla_pb0296a_v3.5 -> Done
# Chr1_covLow_2x-N704-20_Am_Pla_pb0318_v3.5 -> Done
# Chr1_covLow_2x-N704-21_Am_Pla_pb0319_v3.5 -> Done
# Chr1_covLow_2x-N704-22_Am_Pla_pb0320_v3.5 -> Done
# Chr1_covLow_2x-N704-23_Am_Pla_pb0321_v3.5 -> Done
# Chr1_covLow_2x-N704-24_Am_Pla_pb0322_v3.5 -> Done
# Chr1_covLow_2x-N704-25_Am_Pla_pb0323_v3.5 -> Done
# Chr1_covLow_2x-N704-26_Am_Pla_pb0324_v3.5 -> Done
# Chr1_covLow_2x-N704-27_Am_Pla_pb0325_v3.5 -> Done
# Chr1_covLow_2x-N704-28_Am_Pla_pb0326_v3.5 -> Done
# Chr1_covLow_2x-N704-29_Am_Pla_pb0327_v3.5 -> Done
# Chr1_covLow_2x-N704-2_Am_Pla_pb0297_v3.5 -> Done
# Chr1_covLow_2x-N704-30_Am_Pla_pb0328_v3.5 -> Done
# Chr1_covLow_2x-N704-31_Am_Pla_pb0329_v3.5 -> Done
# Chr1_covLow_2x-N704-32_Am_Pla_pb0330_v3.5 -> Done
# Chr1_covLow_2x-N704-33_Am_Pla_pb0331_v3.5 -> Done
# Chr1_covLow_2x-N704-34_Am_Pla_pb0332_v3.5 -> Done
# Chr1_covLow_2x-N704-35_Am_Pla_pb0333_v3.5 -> Done
# Chr1_covLow_2x-N704-36_Am_Pla_pb0334_v3.5 -> Done
# Chr1_covLow_2x-N704-37_Am_Pla_pb0335_v3.5 -> Done
# Chr1_covLow_2x-N704-38_Am_Pla_pb0336_v3.5 -> Done
# Chr1_covLow_2x-N704-39_Am_Pla_pb0337_v3.5 -> Done
# Chr1_covLow_2x-N704-3_Am_Pla_pb0298_v3.5 -> Done
# Chr1_covLow_2x-N704-40_Am_Pla_pb0338_v3.5 -> Done
# Chr1_covLow_2x-N704-41_Am_Pla_pb0339_v3.5 -> Done
# Chr1_covLow_2x-N704-42_Am_Pla_pb0341_v3.5 -> Done
# Chr1_covLow_2x-N704-43_Am_Pla_pb0342_v3.5 -> Done
# Chr1_covLow_2x-N704-44_Am_Pla_pb0343_v3.5 -> Done
# Chr1_covLow_2x-N704-45_Am_Pla_pb0344_v3.5 -> Done
# Chr1_covLow_2x-N704-46_Am_Pla_pb0345_v3.5 -> Done
# Chr1_covLow_2x-N704-47_Am_Pla_pb0346_v3.5 -> Done
# Chr1_covLow_2x-N704-48_Am_Pla_pb0347_v3.5 -> Done
# Chr1_covLow_2x-N704-49_Am_Pla_pb0348_v3.5 -> Done
# Chr1_covLow_2x-N704-4_Am_Pla_pb0300_v3.5 -> Done
# Chr1_covLow_2x-N704-50_Am_Pla_pb0350_v3.5 -> Done
# Chr1_covLow_2x-N704-51_Am_Pla_pb0351_v3.5 -> Done
# Chr1_covLow_2x-N704-52_Am_Pla_pb0352_v3.5 -> Done
# Chr1_covLow_2x-N704-53_Am_Pla_pb0353_v3.5 -> Done
# Chr1_covLow_2x-N704-54_Am_Pla_pb0354_v3.5 -> Done
# Chr1_covLow_2x-N704-55_Am_Pla_pb0355_v3.5 -> Done
# Chr1_covLow_2x-N704-56_Am_Pla_pb0356_v3.5 -> Done
# Chr1_covLow_2x-N704-57_Am_Pla_pb0357_v3.5 -> Done
# Chr1_covLow_2x-N704-58_Am_Pla_pb0358_v3.5 -> Done
# Chr1_covLow_2x-N704-59_Am_Pla_pb0359_v3.5 -> Done
# Chr1_covLow_2x-N704-5_Am_Pla_pb0301_v3.5 -> Done
# Chr1_covLow_2x-N704-60_Am_Pla_pb0360_v3.5 -> Done
# Chr1_covLow_2x-N704-61_Am_Pla_pb0361_v3.5 -> Done
# Chr1_covLow_2x-N704-62_Am_Pla_pb0362_v3.5 -> Done
# Chr1_covLow_2x-N704-63_Am_Pla_pb0363_v3.5 -> Done
# Chr1_covLow_2x-N704-64_Am_Pla_pb0366_v3.5 -> Done
# Chr1_covLow_2x-N704-65_Am_Pla_pb0368_v3.5 -> Done
# Chr1_covLow_2x-N704-66_Am_Pla_pb0369_v3.5 -> Done
# Chr1_covLow_2x-N704-67_Am_Pla_pb0370_v3.5 -> Done
# Chr1_covLow_2x-N704-68_Am_Pla_pb0372_v3.5 -> Done
# Chr1_covLow_2x-N704-69_Am_Pla_pb0374_v3.5 -> Done
# Chr1_covLow_2x-N704-6_Am_Pla_pb0302_v3.5 -> Done
# Chr1_covLow_2x-N704-70_Am_Pla_pb0375_v3.5 -> Done
# Chr1_covLow_2x-N704-71_Am_Pla_pb0376_v3.5 -> Done
# Chr1_covLow_2x-N704-72_Am_Pla_pb0377_v3.5 -> Done
# Chr1_covLow_2x-N704-73_Am_Pla_pb0378_v3.5 -> Done
# Chr1_covLow_2x-N704-74_Am_Pla_pb0380_v3.5 -> Done
# Chr1_covLow_2x-N704-75_Am_Pla_pb0381_v3.5 -> Done
# Chr1_covLow_2x-N704-76_Am_Pla_pb0382_v3.5 -> Done
# Chr1_covLow_2x-N704-77_Am_Pla_pb0383_v3.5 -> Done
# Chr1_covLow_2x-N704-78_Am_Pla_pb0384_v3.5 -> Done
# Chr1_covLow_2x-N704-79_Am_Pla_pb0385_v3.5 -> Done
# Chr1_covLow_2x-N704-7_Am_Pla_pb0303_v3.5 -> Done
# Chr1_covLow_2x-N704-80_Am_Pla_pb0387_v3.5 -> Done
# Chr1_covLow_2x-N704-81_Am_Pla_pb0388_v3.5 -> Done
# Chr1_covLow_2x-N704-82_Am_Pla_pb0389_v3.5 -> Done
# Chr1_covLow_2x-N704-83_Am_Pla_pb0390_v3.5 -> Done
# Chr1_covLow_2x-N704-84_Am_Pla_pb0391_v3.5 -> Done
# Chr1_covLow_2x-N704-85_Am_Pla_pb0392_v3.5 -> Done
# Chr1_covLow_2x-N704-86_Am_Pla_pb0393_v3.5 -> Done
# Chr1_covLow_2x-N704-87_Am_Pla_pb0394_v3.5 -> Done
# Chr1_covLow_2x-N704-88_Am_Pla_pb0395_v3.5 -> Done
# Chr1_covLow_2x-N704-89_Am_Pla_pb0396_v3.5 -> Done
# Chr1_covLow_2x-N704-8_Am_Pla_pb0306_v3.5 -> Done
# Chr1_covLow_2x-N704-90_Am_Pla_pb0397_v3.5 -> Done
# Chr1_covLow_2x-N704-91_Am_Pla_pb0398_v3.5 -> Done
# Chr1_covLow_2x-N704-92_Am_Pla_pb0399_v3.5 -> Done
# Chr1_covLow_2x-N704-93_Am_Pla_pb0400_v3.5 -> Done
# Chr1_covLow_2x-N704-94_Am_Pla_pb0401_v3.5 -> Done
# Chr1_covLow_2x-N704-95_Am_Pla_pb0402_v3.5 -> Done
# Chr1_covLow_2x-N704-9_Am_Pla_pb0307_v3.5 -> Done
# Chr1_covLow_2x-N705-10_Am_Pla_pb0415_v3.5 -> Done
# Chr1_covLow_2x-N705-11_Am_Pla_pb0416_v3.5 -> Done
# Chr1_covLow_2x-N705-12_Am_Pla_pb0418_v3.5 -> Done
# Chr1_covLow_2x-N705-13_Am_Pla_pb0419_v3.5 -> Done
# Chr1_covLow_2x-N705-14_Am_Pla_pb0420_v3.5 -> Done
# Chr1_covLow_2x-N705-15_Am_Pla_pb0421_v3.5 -> Done
# Chr1_covLow_2x-N705-16_Am_Pla_pb0422_v3.5 -> Done
# Chr1_covLow_2x-N705-17_Am_Pla_pb0423_v3.5 -> Done
# Chr1_covLow_2x-N705-18_Am_Pla_pb0424_v3.5 -> Done
# Chr1_covLow_2x-N705-19_Am_Pla_pb0425_v3.5 -> Done
# Chr1_covLow_2x-N705-1_Am_Pla_pb0059_v3.5 -> Done
# Chr1_covLow_2x-N705-20_Am_Pla_pb0427_v3.5 -> Done
# Chr1_covLow_2x-N705-21_Am_Pla_pb0428_v3.5 -> Done
# Chr1_covLow_2x-N705-22_Am_Pla_pb0429_v3.5 -> Done
# Chr1_covLow_2x-N705-23_Am_Pla_pb0432_v3.5 -> Done
# Chr1_covLow_2x-N705-24_Am_Pla_pb0435_v3.5 -> Done
# Chr1_covLow_2x-N705-25_Am_Pla_pb0436_v3.5 -> Done
# Chr1_covLow_2x-N705-26_Am_Pla_pb0437_v3.5 -> Done
# Chr1_covLow_2x-N705-27_Am_Pla_pb0438_v3.5 -> Done
# Chr1_covLow_2x-N705-28_Am_Pla_pb0440_v3.5 -> Done
# Chr1_covLow_2x-N705-29_Am_Pla_pb0441_v3.5 -> Done
# Chr1_covLow_2x-N705-2_Am_Pla_pb0364_v3.5 -> Done
# Chr1_covLow_2x-N705-30_Am_Pla_pb0442_v3.5 -> Done
# Chr1_covLow_2x-N705-31_Am_Pla_pb0443_v3.5 -> Done
# Chr1_covLow_2x-N705-32_Am_Pla_pb0445_v3.5 -> Done
# Chr1_covLow_2x-N705-33_Am_Pla_pb0447_v3.5 -> Done
# Chr1_covLow_2x-N705-34_Am_Pla_pb0448_v3.5 -> Done
# Chr1_covLow_2x-N705-35_Am_Pla_pb0450_v3.5 -> Done
# Chr1_covLow_2x-N705-36_Am_Pla_pb0451_v3.5 -> Done
# Chr1_covLow_2x-N705-37_Am_Pla_pb0453_v3.5 -> Done
# Chr1_covLow_2x-N705-38_Am_Pla_pb0454_v3.5 -> Done
# Chr1_covLow_2x-N705-39_Am_Pla_pb0455_v3.5 -> Done
# Chr1_covLow_2x-N705-3_Am_Pla_pb0405_v3.5 -> Done
# Chr1_covLow_2x-N705-40_Am_Pla_pb0456_v3.5 -> Done
# Chr1_covLow_2x-N705-41_Am_Pla_pb0459_v3.5 -> Done
# Chr1_covLow_2x-N705-42_Am_Pla_pb0460_v3.5 -> Done
# Chr1_covLow_2x-N705-43_Am_Pla_pb0461_v3.5 -> Done
# Chr1_covLow_2x-N705-44_Am_Pla_pb0462_v3.5 -> Done
# Chr1_covLow_2x-N705-45_Am_Pla_pb0463_v3.5 -> Done
# Chr1_covLow_2x-N705-46_Am_Pla_pb0465_v3.5 -> Done
# Chr1_covLow_2x-N705-47_Am_Pla_pb0468_v3.5 -> Done
# Chr1_covLow_2x-N705-48_Am_Pla_pb0469_v3.5 -> Done
# Chr1_covLow_2x-N705-49_Am_Pla_pb0472_v3.5 -> Done
# Chr1_covLow_2x-N705-4_Am_Pla_pb0408_v3.5 -> Done
# Chr1_covLow_2x-N705-50_Am_Pla_pb0474_v3.5 -> Done
# Chr1_covLow_2x-N705-51_Am_Pla_pb0476_v3.5 -> Done
# Chr1_covLow_2x-N705-52_Am_Pla_pb0479_v3.5 -> Done
# Chr1_covLow_2x-N705-53_Am_Pla_pb0480_v3.5 -> Done
# Chr1_covLow_2x-N705-54_Am_Pla_pb0482_v3.5 -> Done
# Chr1_covLow_2x-N705-55_Am_Pla_pb0484_v3.5 -> Done
# Chr1_covLow_2x-N705-56_Am_Pla_pb0485_v3.5 -> Done
# Chr1_covLow_2x-N705-57_Am_Pla_pb0486_v3.5 -> Done
# Chr1_covLow_2x-N705-58_Am_Pla_pb0487_v3.5 -> Done
# Chr1_covLow_2x-N705-59_Am_Pla_pb0489_v3.5 -> Done
# Chr1_covLow_2x-N705-5_Am_Pla_pb0409_v3.5 -> Done
# Chr1_covLow_2x-N705-60_Am_Pla_pb0491_v3.5 -> Done
# Chr1_covLow_2x-N705-61_Am_Pla_pb0494_v3.5 -> Done
# Chr1_covLow_2x-N705-62_Am_Pla_pb0495_v3.5 -> Done
# Chr1_covLow_2x-N705-63_Am_Pla_pb0498_v3.5 -> Done
# Chr1_covLow_2x-N705-64_Am_Pla_pb0500_v3.5 -> Done
# Chr1_covLow_2x-N705-65_Am_Pla_pb0526_v3.5 -> Done
# Chr1_covLow_2x-N705-66_Am_Pla_pb0539_v3.5 -> Done
# Chr1_covLow_2x-N705-67_Am_Pla_pb0547_v3.5 -> Done
# Chr1_covLow_2x-N705-68_Am_Pla_pb0731_v3.5 -> Done
# Chr1_covLow_2x-N705-69_Am_Pla_pb0733_v3.5 -> Done
# Chr1_covLow_2x-N705-6_Am_Pla_pb0410_v3.5 -> Done
# Chr1_covLow_2x-N705-70_Am_Pla_pb0738_v3.5 -> Done
# Chr1_covLow_2x-N705-71_Am_Pla_pb0740_v3.5 -> Done
# Chr1_covLow_2x-N705-72_Am_Pla_pb0743_v3.5 -> Done
# Chr1_covLow_2x-N705-73_Am_Pla_pb0746_v3.5 -> Done
# Chr1_covLow_2x-N705-74_Am_Pla_pb0747_v3.5 -> Done
# Chr1_covLow_2x-N705-75_Am_Pla_pb0750_v3.5 -> Done
# Chr1_covLow_2x-N705-76_Am_Pla_pb0754_v3.5 -> Done
# Chr1_covLow_2x-N705-77_Am_Pla_pb0757_v3.5 -> Done
# Chr1_covLow_2x-N705-78_Am_Pla_pb0758_v3.5 -> Done
# Chr1_covLow_2x-N705-79_Am_Pla_pb0759_v3.5 -> Done
# Chr1_covLow_2x-N705-7_Am_Pla_pb0412_v3.5 -> Done
# Chr1_covLow_2x-N705-80_Am_Pla_pb0760_v3.5 -> Done
# Chr1_covLow_2x-N705-81_Am_Pla_pb0761_v3.5 -> Done
# Chr1_covLow_2x-N705-82_Am_Pla_pb0763_v3.5 -> Done
# Chr1_covLow_2x-N705-83_Am_Pla_pb0764_v3.5 -> Done
# Chr1_covLow_2x-N705-84_Am_Pla_pb0765_v3.5 -> Done
# Chr1_covLow_2x-N705-85_Am_Pla_pb0766_v3.5 -> Done
# Chr1_covLow_2x-N705-86_Am_Pla_pb0767_v3.5 -> Done
# Chr1_covLow_2x-N705-87_Am_Pla_pb0769_v3.5 -> Done
# Chr1_covLow_2x-N705-88_Am_Pla_pb0770_v3.5 -> Done
# Chr1_covLow_2x-N705-89_Am_Pla_pb0771_v3.5 -> Done
# Chr1_covLow_2x-N705-8_Am_Pla_pb0413_v3.5 -> Done
# Chr1_covLow_2x-N705-90_Am_Pla_pb0772_v3.5 -> Done
# Chr1_covLow_2x-N705-91_Am_Pla_pb0773_v3.5 -> Done
# Chr1_covLow_2x-N705-9_Am_Pla_pb0414_v3.5 -> Done
# Chr1_covLow_2x-N706-10_Am_Pla_pb0786_v3.5 -> Done
# Chr1_covLow_2x-N706-11_Am_Pla_pb0787_v3.5 -> Done
# Chr1_covLow_2x-N706-12_Am_Pla_pb0788_v3.5 -> Done
# Chr1_covLow_2x-N706-13_Am_Pla_pb0789_v3.5 -> Done
# Chr1_covLow_2x-N706-14_Am_Pla_pb0790_v3.5 -> Done
# Chr1_covLow_2x-N706-15_Am_Pla_pb0791_v3.5 -> Done
# Chr1_covLow_2x-N706-16_Am_Pla_pb0792_v3.5 -> Done
# Chr1_covLow_2x-N706-17_Am_Pla_pb0793_v3.5 -> Done
# Chr1_covLow_2x-N706-18_Am_Pla_pb0794_v3.5 -> Done
# Chr1_covLow_2x-N706-19_Am_Pla_pb0795_v3.5 -> Done
# Chr1_covLow_2x-N706-1_Am_Pla_pb0774_v3.5 -> Done
# Chr1_covLow_2x-N706-20_Am_Pla_pb0796_v3.5 -> Done
# Chr1_covLow_2x-N706-21_Am_Pla_pb0797_v3.5 -> Done
# Chr1_covLow_2x-N706-22_Am_Pla_pb0798_v3.5 -> Done
# Chr1_covLow_2x-N706-23_Am_Pla_pb0799_v3.5 -> Done
# Chr1_covLow_2x-N706-24_Am_Pla_pb0800_v3.5 -> Done
# Chr1_covLow_2x-N706-25_Am_Pla_pb1823_v3.5 -> Done
# Chr1_covLow_2x-N706-26_Am_Pla_pb1824_v3.5 -> Done
# Chr1_covLow_2x-N706-27_Am_Pla_pb1826_v3.5 -> Done
# Chr1_covLow_2x-N706-28_Am_Pla_pb1827_v3.5 -> Done
# Chr1_covLow_2x-N706-29_Am_Pla_pb1828_v3.5 -> Done
# Chr1_covLow_2x-N706-2_Am_Pla_pb0775_v3.5 -> Done
# Chr1_covLow_2x-N706-30_Am_Pla_pb1829_v3.5 -> Done
# Chr1_covLow_2x-N706-31_Am_Pla_pb1831_v3.5 -> Done
# Chr1_covLow_2x-N706-32_Am_Pla_pb1832_v3.5 -> Done
# Chr1_covLow_2x-N706-33_Am_Pla_pb1833_v3.5 -> Done
# Chr1_covLow_2x-N706-34_Am_Pla_pb1834_v3.5 -> Done
# Chr1_covLow_2x-N706-35_Am_Pla_pb1835_v3.5 -> Done
# Chr1_covLow_2x-N706-36_Am_Pla_pb1838_v3.5 -> Done
# Chr1_covLow_2x-N706-37_Am_Pla_pb1839_v3.5 -> Done
# Chr1_covLow_2x-N706-38_Am_Pla_pb1840_v3.5 -> Done
# Chr1_covLow_2x-N706-39_Am_Pla_pb1941_v3.5 -> Done
# Chr1_covLow_2x-N706-3_Am_Pla_pb0777_v3.5 -> Done
# Chr1_covLow_2x-N706-40_Am_Pla_pb1943_v3.5 -> Done
# Chr1_covLow_2x-N706-41_Am_Pla_pb1945_v3.5 -> Done
# Chr1_covLow_2x-N706-42_Am_Pla_pb1946_v3.5 -> Done
# Chr1_covLow_2x-N706-43_Am_Pla_pb1947_v3.5 -> Done
# Chr1_covLow_2x-N706-44_Am_Pla_pb1948_v3.5 -> Done
# Chr1_covLow_2x-N706-45_Am_Pla_pb1949_v3.5 -> Done
# Chr1_covLow_2x-N706-46_Am_Pla_pb1951_v3.5 -> Done
# Chr1_covLow_2x-N706-47_Am_Pla_pb1954_v3.5 -> Done
# Chr1_covLow_2x-N706-48_Am_Pla_pb1962_v3.5 -> Done
# Chr1_covLow_2x-N706-49_Am_Pla_pb1965_v3.5 -> Done
# Chr1_covLow_2x-N706-4_Am_Pla_pb0778_v3.5 -> Done
# Chr1_covLow_2x-N706-50_Am_Pla_pb2052_v3.5 -> Done
# Chr1_covLow_2x-N706-51_Am_Pla_pb2321_v3.5 -> Done
# Chr1_covLow_2x-N706-52_Am_Pla_pb2327_v3.5 -> Done
# Chr1_covLow_2x-N706-53_Am_Pla_pb2335_v3.5 -> Done
# Chr1_covLow_2x-N706-54_Am_Pla_pb2337_v3.5 -> Done
# Chr1_covLow_2x-N706-55_Am_Pla_pb2340_v3.5 -> Done
# Chr1_covLow_2x-N706-56_Am_Pla_pb2401_v3.5 -> Done
# Chr1_covLow_2x-N706-57_Am_Pla_pb2408_v3.5 -> Done
# Chr1_covLow_2x-N706-58_Am_Pla_pb2412_v3.5 -> Done
# Chr1_covLow_2x-N706-59_Am_Pla_pb2413_v3.5 -> Done
# Chr1_covLow_2x-N706-5_Am_Pla_pb0779_v3.5 -> Done
# Chr1_covLow_2x-N706-60_Am_Pla_pb2466_v3.5 -> Done
# Chr1_covLow_2x-N706-61_Am_Pla_pb2524_v3.5 -> Done
# Chr1_covLow_2x-N706-62_Am_Pla_pb2536_v3.5 -> Done
# Chr1_covLow_2x-N706-63_Am_Pla_pb2539_v3.5 -> Done
# Chr1_covLow_2x-N706-64_Am_Pla_pb2542_v3.5 -> Done
# Chr1_covLow_2x-N706-65_Am_Pla_pb2543_v3.5 -> Done
# Chr1_covLow_2x-N706-66_Am_Pla_pb2547_v3.5 -> Done
# Chr1_covLow_2x-N706-67_Am_Pla_pb2549_v3.5 -> Done
# Chr1_covLow_2x-N706-68_Am_Pla_pb2551_v3.5 -> Done
# Chr1_covLow_2x-N706-69_Am_Pla_pb2552_v3.5 -> Done
# Chr1_covLow_2x-N706-6_Am_Pla_pb0780_v3.5 -> Done
# Chr1_covLow_2x-N706-70_Am_Pla_pb2555_v3.5 -> Done
# Chr1_covLow_2x-N706-71_Am_Pla_pb2556_v3.5 -> Done
# Chr1_covLow_2x-N706-72_Am_Pla_pb2557_v3.5 -> Done
# Chr1_covLow_2x-N706-73_Am_Pla_pb2558_v3.5 -> Done
# Chr1_covLow_2x-N706-74_Am_Pla_pb2559_v3.5 -> Done
# Chr1_covLow_2x-N706-75_Am_Pla_pb2560_v3.5 -> Done
# Chr1_covLow_2x-N706-76_Am_Pla_pb2595_v3.5 -> Done
# Chr1_covLow_2x-N706-77_Am_Pla_pb2750_v3.5 -> Done
# Chr1_covLow_2x-N706-78_Am_Pla_pb2757_v3.5 -> Done
# Chr1_covLow_2x-N706-79_Am_Pla_pb2804_v3.5 -> Done
# Chr1_covLow_2x-N706-7_Am_Pla_pb0782_v3.5 -> Done
# Chr1_covLow_2x-N706-80_Am_Pla_pb2808_v3.5 -> Done
# Chr1_covLow_2x-N706-81_Am_Pla_pb2820_v3.5 -> Done
# Chr1_covLow_2x-N706-82_Am_Pla_pb2862_v3.5 -> Done
# Chr1_covLow_2x-N706-83_Am_Pla_pb2863_v3.5 -> Done
# Chr1_covLow_2x-N706-84_Am_Pla_pb2864_v3.5 -> Done
# Chr1_covLow_2x-N706-85_Am_Pla_pb2865_v3.5 -> Done
# Chr1_covLow_2x-N706-86_Am_Pla_pb2866_v3.5 -> Done
# Chr1_covLow_2x-N706-87_Am_Pla_pb2867_v3.5 -> Done
# Chr1_covLow_2x-N706-88_Am_Pla_pb2868_v3.5 -> Done
# Chr1_covLow_2x-N706-89_Am_Pla_pb2869_v3.5 -> Done
# Chr1_covLow_2x-N706-8_Am_Pla_pb0784_v3.5 -> Done
# Chr1_covLow_2x-N706-90_Am_Pla_pb2871_v3.5 -> Done
# Chr1_covLow_2x-N706-91_Am_Pla_pb2872_v3.5 -> Done
# Chr1_covLow_2x-N706-92_Am_Pla_pb2873_v3.5 -> Done
# Chr1_covLow_2x-N706-93_Am_Pla_pb2874_v3.5 -> Done
# Chr1_covLow_2x-N706-94_Am_Pla_pb2875_v3.5 -> Done
# Chr1_covLow_2x-N706-95_Am_Pla_pb2877_v3.5 -> Done
# Chr1_covLow_2x-N706-9_Am_Pla_pb0785_v3.5 -> Done
# Chr1_covLow_2x-N707-10_Am_Pla_pb2917_v3.5 -> Done
# Chr1_covLow_2x-N707-11_Am_Pla_pb2919_v3.5 -> Done
# Chr1_covLow_2x-N707-12_Am_Pla_pb3343_v3.5 -> Done
# Chr1_covLow_2x-N707-13_Am_Pla_pb3346_v3.5 -> Done
# Chr1_covLow_2x-N707-14_Am_Pla_pb3354_v3.5 -> Done
# Chr1_covLow_2x-N707-15_Am_Pla_pb3355_v3.5 -> Done
# Chr1_covLow_2x-N707-16_Am_Pla_pb3356_v3.5 -> Done
# Chr1_covLow_2x-N707-17_Am_Pla_pb3357_v3.5 -> Done
# Chr1_covLow_2x-N707-18_Am_Pla_pb3405_v3.5 -> Done
# Chr1_covLow_2x-N707-19_Am_Pla_pb3407_v3.5 -> Done
# Chr1_covLow_2x-N707-1_Am_Pla_pb2879_v3.5 -> Done
# Chr1_covLow_2x-N707-20_Am_Pla_pb3408_v3.5 -> Done
# Chr1_covLow_2x-N707-21_Am_Pla_pb3409_v3.5 -> Done
# Chr1_covLow_2x-N707-22_Am_Pla_pb3410_v3.5 -> Done
# Chr1_covLow_2x-N707-23_Am_Pla_pb3411_v3.5 -> Done
# Chr1_covLow_2x-N707-24_Am_Pla_pb3412_v3.5 -> Done
# Chr1_covLow_2x-N707-25_Am_Pla_pb3414_v3.5 -> Done
# Chr1_covLow_2x-N707-26_Am_Pla_pb3415_v3.5 -> Done
# Chr1_covLow_2x-N707-27_Am_Pla_pb3417_v3.5 -> Done
# Chr1_covLow_2x-N707-28_Am_Pla_pb3824_v3.5 -> Done
# Chr1_covLow_2x-N707-29_Am_Pla_pb3826_v3.5 -> Done
# Chr1_covLow_2x-N707-2_Am_Pla_pb2880_v3.5 -> Done
# Chr1_covLow_2x-N707-30_Am_Pla_pb3827_v3.5 -> Done
# Chr1_covLow_2x-N707-31_Am_Pla_pb3828_v3.5 -> Done
# Chr1_covLow_2x-N707-32_Am_Pla_pb3829_v3.5 -> Done
# Chr1_covLow_2x-N707-33_Am_Pla_pb3834_v3.5 -> Done
# Chr1_covLow_2x-N707-34_Am_Pla_pb3836_v3.5 -> Done
# Chr1_covLow_2x-N707-35_Am_Pla_pb3837_v3.5 -> Done
# Chr1_covLow_2x-N707-36_Am_Pla_pb3838_v3.5 -> Done
# Chr1_covLow_2x-N707-37_Am_Pla_pb3839_v3.5 -> Done
# Chr1_covLow_2x-N707-38_Am_Pla_pb3882_v3.5 -> Done
# Chr1_covLow_2x-N707-39_Am_Pla_pb3885_v3.5 -> Done
# Chr1_covLow_2x-N707-3_Am_Pla_pb2906_v3.5 -> Done
# Chr1_covLow_2x-N707-40_Am_Pla_pb3886_v3.5 -> Done
# Chr1_covLow_2x-N707-41_Am_Pla_pb3887_v3.5 -> Done
# Chr1_covLow_2x-N707-42_Am_Pla_pb3888_v3.5 -> Done
# Chr1_covLow_2x-N707-43_Am_Pla_pb3889_v3.5 -> Done
# Chr1_covLow_2x-N707-44_Am_Pla_pb3890_v3.5 -> Done
# Chr1_covLow_2x-N707-45_Am_Pla_pb3891_v3.5 -> Done
# Chr1_covLow_2x-N707-46_Am_Pla_pb3892_v3.5 -> Done
# Chr1_covLow_2x-N707-47_Am_Pla_pb3893_v3.5 -> Done
# Chr1_covLow_2x-N707-48_Am_Pla_pb3894_v3.5 -> Done
# Chr1_covLow_2x-N707-49_Am_Pla_pb3896_v3.5 -> Done
# Chr1_covLow_2x-N707-4_Am_Pla_pb2907_v3.5 -> Done
# Chr1_covLow_2x-N707-50_Am_Pla_pb3897_v3.5 -> Done
# Chr1_covLow_2x-N707-51_Am_Pla_pb3898_v3.5 -> Done
# Chr1_covLow_2x-N707-52_Am_Pla_pb3899_v3.5 -> Done
# Chr1_covLow_2x-N707-53_Am_Pla_pb4084_v3.5 -> Done
# Chr1_covLow_2x-N707-54_Am_Pla_pb4099_v3.5 -> Done
# Chr1_covLow_2x-N707-55_Am_Pla_pb4102_v3.5 -> Done
# Chr1_covLow_2x-N707-56_Am_Pla_pb4104_v3.5 -> Done
# Chr1_covLow_2x-N707-57_Am_Pla_pb4108_v3.5 -> Done
# Chr1_covLow_2x-N707-58_Am_Pla_pb4113_v3.5 -> Done
# Chr1_covLow_2x-N707-59_Am_Pla_pb4116_v3.5 -> Done
# Chr1_covLow_2x-N707-5_Am_Pla_pb2910_v3.5 -> Done
# Chr1_covLow_2x-N707-60_Am_Pla_pb4119_v3.5 -> Done
# Chr1_covLow_2x-N707-61_Am_Pla_pb4284_v3.5 -> Done
# Chr1_covLow_2x-N707-62_Am_Pla_pb4285_v3.5 -> Done
# Chr1_covLow_2x-N707-63_Am_Pla_pb4286_v3.5 -> Done
# Chr1_covLow_2x-N707-64_Am_Pla_pb4289_v3.5 -> Done
# Chr1_covLow_2x-N707-65_Am_Pla_pb4290_v3.5 -> Done
# Chr1_covLow_2x-N707-66_Am_Pla_pb4292_v3.5 -> Done
# Chr1_covLow_2x-N707-67_Am_Pla_pb4293_v3.5 -> Done
# Chr1_covLow_2x-N707-68_Am_Pla_pb4294_v3.5 -> Done
# Chr1_covLow_2x-N707-69_Am_Pla_pb4295_v3.5 -> Done
# Chr1_covLow_2x-N707-6_Am_Pla_pb2911_v3.5 -> Done
# Chr1_covLow_2x-N707-70_Am_Pla_pb4296_v3.5 -> Done
# Chr1_covLow_2x-N707-71_Am_Pla_pb4297_v3.5 -> Done
# Chr1_covLow_2x-N707-72_Am_Pla_pb4298_v3.5 -> Done
# Chr1_covLow_2x-N707-73_Am_Pla_pb4299_v3.5 -> Done
# Chr1_covLow_2x-N707-74_Am_Pla_pb4300_v3.5 -> Done
# Chr1_covLow_2x-N707-75_Am_Pla_pb4301_v3.5 -> Done
# Chr1_covLow_2x-N707-76_Am_Pla_pb4303_v3.5 -> Done
# Chr1_covLow_2x-N707-77_Am_Pla_pb4306_v3.5 -> Done
# Chr1_covLow_2x-N707-78_Am_Pla_pb4308_v3.5 -> Done
# Chr1_covLow_2x-N707-79_Am_Pla_pb4310_v3.5 -> Done
# Chr1_covLow_2x-N707-7_Am_Pla_pb2912_v3.5 -> Done
# Chr1_covLow_2x-N707-80_Am_Pla_pb4311_v3.5 -> Done
# Chr1_covLow_2x-N707-81_Am_Pla_pb4313_v3.5 -> Done
# Chr1_covLow_2x-N707-82_Am_Pla_pb4314_v3.5 -> Done
# Chr1_covLow_2x-N707-83_Am_Pla_pb4315_v3.5 -> Done
# Chr1_covLow_2x-N707-84_Am_Pla_pb4316_v3.5 -> Done
# Chr1_covLow_2x-N707-85_Am_Pla_pb4319_v3.5 -> Done
# Chr1_covLow_2x-N707-86_Am_Pla_pb4323_v3.5 -> Done
# Chr1_covLow_2x-N707-87_Am_Pla_pb4324_v3.5 -> Done
# Chr1_covLow_2x-N707-88_Am_Pla_pb4329_v3.5 -> Done
# Chr1_covLow_2x-N707-89_Am_Pla_pb4330_v3.5 -> Done
# Chr1_covLow_2x-N707-8_Am_Pla_pb2914_v3.5 -> Done
# Chr1_covLow_2x-N707-90_Am_Pla_pb4331_v3.5 -> Done
# Chr1_covLow_2x-N707-91_Am_Pla_pb4561_v3.5 -> Done
# Chr1_covLow_2x-N707-92_Am_Pla_pb4562_v3.5 -> Done
# Chr1_covLow_2x-N707-93_Am_Pla_pb4564_v3.5 -> Done
# Chr1_covLow_2x-N707-9_Am_Pla_pb2916_v3.5 -> Done
# Chr1_covLow_2x-N708-10_Am_Pla_pa0344_v3.5 -> Done
# Chr1_covLow_2x-N708-11_Am_Pla_pa0349_v3.5 -> Done
# Chr1_covLow_2x-N708-12_Am_Pla_pa0350_v3.5 -> Done
# Chr1_covLow_2x-N708-13_Am_Pla_pa0356_v3.5 -> Done
# Chr1_covLow_2x-N708-14_Am_Pla_pa0447_v3.5 -> Done
# Chr1_covLow_2x-N708-15_Am_Pla_pa0448_v3.5 -> Done
# Chr1_covLow_2x-N708-16_Am_Pla_pa0460_v3.5 -> Done
# Chr1_covLow_2x-N708-17_Am_Pla_pa0666_v3.5 -> Done
# Chr1_covLow_2x-N708-18_Am_Pla_pa0760_v3.5 -> Done
# Chr1_covLow_2x-N708-19_Am_Pla_pa0981_v3.5 -> Done
# Chr1_covLow_2x-N708-1_Am_Pla_pa0212_v3.5 -> Done
# Chr1_covLow_2x-N708-20_Am_Pla_pa0986_v3.5 -> Done
# Chr1_covLow_2x-N708-21_Am_Pla_pa0994_v3.5 -> Done
# Chr1_covLow_2x-N708-22_Am_Pla_pa0998_v3.5 -> Done
# Chr1_covLow_2x-N708-23_Am_Pla_pa0999_v3.5 -> Done
# Chr1_covLow_2x-N708-24_Am_Pla_pa1148_v3.5 -> Done
# Chr1_covLow_2x-N708-25_Am_Pla_pa1168_v3.5 -> Done
# Chr1_covLow_2x-N708-26_Am_Pla_pa1179_v3.5 -> Done
# Chr1_covLow_2x-N708-27_Am_Pla_pa1291_v3.5 -> Done
# Chr1_covLow_2x-N708-28_Am_Pla_pa1308_v3.5 -> Done
# Chr1_covLow_2x-N708-29_Am_Pla_pa1321_v3.5 -> Done
# Chr1_covLow_2x-N708-2_Am_Pla_pa0283_v3.5 -> Done
# Chr1_covLow_2x-N708-30_Am_Pla_pa1799_v3.5 -> Done
# Chr1_covLow_2x-N708-31_Am_Pla_pa1849_v3.5 -> Done
# Chr1_covLow_2x-N708-32_Am_Pla_pa1851_v3.5 -> Done
# Chr1_covLow_2x-N708-33_Am_Pla_pa1852_v3.5 -> Done
# Chr1_covLow_2x-N708-34_Am_Pla_pb4565_v3.5 -> Done
# Chr1_covLow_2x-N708-35_Am_Pla_pb4566_v3.5 -> Done
# Chr1_covLow_2x-N708-36_Am_Pla_pb4567_v3.5 -> Done
# Chr1_covLow_2x-N708-37_Am_Pla_pb4568_v3.5 -> Done
# Chr1_covLow_2x-N708-38_Am_Pla_pb4569_v3.5 -> Done
# Chr1_covLow_2x-N708-39_Am_Pla_pb4570_v3.5 -> Done
# Chr1_covLow_2x-N708-3_Am_Pla_pa0291_v3.5 -> Done
# Chr1_covLow_2x-N708-40_Am_Pla_pb4572_v3.5 -> Done
# Chr1_covLow_2x-N708-41_Am_Pla_pb4574_v3.5 -> Done
# Chr1_covLow_2x-N708-42_Am_Pla_pb4575_v3.5 -> Done
# Chr1_covLow_2x-N708-43_Am_Pla_pb4576_v3.5 -> Done
# Chr1_covLow_2x-N708-44_Am_Pla_pb4578_v3.5 -> Done
# Chr1_covLow_2x-N708-45_Am_Pla_pb4579_v3.5 -> Done
# Chr1_covLow_2x-N708-46_Am_Pla_pb4580_v3.5 -> Done
# Chr1_covLow_2x-N708-47_Am_Pla_pb4701_v3.5 -> Done
# Chr1_covLow_2x-N708-48_Am_Pla_pb4702_v3.5 -> Done
# Chr1_covLow_2x-N708-49_Am_Pla_pb4703_v3.5 -> Done
# Chr1_covLow_2x-N708-4_Am_Pla_pa0299_v3.5 -> Done
# Chr1_covLow_2x-N708-50_Am_Pla_pb4704_v3.5 -> Done
# Chr1_covLow_2x-N708-51_Am_Pla_pb4705_v3.5 -> Done
# Chr1_covLow_2x-N708-52_Am_Pla_pb4707_v3.5 -> Done
# Chr1_covLow_2x-N708-53_Am_Pla_pb4714_v3.5 -> Done
# Chr1_covLow_2x-N708-54_Am_Pla_pb4715_v3.5 -> Done
# Chr1_covLow_2x-N708-55_Am_Pla_pb4716_v3.5 -> Done
# Chr1_covLow_2x-N708-56_Am_Pla_pb4717_v3.5 -> Done
# Chr1_covLow_2x-N708-57_Am_Pla_pb4718_v3.5 -> Done
# Chr1_covLow_2x-N708-58_Am_Pla_pb4841_v3.5 -> Done
# Chr1_covLow_2x-N708-59_Am_Pla_pb4842_v3.5 -> Done
# Chr1_covLow_2x-N708-5_Am_Pla_pa0323_v3.5 -> Done
# Chr1_covLow_2x-N708-60_Am_Pla_pb4843_v3.5 -> Done
# Chr1_covLow_2x-N708-61_Am_Pla_pb4844_v3.5 -> Done
# Chr1_covLow_2x-N708-62_Am_Pla_pb4845_v3.5 -> Done
# Chr1_covLow_2x-N708-63_Am_Pla_pb4847_v3.5 -> Done
# Chr1_covLow_2x-N708-64_Am_Pla_pb4848_v3.5 -> Done
# Chr1_covLow_2x-N708-65_Am_Pla_pb4850_v3.5 -> Done
# Chr1_covLow_2x-N708-66_Am_Pla_pb4857_v3.5 -> Done
# Chr1_covLow_2x-N708-67_Am_Pla_pb4858_v3.5 -> Done
# Chr1_covLow_2x-N708-68_Am_Pla_pb4859_v3.5 -> Done
# Chr1_covLow_2x-N708-69_Am_Pla_y1916_v3.5 -> Done
# Chr1_covLow_2x-N708-6_Am_Pla_pa0330_v3.5 -> Done
# Chr1_covLow_2x-N708-70_Am_Pla_y2016_v3.5 -> Done
# Chr1_covLow_2x-N708-71_Am_Pla_y208_v3.5 -> Done
# Chr1_covLow_2x-N708-72_Am_Pla_z0040_v3.5 -> Done
# Chr1_covLow_2x-N708-73_Am_Pla_z0191_v3.5 -> Done
# Chr1_covLow_2x-N708-74_Am_Pla_z0219_v3.5 -> Done
# Chr1_covLow_2x-N708-75_Am_Pla_z0403_v3.5 -> Done
# Chr1_covLow_2x-N708-76_Am_Pla_z0455_v3.5 -> Done
# Chr1_covLow_2x-N708-77_Am_Pla_z0464_v3.5 -> Done
# Chr1_covLow_2x-N708-78_Am_Pla_z0466_v3.5 -> Done
# Chr1_covLow_2x-N708-79_Am_Pla_z0474_v3.5 -> Done
# Chr1_covLow_2x-N708-7_Am_Pla_pa0333_v3.5 -> Done
# Chr1_covLow_2x-N708-80_Am_Pla_z0491_v3.5 -> Done
# Chr1_covLow_2x-N708-81_Am_Pla_z0511_v3.5 -> Done
# Chr1_covLow_2x-N708-82_Am_Pla_z0572_v3.5 -> Done
# Chr1_covLow_2x-N708-83_Am_Pla_z0573_v3.5 -> Done
# Chr1_covLow_2x-N708-84_Am_Pla_z0576_v3.5 -> Done
# Chr1_covLow_2x-N708-85_Am_Pla_z0715_v3.5 -> Done
# Chr1_covLow_2x-N708-86_Am_Pla_z1062_v3.5 -> Done
# Chr1_covLow_2x-N708-87_Am_Pla_z1066_v3.5 -> Done
# Chr1_covLow_2x-N708-88_Am_Pla_z1071_v3.5 -> Done
# Chr1_covLow_2x-N708-89_Am_Pla_z1079_v3.5 -> Done
# Chr1_covLow_2x-N708-8_Am_Pla_pa0341_v3.5 -> Done
# Chr1_covLow_2x-N708-90_Am_Pla_z1259_v3.5 -> Done
# Chr1_covLow_2x-N708-91_Am_Pla_z1621_v3.5 -> Done
# Chr1_covLow_2x-N708-92_Am_Pla_z1765_v3.5 -> Done
# Chr1_covLow_2x-N708-93_Am_Pla_z2100_v3.5 -> Done
# Chr1_covLow_2x-N708-94_Am_Pla_z2108_v3.5 -> Done
# Chr1_covLow_2x-N708-95_Am_Pla_z2983_v3.5 -> Done
# Chr1_covLow_2x-N708-96_Am_Pla_z4584_v3.5 -> Done
# Chr1_covLow_2x-N708-9_Am_Pla_pa0343_v3.5 -> Done
# Chr1_covLow_2x-N709-10_Am_Pla_pa2386_v3.5 -> Done
# Chr1_covLow_2x-N709-11_Am_Pla_pa2389_v3.5 -> Done
# Chr1_covLow_2x-N709-12_Am_Pla_pa2393_v3.5 -> Done
# ...
# Chr8_covLow_2x-N706-87_Am_Pla_pb2867_v3.5 -> Done
# Chr8_covLow_2x-N706-88_Am_Pla_pb2868_v3.5 -> Done
# Chr8_covLow_2x-N706-89_Am_Pla_pb2869_v3.5 -> Done
# Chr8_covLow_2x-N706-8_Am_Pla_pb0784_v3.5 -> Done
# Chr8_covLow_2x-N706-90_Am_Pla_pb2871_v3.5 -> Done
# Chr8_covLow_2x-N706-91_Am_Pla_pb2872_v3.5 -> Done
# Chr8_covLow_2x-N706-92_Am_Pla_pb2873_v3.5 -> Done
# Chr8_covLow_2x-N706-93_Am_Pla_pb2874_v3.5 -> Done
# Chr8_covLow_2x-N706-94_Am_Pla_pb2875_v3.5 -> Done
# Chr8_covLow_2x-N706-95_Am_Pla_pb2877_v3.5 -> Done
# Chr8_covLow_2x-N706-9_Am_Pla_pb0785_v3.5 -> Done
# Chr8_covLow_2x-N707-10_Am_Pla_pb2917_v3.5 -> Done
# Chr8_covLow_2x-N707-11_Am_Pla_pb2919_v3.5 -> Done
# Chr8_covLow_2x-N707-12_Am_Pla_pb3343_v3.5 -> Done
# Chr8_covLow_2x-N707-13_Am_Pla_pb3346_v3.5 -> Done
# Chr8_covLow_2x-N707-14_Am_Pla_pb3354_v3.5 -> Done
# Chr8_covLow_2x-N707-15_Am_Pla_pb3355_v3.5 -> Done
# Chr8_covLow_2x-N707-16_Am_Pla_pb3356_v3.5 -> Done
# Chr8_covLow_2x-N707-17_Am_Pla_pb3357_v3.5 -> Done
# Chr8_covLow_2x-N707-18_Am_Pla_pb3405_v3.5 -> Done
# Chr8_covLow_2x-N707-19_Am_Pla_pb3407_v3.5 -> Done
# Chr8_covLow_2x-N707-1_Am_Pla_pb2879_v3.5 -> Done
# Chr8_covLow_2x-N707-20_Am_Pla_pb3408_v3.5 -> Done
# Chr8_covLow_2x-N707-21_Am_Pla_pb3409_v3.5 -> Done
# Chr8_covLow_2x-N707-22_Am_Pla_pb3410_v3.5 -> Done
# Chr8_covLow_2x-N707-23_Am_Pla_pb3411_v3.5 -> Done
# Chr8_covLow_2x-N707-24_Am_Pla_pb3412_v3.5 -> Done
# Chr8_covLow_2x-N707-25_Am_Pla_pb3414_v3.5 -> Done
# Chr8_covLow_2x-N707-26_Am_Pla_pb3415_v3.5 -> Done
# Chr8_covLow_2x-N707-27_Am_Pla_pb3417_v3.5 -> Done
# Chr8_covLow_2x-N707-28_Am_Pla_pb3824_v3.5 -> Done
# Chr8_covLow_2x-N707-29_Am_Pla_pb3826_v3.5 -> Done
# Chr8_covLow_2x-N707-2_Am_Pla_pb2880_v3.5 -> Done
# Chr8_covLow_2x-N707-30_Am_Pla_pb3827_v3.5 -> Done
# Chr8_covLow_2x-N707-31_Am_Pla_pb3828_v3.5 -> Done
# Chr8_covLow_2x-N707-32_Am_Pla_pb3829_v3.5 -> Done
# Chr8_covLow_2x-N707-33_Am_Pla_pb3834_v3.5 -> Done
# Chr8_covLow_2x-N707-34_Am_Pla_pb3836_v3.5 -> Done
# Chr8_covLow_2x-N707-35_Am_Pla_pb3837_v3.5 -> Done
# Chr8_covLow_2x-N707-36_Am_Pla_pb3838_v3.5 -> Done
# Chr8_covLow_2x-N707-37_Am_Pla_pb3839_v3.5 -> Done
# Chr8_covLow_2x-N707-38_Am_Pla_pb3882_v3.5 -> Done
# Chr8_covLow_2x-N707-39_Am_Pla_pb3885_v3.5 -> Done
# Chr8_covLow_2x-N707-3_Am_Pla_pb2906_v3.5 -> Done
# Chr8_covLow_2x-N707-40_Am_Pla_pb3886_v3.5 -> Done
# Chr8_covLow_2x-N707-41_Am_Pla_pb3887_v3.5 -> Done
# Chr8_covLow_2x-N707-42_Am_Pla_pb3888_v3.5 -> Done
# Chr8_covLow_2x-N707-43_Am_Pla_pb3889_v3.5 -> Done
# Chr8_covLow_2x-N707-44_Am_Pla_pb3890_v3.5 -> Done
# Chr8_covLow_2x-N707-45_Am_Pla_pb3891_v3.5 -> Done
# Chr8_covLow_2x-N707-46_Am_Pla_pb3892_v3.5 -> Done
# Chr8_covLow_2x-N707-47_Am_Pla_pb3893_v3.5 -> Done
# Chr8_covLow_2x-N707-48_Am_Pla_pb3894_v3.5 -> Done
# Chr8_covLow_2x-N707-49_Am_Pla_pb3896_v3.5 -> Done
# Chr8_covLow_2x-N707-4_Am_Pla_pb2907_v3.5 -> Done
# Chr8_covLow_2x-N707-50_Am_Pla_pb3897_v3.5 -> Done
# Chr8_covLow_2x-N707-51_Am_Pla_pb3898_v3.5 -> Done
# Chr8_covLow_2x-N707-52_Am_Pla_pb3899_v3.5 -> Done
# Chr8_covLow_2x-N707-53_Am_Pla_pb4084_v3.5 -> Done
# Chr8_covLow_2x-N707-54_Am_Pla_pb4099_v3.5 -> Done
# Chr8_covLow_2x-N707-55_Am_Pla_pb4102_v3.5 -> Done
# Chr8_covLow_2x-N707-56_Am_Pla_pb4104_v3.5 -> Done
# Chr8_covLow_2x-N707-57_Am_Pla_pb4108_v3.5 -> Done
# Chr8_covLow_2x-N707-58_Am_Pla_pb4113_v3.5 -> Done
# Chr8_covLow_2x-N707-59_Am_Pla_pb4116_v3.5 -> Done
# Chr8_covLow_2x-N707-5_Am_Pla_pb2910_v3.5 -> Done
# Chr8_covLow_2x-N707-60_Am_Pla_pb4119_v3.5 -> Done
# Chr8_covLow_2x-N707-61_Am_Pla_pb4284_v3.5 -> Done
# Chr8_covLow_2x-N707-62_Am_Pla_pb4285_v3.5 -> Done
# Chr8_covLow_2x-N707-63_Am_Pla_pb4286_v3.5 -> Done
# Chr8_covLow_2x-N707-64_Am_Pla_pb4289_v3.5 -> Done
# Chr8_covLow_2x-N707-65_Am_Pla_pb4290_v3.5 -> Done
# Chr8_covLow_2x-N707-66_Am_Pla_pb4292_v3.5 -> Done
# Chr8_covLow_2x-N707-67_Am_Pla_pb4293_v3.5 -> Done
# Chr8_covLow_2x-N707-68_Am_Pla_pb4294_v3.5 -> Done
# Chr8_covLow_2x-N707-69_Am_Pla_pb4295_v3.5 -> Done
# Chr8_covLow_2x-N707-6_Am_Pla_pb2911_v3.5 -> Done
# Chr8_covLow_2x-N707-70_Am_Pla_pb4296_v3.5 -> Done
# Chr8_covLow_2x-N707-71_Am_Pla_pb4297_v3.5 -> Done
# Chr8_covLow_2x-N707-72_Am_Pla_pb4298_v3.5 -> Done
# Chr8_covLow_2x-N707-73_Am_Pla_pb4299_v3.5 -> Done
# Chr8_covLow_2x-N707-74_Am_Pla_pb4300_v3.5 -> Done
# Chr8_covLow_2x-N707-75_Am_Pla_pb4301_v3.5 -> Done
# Chr8_covLow_2x-N707-76_Am_Pla_pb4303_v3.5 -> Done
# Chr8_covLow_2x-N707-77_Am_Pla_pb4306_v3.5 -> Done
# Chr8_covLow_2x-N707-78_Am_Pla_pb4308_v3.5 -> Done
# Chr8_covLow_2x-N707-79_Am_Pla_pb4310_v3.5 -> Done
# Chr8_covLow_2x-N707-7_Am_Pla_pb2912_v3.5 -> Done
# Chr8_covLow_2x-N707-80_Am_Pla_pb4311_v3.5 -> Done
# Chr8_covLow_2x-N707-81_Am_Pla_pb4313_v3.5 -> Done
# Chr8_covLow_2x-N707-82_Am_Pla_pb4314_v3.5 -> Done
# Chr8_covLow_2x-N707-83_Am_Pla_pb4315_v3.5 -> Done
# Chr8_covLow_2x-N707-84_Am_Pla_pb4316_v3.5 -> Done
# Chr8_covLow_2x-N707-85_Am_Pla_pb4319_v3.5 -> Done
# Chr8_covLow_2x-N707-86_Am_Pla_pb4323_v3.5 -> Done
# Chr8_covLow_2x-N707-87_Am_Pla_pb4324_v3.5 -> Done
# Chr8_covLow_2x-N707-88_Am_Pla_pb4329_v3.5 -> Done
# Chr8_covLow_2x-N707-89_Am_Pla_pb4330_v3.5 -> Done
# Chr8_covLow_2x-N707-8_Am_Pla_pb2914_v3.5 -> Done
# Chr8_covLow_2x-N707-90_Am_Pla_pb4331_v3.5 -> Done
# Chr8_covLow_2x-N707-91_Am_Pla_pb4561_v3.5 -> Done
# Chr8_covLow_2x-N707-92_Am_Pla_pb4562_v3.5 -> Done
# Chr8_covLow_2x-N707-93_Am_Pla_pb4564_v3.5 -> Done
# Chr8_covLow_2x-N707-9_Am_Pla_pb2916_v3.5 -> Done
# Chr8_covLow_2x-N708-10_Am_Pla_pa0344_v3.5 -> Done
# Chr8_covLow_2x-N708-11_Am_Pla_pa0349_v3.5 -> Done
# Chr8_covLow_2x-N708-12_Am_Pla_pa0350_v3.5 -> Done
# Chr8_covLow_2x-N708-13_Am_Pla_pa0356_v3.5 -> Done
# Chr8_covLow_2x-N708-14_Am_Pla_pa0447_v3.5 -> Done
# Chr8_covLow_2x-N708-15_Am_Pla_pa0448_v3.5 -> Done
# Chr8_covLow_2x-N708-16_Am_Pla_pa0460_v3.5 -> Done
# Chr8_covLow_2x-N708-17_Am_Pla_pa0666_v3.5 -> Done
# Chr8_covLow_2x-N708-18_Am_Pla_pa0760_v3.5 -> Done
# Chr8_covLow_2x-N708-19_Am_Pla_pa0981_v3.5 -> Done
# Chr8_covLow_2x-N708-1_Am_Pla_pa0212_v3.5 -> Done
# Chr8_covLow_2x-N708-20_Am_Pla_pa0986_v3.5 -> Done
# Chr8_covLow_2x-N708-21_Am_Pla_pa0994_v3.5 -> Done
# Chr8_covLow_2x-N708-22_Am_Pla_pa0998_v3.5 -> Done
# Chr8_covLow_2x-N708-23_Am_Pla_pa0999_v3.5 -> Done
# Chr8_covLow_2x-N708-24_Am_Pla_pa1148_v3.5 -> Done
# Chr8_covLow_2x-N708-25_Am_Pla_pa1168_v3.5 -> Done
# Chr8_covLow_2x-N708-26_Am_Pla_pa1179_v3.5 -> Done
# Chr8_covLow_2x-N708-27_Am_Pla_pa1291_v3.5 -> Done
# Chr8_covLow_2x-N708-28_Am_Pla_pa1308_v3.5 -> Done
# Chr8_covLow_2x-N708-29_Am_Pla_pa1321_v3.5 -> Done
# Chr8_covLow_2x-N708-2_Am_Pla_pa0283_v3.5 -> Done
# Chr8_covLow_2x-N708-30_Am_Pla_pa1799_v3.5 -> Done
# Chr8_covLow_2x-N708-31_Am_Pla_pa1849_v3.5 -> Done
# Chr8_covLow_2x-N708-32_Am_Pla_pa1851_v3.5 -> Done
# Chr8_covLow_2x-N708-33_Am_Pla_pa1852_v3.5 -> Done
# Chr8_covLow_2x-N708-34_Am_Pla_pb4565_v3.5 -> Done
# Chr8_covLow_2x-N708-35_Am_Pla_pb4566_v3.5 -> Done
# Chr8_covLow_2x-N708-36_Am_Pla_pb4567_v3.5 -> Done
# Chr8_covLow_2x-N708-37_Am_Pla_pb4568_v3.5 -> Done
# Chr8_covLow_2x-N708-38_Am_Pla_pb4569_v3.5 -> Done
# Chr8_covLow_2x-N708-39_Am_Pla_pb4570_v3.5 -> Done
# Chr8_covLow_2x-N708-3_Am_Pla_pa0291_v3.5 -> Done
# Chr8_covLow_2x-N708-40_Am_Pla_pb4572_v3.5 -> Done
# Chr8_covLow_2x-N708-41_Am_Pla_pb4574_v3.5 -> Done
# Chr8_covLow_2x-N708-42_Am_Pla_pb4575_v3.5 -> Done
# Chr8_covLow_2x-N708-43_Am_Pla_pb4576_v3.5 -> Done
# Chr8_covLow_2x-N708-44_Am_Pla_pb4578_v3.5 -> Done
# Chr8_covLow_2x-N708-45_Am_Pla_pb4579_v3.5 -> Done
# Chr8_covLow_2x-N708-46_Am_Pla_pb4580_v3.5 -> Done
# Chr8_covLow_2x-N708-47_Am_Pla_pb4701_v3.5 -> Done
# Chr8_covLow_2x-N708-48_Am_Pla_pb4702_v3.5 -> Done
# Chr8_covLow_2x-N708-49_Am_Pla_pb4703_v3.5 -> Done
# Chr8_covLow_2x-N708-4_Am_Pla_pa0299_v3.5 -> Done
# Chr8_covLow_2x-N708-50_Am_Pla_pb4704_v3.5 -> Done
# Chr8_covLow_2x-N708-51_Am_Pla_pb4705_v3.5 -> Done
# Chr8_covLow_2x-N708-52_Am_Pla_pb4707_v3.5 -> Done
# Chr8_covLow_2x-N708-53_Am_Pla_pb4714_v3.5 -> Done
# Chr8_covLow_2x-N708-54_Am_Pla_pb4715_v3.5 -> Done
# Chr8_covLow_2x-N708-55_Am_Pla_pb4716_v3.5 -> Done
# Chr8_covLow_2x-N708-56_Am_Pla_pb4717_v3.5 -> Done
# Chr8_covLow_2x-N708-57_Am_Pla_pb4718_v3.5 -> Done
# Chr8_covLow_2x-N708-58_Am_Pla_pb4841_v3.5 -> Done
# Chr8_covLow_2x-N708-59_Am_Pla_pb4842_v3.5 -> Done
# Chr8_covLow_2x-N708-5_Am_Pla_pa0323_v3.5 -> Done
# Chr8_covLow_2x-N708-60_Am_Pla_pb4843_v3.5 -> Done
# Chr8_covLow_2x-N708-61_Am_Pla_pb4844_v3.5 -> Done
# Chr8_covLow_2x-N708-62_Am_Pla_pb4845_v3.5 -> Done
# Chr8_covLow_2x-N708-63_Am_Pla_pb4847_v3.5 -> Done
# Chr8_covLow_2x-N708-64_Am_Pla_pb4848_v3.5 -> Done
# Chr8_covLow_2x-N708-65_Am_Pla_pb4850_v3.5 -> Done
# Chr8_covLow_2x-N708-66_Am_Pla_pb4857_v3.5 -> Done
# Chr8_covLow_2x-N708-67_Am_Pla_pb4858_v3.5 -> Done
# Chr8_covLow_2x-N708-68_Am_Pla_pb4859_v3.5 -> Done
# Chr8_covLow_2x-N708-69_Am_Pla_y1916_v3.5 -> Done
# Chr8_covLow_2x-N708-6_Am_Pla_pa0330_v3.5 -> Done
# Chr8_covLow_2x-N708-70_Am_Pla_y2016_v3.5 -> Done
# Chr8_covLow_2x-N708-71_Am_Pla_y208_v3.5 -> Done
# Chr8_covLow_2x-N708-72_Am_Pla_z0040_v3.5 -> Done
# Chr8_covLow_2x-N708-73_Am_Pla_z0191_v3.5 -> Done
# Chr8_covLow_2x-N708-74_Am_Pla_z0219_v3.5 -> Done
# Chr8_covLow_2x-N708-75_Am_Pla_z0403_v3.5 -> Done
# Chr8_covLow_2x-N708-76_Am_Pla_z0455_v3.5 -> Done
# Chr8_covLow_2x-N708-77_Am_Pla_z0464_v3.5 -> Done
# Chr8_covLow_2x-N708-78_Am_Pla_z0466_v3.5 -> Done
# Chr8_covLow_2x-N708-79_Am_Pla_z0474_v3.5 -> Done
# Chr8_covLow_2x-N708-7_Am_Pla_pa0333_v3.5 -> Done
# Chr8_covLow_2x-N708-80_Am_Pla_z0491_v3.5 -> Done
# Chr8_covLow_2x-N708-81_Am_Pla_z0511_v3.5 -> Done
# Chr8_covLow_2x-N708-82_Am_Pla_z0572_v3.5 -> Done
# Chr8_covLow_2x-N708-83_Am_Pla_z0573_v3.5 -> Done
# Chr8_covLow_2x-N708-84_Am_Pla_z0576_v3.5 -> Done
# Chr8_covLow_2x-N708-85_Am_Pla_z0715_v3.5 -> Done
# Chr8_covLow_2x-N708-86_Am_Pla_z1062_v3.5 -> Done
# Chr8_covLow_2x-N708-87_Am_Pla_z1066_v3.5 -> Done
# Chr8_covLow_2x-N708-88_Am_Pla_z1071_v3.5 -> Done
# Chr8_covLow_2x-N708-89_Am_Pla_z1079_v3.5 -> Done
# Chr8_covLow_2x-N708-8_Am_Pla_pa0341_v3.5 -> Done
# Chr8_covLow_2x-N708-90_Am_Pla_z1259_v3.5 -> Done
# Chr8_covLow_2x-N708-91_Am_Pla_z1621_v3.5 -> Done
# Chr8_covLow_2x-N708-92_Am_Pla_z1765_v3.5 -> Done
# Chr8_covLow_2x-N708-93_Am_Pla_z2100_v3.5 -> Done
# Chr8_covLow_2x-N708-94_Am_Pla_z2108_v3.5 -> Done
# Chr8_covLow_2x-N708-95_Am_Pla_z2983_v3.5 -> Done
# Chr8_covLow_2x-N708-96_Am_Pla_z4584_v3.5 -> Done
# Chr8_covLow_2x-N708-9_Am_Pla_pa0343_v3.5 -> Done
# Chr8_covLow_2x-N709-10_Am_Pla_pa2386_v3.5 -> Done
# Chr8_covLow_2x-N709-11_Am_Pla_pa2389_v3.5 -> Done
# Chr8_covLow_2x-N709-12_Am_Pla_pa2393_v3.5 -> Done
# Chr8_covLow_2x-N709-13_Am_Pla_pa2395_v3.5 -> Done
# Chr8_covLow_2x-N709-14_Am_Pla_pa2399_v3.5 -> Done
# Chr8_covLow_2x-N709-15_Am_Pla_pa2400_v3.5 -> Done
# Chr8_covLow_2x-N709-16_Am_Pla_pa2417_v3.5 -> Done
# Chr8_covLow_2x-N709-17_Am_Pla_pa2468_v3.5 -> Done
# Chr8_covLow_2x-N709-18_Am_Pla_pa2472_v3.5 -> Done
# Chr8_covLow_2x-N709-19_Am_Pla_pa2477_v3.5 -> Done
# Chr8_covLow_2x-N709-1_Am_Pla_pa1282_v3.5 -> Done
# Chr8_covLow_2x-N709-20_Am_Pla_pa2478_v3.5 -> Done
# Chr8_covLow_2x-N709-21_Am_Pla_pa2483_v3.5 -> Done
# Chr8_covLow_2x-N709-22_Am_Pla_pa2484_v3.5 -> Done
# Chr8_covLow_2x-N709-23_Am_Pla_pa2485_v3.5 -> Done
# Chr8_covLow_2x-N709-24_Am_Pla_pa2486_v3.5 -> Done
# Chr8_covLow_2x-N709-25_Am_Pla_pa2495_v3.5 -> Done
# Chr8_covLow_2x-N709-26_Am_Pla_pa2499_v3.5 -> Done
# Chr8_covLow_2x-N709-27_Am_Pla_pa2514_v3.5 -> Done
# Chr8_covLow_2x-N709-28_Am_Pla_pa2520_v3.5 -> Done
# Chr8_covLow_2x-N709-29_Am_Pla_pa2530_v3.5 -> Done
# Chr8_covLow_2x-N709-2_Am_Pla_pa1854_v3.5 -> Done
# Chr8_covLow_2x-N709-30_Am_Pla_pb0292b_v3.5 -> Done
# Chr8_covLow_2x-N709-31_Am_Pla_pb0296b_v3.5 -> Done
# Chr8_covLow_2x-N709-3_Am_Pla_pa1858_v3.5 -> Done
# Chr8_covLow_2x-N709-44_Am_Pla_pb0934_v3.5 -> Done
# Chr8_covLow_2x-N709-4_Am_Pla_pa1896_v3.5 -> Done
# Chr8_covLow_2x-N709-5_Am_Pla_pa1904_v3.5 -> Done
# Chr8_covLow_2x-N709-6_Am_Pla_pa1912_v3.5 -> Done
# Chr8_covLow_2x-N709-7_Am_Pla_pa1943_v3.5 -> Done
# Chr8_covLow_2x-N709-8_Am_Pla_pa1945_v3.5 -> Done
# Chr8_covLow_2x-N709-9_Am_Pla_pa2382_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x3318_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x3327_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x3333_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x3394_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4101_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4102_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4116_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4128_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4129_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4134_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4137_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4140_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4148_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4149_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4150_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4153_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4155_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4158_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4159_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4161_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4178_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4359_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4392_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4429_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4459_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4463_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4477_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4491_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4570_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4579_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4580_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4585_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4593_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4608_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4624_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4786_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4837_v3.5 -> Done
# Chr8_covLow_n96_Am_Ave_x4867_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0035_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0047_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0050_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0147_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0156_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0169_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0204_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0347_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0550_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0704_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0713_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0837_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0847_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0852_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z0854_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z1403_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z1441_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z1778_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z1802_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2008_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2018_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2020_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2046_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2281_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2283_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2286_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2287_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2290_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2292_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2293_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2294_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2295_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2296_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2298_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2300_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2706_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z2711_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z3021_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z3257_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z3891_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z4710_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z4712_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z4758_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z4783_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z4793_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z4797_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z5444_v3.5 -> Done
# Chr8_covLow_n96_Am_Pla_z5451_v3.5 -> Done
# Chr8_covLow_TRIO-10_Am_Pla_S1803_v3.5 -> Done
# Chr8_covLow_TRIO-11_Am_Pla_S5237_v3.5 -> Done
# Chr8_covLow_TRIO-15_Am_Pla_V0574_v3.5 -> Done
# Chr8_covLow_TRIO-1_Am_GH_406_v3.5 -> Done
# Chr8_covLow_TRIO-1_Am_Pla_L1190_v3.5 -> Done
# Chr8_covLow_TRIO-2_Am_GH_603_v3.5 -> Done
# Chr8_covLow_TRIO-2_Am_Pla_L1293_v3.5 -> Done
# Chr8_covLow_TRIO-3_Am_GH_608_v3.5 -> Done
# Chr8_covLow_TRIO-3_Am_Pla_M0989_v3.5 -> Done
# Chr8_covLow_TRIO-4_Am_Pla_P0192_v3.5 -> Done
# Chr8_covLow_TRIO-5_Am_Pla_P0239_v3.5 -> Done
# Chr8_covLow_TRIO-6_Am_Pla_P0247_v3.5 -> Done
# Chr8_covLow_TRIO-7_Am_GH_D04_v3.5 -> Done
# Chr8_covLow_TRIO-7_Am_Pla_P0278_v3.5 -> Done
# Chr8_covLow_TRIO-8_Am_GH_D05_v3.5 -> Done
# Chr8_covLow_TRIO-8_Am_Pla_P0293_v3.5 -> Done
# Chr8_covLow_TRIO-9_Am_GH_D06_v3.5 -> Done
# Chr8_covLow_TRIO-9_Am_Pla_P0578_v3.5 -> Done

# %% [markdown]
# ## RosEl phaseblocks

# %% [markdown]
# ### Sample1: Chr6_covHigh_60x-1_Am_Pla_pb0464_v3.5

# %%
## Read input
chrom=Chr6
chromStart_buffer=52500000
chromEnd_buffer=53500000
chromStart_RosEl=52775000
chromEnd_RosEl=53150000

sample=Chr6_covHigh_60x-1_Am_Pla_pb0464_v3.5

## Define variables
baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}/indv-molphase
sampleDIR=${baseDIR}/${sample}

## Got to working directory
cd $sampleDIR
pwd

# %%
## gzip and index HET VCF
if [ ! -e *.het.vcf.gz ]; 
then 
    bgzip *.het.vcf; 
fi 

hetVCF=(*.het.vcf.gz)
echo hetVCF: $hetVCF

bcftools tabix -f $hetVCF
# Out:
# hetVCF: Chr6_covHigh_60x-1_Am_Pla_pb0464_v3.5.het.vcf.gz

# %%
# Get no. of total variants
echo "Variants in RosEl+buffer:" `bcftools view -H -r $chrom:${chromStart_buffer}-${chromEnd_buffer} $hetVCF | wc -l`
echo "Variants in RosEl:" `bcftools view -H -r $chrom:${chromStart_RosEl}-${chromEnd_RosEl} $hetVCF | wc -l`

# %% [markdown]
# Variants in RosEl+buffer: 10897
# Variants in RosEl: 3888

# %%
# Get no. of molphased variants

phaseBlockFile=(*.hapcut2.output)
echo $phaseBlockFile

echo "Phased Variants in RosEl+buffer:" \
    `awk -v chromStart_buffer=${chromStart_buffer} \
        -v chromEnd_buffer=${chromEnd_buffer} \
        '$5 > chromStart_buffer && $5 < chromEnd_buffer {count++} END {print count}' $phaseBlockFile`

echo "Phased Variants in RosEl:" \
    `awk -v chromStart_RosEl=${chromStart_RosEl} \
        -v chromEnd_RosEl=${chromEnd_RosEl} \
        '$5 > chromStart_RosEl && $5 < chromEnd_RosEl {count++} END {print count}' $phaseBlockFile`

# %% [markdown]
# Chr6_covHigh_60x-1_Am_Pla_pb0464_v3.5_thres10.hapcut2.output
# Phased Variants in RosEl+buffer: 10700
# Phased Variants in RosEl: 3827

# %%
# Print mol-phaseblocks in RosEl
phaseBlockBED=(*.hapcut2.bed)

cat $phaseBlockBED | \
    awk -v start=${chromStart_RosEl} -v end=${chromEnd_RosEl} \
        '!($3 < start) && !($2 > end)' | \
    sort -k 8nr
# Out:
# Chr6	45167013	55662924	Chr6:45167013-55662924:95857:10495911:618514	350632	101218	95857	10495911	618514
# Chr6	53128522	53132181	Chr6:53128522-53132181:4:3659:77	427813	4	4	3659	77
# Chr6	52938340	52939012	Chr6:52938340-52939012:13:672:170	425877	13	13	672	170
# Chr6	52788415	52788834	Chr6:52788415-52788834:10:419:16	424359	10	10	419	16
# Chr6	53043020	53043318	Chr6:53043020-53043318:3:298:4	426919	3	3	298	4
# Chr6	52787198	52787472	Chr6:52787198-52787472:7:274:29	424352	7	7	274	29
# Chr6	53058632	53058842	Chr6:53058632-53058842:2:210:2	427014	2	2	210	2
# Chr6	53115916	53116076	Chr6:53115916-53116076:2:160:10	427684	2	2	160	10
# Chr6	52876790	52876948	Chr6:52876790-52876948:3:158:77	425378	3	3	158	77
# Chr6	53146728	53146853	Chr6:53146728-53146853:6:125:11	427982	6	6	125	11
# Chr6	53147591	53147715	Chr6:53147591-53147715:3:124:18	427989	3	3	124	18
# Chr6	52792422	52792513	Chr6:52792422-52792513:3:91:6	424392	3	3	91	6
# Chr6	53056194	53056282	Chr6:53056194-53056282:4:88:1	427009	4	4	88	1
# Chr6	52788978	52789061	Chr6:52788978-52789061:7:83:3	424370	7	7	83	3
# Chr6	53055722	53055801	Chr6:53055722-53055801:2:79:2	427002	2	2	79	2
# Chr6	52931044	52931105	Chr6:52931044-52931105:6:61:4	425783	6	6	61	4
# Chr6	52789169	52789217	Chr6:52789169-52789217:2:48:2	424377	2	2	48	2
# Chr6	52834170	52834206	Chr6:52834170-52834206:3:36:1	425047	3	3	36	1
# Chr6	52791886	52791915	Chr6:52791886-52791915:2:29:4	424388	2	2	29	4
# Chr6	52928733	52928761	Chr6:52928733-52928761:2:28:1	425760	2	2	28	1
# Chr6	52963488	52963513	Chr6:52963488-52963513:2:25:16	425956	2	2	25	16
# Chr6	53041279	53041297	Chr6:53041279-53041297:2:18:64	426915	2	2	18	64
# Chr6	52834830	52834841	Chr6:52834830-52834841:3:11:2	425055	3	3	11	2
# Chr6	53127341	53127350	Chr6:53127341-53127350:2:9:30	427810	2	2	9	30
# Chr6	53132606	53132612	Chr6:53132606-53132612:2:6:8	427817	2	2	6	8

# %%
## Print a particular block stats
# Chr6	53128522	53132181	Chr6:53128522-53132181:4:3659:77	427813	4	4	3659	77

phased=4
span=3659
block="SPAN: $span"

echo $block
grep -A $((phased+1)) "$block" *output | awk -v start=${chromStart_RosEl} -v end=${chromEnd_RosEl} '!($5 < start) && !($5 > end) {count++} END {print count}'
grep -A $((phased+1)) "$block" *output | awk -v start=${chromStart_buffer} -v end=${chromEnd_buffer} '!($5 < start) && !($5 > end) {count++} END {print count}'
# Out:
# SPAN: 3659
# 4
# 4

# %%
## Print a particular block stats
# Chr6	45167013	55662924	Chr6:45167013-55662924:95857:10495911:618514	350632	101218	95857	10495911	618514

phased=95857
span=10495911
block="SPAN: $span"

echo $block
grep -A $((phased+1)) "$block" *output | awk -v start=${chromStart_RosEl} -v end=${chromEnd_RosEl} '!($5 < start) && !($5 > end) {count++} END {print count}'
grep -A $((phased+1)) "$block" *output | awk -v start=${chromStart_buffer} -v end=${chromEnd_buffer} '!($5 < start) && !($5 > end) {count++} END {print count}'
# Out:
# SPAN: 10495911
# 3732
# 10374

# %% [markdown]
# ### all Samples

# %%
module load bcftools/1.18

## Read input
chrom=Chr6
chromStart_buffer=52500000
chromEnd_buffer=53500000
chromStart_RosEl=52775000
chromEnd_RosEl=53150000

baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}/indv-molphase
cd $baseDIR

for sample in $baseDIR/*cov*
do
    echo $sample
    cd $sample

    ## Read variables
    phaseBlockBED=(*.hapcut2.bed)
    blockFile=(*.hapcut2.output)

    ## Get phaseBlocks in RosEl region
    awk -v start=${chromStart_RosEl} -v end=${chromEnd_RosEl} '!($3 < start) && !($2 > end)' $phaseBlockBED | \
        sort -k 8nr > ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl.bed}
    # if [ -e ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl.tmp.bed} ]; then rm ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl.tmp.bed}; fi
	
    while read chrom chromStart chromEnd blockName offset len phased span frags;
	do
		block="BLOCK: offset: $offset len: $len phased: $phased SPAN: $span fragments $frags"
		phased_RosEl=`grep -A $((phased+1)) "$block" $blockFile | awk -v start=${chromStart_RosEl} -v end=${chromEnd_RosEl} '!($5 < start) && !($5 > end) {count++} END {print count}'`
		echo -e $chrom"\t"$chromStart"\t"$chromEnd"\t"$blockName"\t"$offset"\t"$len"\t"$phased"\t"$span"\t"$frags"\t"${phased_RosEl} >> ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl.tmp.bed}
	done < ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl.bed}
	mv ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl.tmp.bed} ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl.bed}

    
    ## Get phaseBlocks in RosEl+buffer region
    awk -v start=${chromStart_buffer} -v end=${chromEnd_buffer} '!($3 < start) && !($2 > end)' $phaseBlockBED | \
    	sort -k 8nr > ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl+buffer.bed}
    # if [ -e ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl+buffer.tmp.bed} ]; then rm ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl+buffer.tmp.bed}; fi
	while read chrom chromStart chromEnd blockName offset len phased span frags;
	do
		block="BLOCK: offset: $offset len: $len phased: $phased SPAN: $span fragments $frags"
		phased_buffer=`grep -A $((phased+1)) "$block" $blockFile | awk -v start=${chromStart_buffer} -v end=${chromEnd_buffer} '!($5 < start) && !($5 > end) {count++} END {print count}'`
		echo -e $chrom"\t"$chromStart"\t"$chromEnd"\t"$blockName"\t"$offset"\t"$len"\t"$phased"\t"$span"\t"$frags"\t"${phased_buffer} >> ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl+buffer.tmp.bed}
	done < ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl+buffer.bed}
	mv ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl+buffer.tmp.bed} ${phaseBlockBED/_thres10.hapcut2.bed/_RosEl+buffer.bed}
done

# %% [markdown]
# ### Molphase summary for RosEl region

# %%
module load bcftools/1.18 datamash

## Read input
chrom=Chr6
chromStart_buffer=52500000
chromEnd_buffer=53500000
chromStart_RosEl=52775000
chromEnd_RosEl=53150000

baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}/indv-molphase
cd $baseDIR

summaryRosEl=/nfs/scistore18/bartogrp/apal/snap_hap/variants/molphase/${chrom}/phaseSummary_RosEl.txt
if [ -e $summaryRosEl]; then rm $summaryRosEl; fi
echo -e sample"\t"SNPs_RosEl"\t"phased_RosEl"\t"phased_RosEl_Top5"\t"phased_RosEl_Top3"\t"SNPs_buffer"\t"phased_buffer"\t"phased_buffer_Top5"\t"phased_buffer_Top3 > $summaryRosEl

for sample in $baseDIR/*
do
    echo $sample
    cd $sample
    
	## gzip and index HET VCF
	# if [ ! -e *.het.vcf.gz ]; then bgzip *.het.vcf; fi 
	bgzip -f *het.vcf
    hetVCF=(*.het.vcf.gz)
	echo hetVCF: $hetVCF
	bcftools tabix -f $hetVCF

	## Count SNPs in RosEl 
	SNPs_RosEl=`bcftools view -H -r $chrom:${chromStart_RosEl}-${chromEnd_RosEl} $hetVCF | wc -l`
    ## Count phased SNPs in RosEl 
    blocks_RosEl=(*RosEl.bed)
    phased_RosEl=`sort -k 10nr $blocks_RosEl | datamash sum 10`
    ## Count phased SNPs in RosEl that are covered by the longest phaseBlocks 
    phased_RosEl_Top1=`sort -k 10nr $blocks_RosEl | head -1 | datamash sum 10`
    phased_RosEl_Top3=`sort -k 10nr $blocks_RosEl | head -3 | datamash sum 10`
    phased_RosEl_Top5=`sort -k 10nr $blocks_RosEl | head -5 | datamash sum 10`

    
	## Count SNPs in RosEl+buffer 
	SNPs_buffer=`bcftools view -H -r $chrom:${chromStart_buffer}-${chromEnd_buffer} $hetVCF | wc -l`
	## Count phased SNPs in RosEl+buffer
    blocks_buffer=(*RosEl+buffer.bed)
    phased_buffer=`sort -k 10nr $blocks_buffer | datamash sum 10`
	## Count phased SNPs in RosEl+buffer that are covered by the largest phaseBlocks
    phased_buffer_Top1=`sort -k 10nr $blocks_buffer | head -1 | datamash sum 10`
    phased_buffer_Top3=`sort -k 10nr $blocks_buffer | head -3 | datamash sum 10`
    phased_buffer_Top5=`sort -k 10nr $blocks_buffer | head -5 | datamash sum 10`

    echo -e ${sample}"\t"${SNPs_RosEl}"\t"${phased_RosEl}"\t"${phased_RosEl_Top5}"\t"${phased_RosEl_Top3}"\t"${phased_RosEl_Top1}"\t"${SNPs_buffer}"\t"${phased_buffer}"\t"${phased_buffer_Top5}"\t"${phased_buffer_Top3}"\t"${phased_buffer_Top1} >> $summaryRosEl
done
