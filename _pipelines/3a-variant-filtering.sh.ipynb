# %% [markdown]
# # Variant Filtering

# %% [markdown]
# ### Steps
# 1. Remove monomorphic REF sites <br/>
#    `bcftools view -m2 -Oz -o out.vcf.gz in.vcf.gz`
#     <br/>
#
# 3. Remove INDELs (with SnpGap 0/5/10) <br/>
#    `bcftools filter --SnpGap <INT> in.vcf.gz | bcftools view -V indels -Oz -o out.vcf.gz`
#    <br/>
#
# 5. Remove monomorphic SNPs <br/>
#    `bcftools view -e "AC==AN || AC==0" -Oz -o $outVCF $inVCF`
#    <br/>
#
# 7. Remove multi-allelic SNPs <br/>
#    `bcftools view -m2 -M2 -Oz -o $outVCF $inVCF`
#    <br/>
#
# 9. Filter based on DEPTH, QUALITY, and MQ. <br/>
#    `bcftools filter -e 'INFO/DP<500 | INFO/DP>7732 | QUAL<20 | MQ<30' -Oz -o $outVCF $inVCF`
#    <br/>

# %% [markdown]
# __NB:__ "SNPs" in VCF files incl. all sites that are
# - bi-allelic SNPs, ie. only 1 ALT allele
# - multi-allelic SNPs ie. >1 ALT allele
# - fixed at ALT
#
# <br/>

# %%
## Load modules
module load bcftools vcftools python3

# %% [markdown]
# <br/>
#
# ## Test variant filtering steps

# %%
cd   ~/snap_hap/variants/vcf_bcftools_Am_all/test

## Test VCF
bcftools view -r Chr8:1-10000 -Oz -o ~/snap_hap/variants/vcf_bcftools_Am_all/test/test.vcf.gz \
    ~/snap_hap/variants/vcf_bcftools_Am_all/Chr8/Am_all_bcftools_Chr8.vcf.gz

## Initialize variables
inVCF=/nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all/test/test.vcf.gz 

## Index VCF
bcftools tabix -f $inVCF

## bcftools stats
bcftools stats --threads 10 -s- --af-bins <(seq 0 0.1 1) --depth 0,25000,25 $inVCF > ${inVCF/.vcf.gz/_stats.vchk}
head -31 ${inVCF/.vcf.gz/_stats.vchk}
# Out:
# # This file was produced by bcftools stats (1.16+htslib-1.16) and can be plotted using plot-vcfstats.
# # The command line was:	bcftools stats  --threads 10 -s- --af-bins /dev/fd/63 --depth 0,25000,25 /nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all/test/test.vcf.gz
# #
# # Definition of sets:
# # ID	[2]id	[3]tab-separated file names
# ID	0	/nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all/test/test.vcf.gz
# # SN, Summary numbers:
# #   number of records   .. number of data rows in the VCF
# #   number of no-ALTs   .. reference-only sites, ALT is either "." or identical to REF
# #   number of SNPs      .. number of rows with a SNP
# #   number of MNPs      .. number of rows with a MNP, such as CC>TT
# #   number of indels    .. number of rows with an indel
# #   number of others    .. number of rows with other type, for example a symbolic allele or
# #                          a complex substitution, such as ACT>TCGA
# #   number of multiallelic sites     .. number of rows with multiple alternate alleles
# #   number of multiallelic SNP sites .. number of rows with multiple alternate alleles, all SNPs
# #
# #   Note that rows containing multiple types will be counted multiple times, in each
# #   counter. For example, a row with a SNP and an indel increments both the SNP and
# #   the indel counter.
# #
# # SN	[2]id	[3]key	[4]value
# SN	0	number of samples:	1074
# SN	0	number of records:	10085
# SN	0	number of no-ALTs:	9720
# SN	0	number of SNPs:	326
# SN	0	number of MNPs:	0
# SN	0	number of indels:	39
# SN	0	number of others:	0
# SN	0	number of multiallelic sites:	19
# SN	0	number of multiallelic SNP sites:	16

# %%
cd   ~/snap_hap/variants/vcf_bcftools_Am_all/test

## 1. Remove monomorphic REF sites
inVCF=test.vcf.gz
outVCF=test_allSNPs+allINDELs.vcf.gz
bcftools view --threads 20 -m2 -Oz -o $outVCF $inVCF
bcftools stats --threads 20 -s- --af-bins <(seq 0 0.1 1) --depth 0,25000,25 $outVCF > ${outVCF/.vcf.gz/_stats.vchk}


## 2. Remove INDELs (with SnpGap 0)
inVCF=test_allSNPs+allINDELs.vcf.gz
outVCF=test_SnpGap0_allSNPs.vcf.gz
bcftools view --threads 20 -V indels -Oz -o $outVCF $inVCF
bcftools stats --threads 20 -s- --af-bins <(seq 0 0.1 1) --depth 0,25000,25 $outVCF > ${outVCF/.vcf.gz/_stats.vchk}


## 3. Remove monomorphic SNPs
inVCF=test_SnpGap0_allSNPs.vcf.gz
outVCF=test_SnpGap0_polySNPs.vcf.gz
bcftools view --threads 20 -e AC==AN || AC==0" -Oz -o $outVCF $inVCF
bcftools stats --threads 20 -s- --af-bins <(seq 0 0.1 1) --depth 0,25000,25 $outVCF > ${outVCF/.vcf.gz/_stats.vchk}


## 4. Remove multi-allelic SNPs
inVCF=test_SnpGap0_polySNPs.vcf.gz
outVCF=test_SnpGap0_biSNPs.vcf.gz
bcftools view --threads 20 -m2 -M2 -v snps -Oz -o $outVCF $inVCF
bcftools stats --threads 20 -s- --af-bins <(seq 0 0.1 1) --depth 0,25000,25 $outVCF > ${outVCF/.vcf.gz/_stats.vchk}

# %%
echo -e "Records from the original VCF"

echo Total records = `bcftools view -H test.vcf.gz | wc -l`
echo Fixed REFs = `bcftools view -H -M1 test.vcf.gz | wc -l`
echo without Fixed REFs = `bcftools view -H -m2 test.vcf.gz | wc -l`

echo Fixed ALT indels = `bcftools view -H -v indels -i "AC==AN" test.vcf.gz | wc -l`
echo Fixed ALT snps = `bcftools view -H -v snps -i "AC==AN" test.vcf.gz | wc -l`

echo Multi-allelic sites = `bcftools view -H -m3 -e "AC==AN" test.vcf.gz | wc -l`
echo indels at multi-allelic sites = `bcftools view -H -v indels -m3 -e "AC==AN" test.vcf.gz | wc -l`
echo snps at multi-allelic sites = `bcftools view -H -v snps -m3 -e "AC==AN" test.vcf.gz | wc -l`

echo indels at TRUE bi-allelic sites =  `bcftools view -H -v indels -m2 -M2 -e "AC==AN" test.vcf.gz | wc -l`
echo snps at TRUE biallelic sites = `bcftools view -H -v snps -m2 -M2 -e "AC==AN" test.vcf.gz | wc -l`

echo -e "\n\nRecords from the filtered VCF"
echo Total Records: `bcftools view -H test.vcf.gz | wc -l` 
echo allSNPs + allINDELs: `bcftools view -H test_allSNPs+allINDELs.vcf.gz | wc -l`
echo allSNPs: `bcftools view -H test_SnpGap0_allSNPs.vcf.gz | wc -l`
echo polySNPs: `bcftools view -H test_SnpGap0_polySNPs.vcf.gz | wc -l`
echo biSNPs: `bcftools view -H test_SnpGap0_biSNPs.vcf.gz | wc -l`
# Out:
# Records from the original VCF
# Total records = 10085
# Fixed REFs = 9720
# without Fixed REFs = 365
# Fixed ALT indels = 25
# Fixed ALT snps = 16
# Multi-allelic sites = 19
# indels at multi-allelic sites = 3
# snps at multi-allelic sites = 16
# indels at TRUE bi-allelic sites = 11
# snps at TRUE biallelic sites = 294
#
#
# Records from the filtered VCF
# Total Records: 10085
# allSNPs + allINDELs: 365
# allSNPs: 326
# polySNPs: 310
# biSNPs: 294

# %% [markdown]
# <br/>
# <hr/>
#
# ## Variant Filtering on cluster

# %% [markdown]
# ### Filter1: Remove monomorphic REFs

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/4-variant-filtering
#chr=Chr1
#threads=10

for chr in Chr{1..8}
do
    sbatch -J ${chr}-filter1-removeREFs ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_filter1-removeREFs.sbatch \
        ~/snap_hap/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}.vcf.gz \
        ~/snap_hap/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_allSNPs+allINDELs.vcf.gz \
        $threads
done

## Run bcftools stats
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/3-stats
for inVCF in ~/snap_hap/variants/vcf_bcftools_Am_all/*/Am_all_bcftools_*_allSNPs+allINDELs.vcf.gz
do
    echo $inVCF
    sbatch -J vcf-stats ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_stats.sbatch $inVCF $threads
done

# %% [markdown]
# ```
# #SBATCH --partition=defaultp
# #SBATCH --exclude=zeta[243-262],beta[231-235]
# #SBATCH --time=120:00:00
# #SBATCH --cpus-per-task=1
# #SBATCH --mem-per-cpu=8G
# #SBATCH --ntasks-per-node=1
# #SBATCH --ntasks=1
# ```

# %% [markdown]
# ### Filter2: Remove INDELs (incl. SNPs in vicinity)

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/4-variant-filtering
#chr=Chr1 ## Chr{1..8}
#threads=10 
#SnpGap=10 ## SnpGap: 0,5,10

for chr in Chr{1..8}
do
    for SnpGap in 0 5 10
    do
        echo $chr SnpGap$SnpGap
        sbatch -J ${chr}-filter2-removeINDELs-SnpGap${SnpGap} ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_filter2-removeINDELs.sbatch \
            ~/snap_hap/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_allSNPs+allINDELs.vcf.gz \
            ~/snap_hap/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_SnpGap${SnpGap}_allSNPs.vcf.gz \
            $threads \
            $SnpGap
    done
done

## Run bcftools stats
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/3-stats
for inVCF in ~/snap_hap/variants/vcf_bcftools_Am_all/*/Am_all_bcftools_*_allSNPs.vcf.gz
do
    echo $inVCF
    sbatch -J vcf-stats ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_stats.sbatch $inVCF $threads
done

# %% [markdown]
# ### Filter3: Remove monomoprhic SNPs

# %% [raw]
# cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/4-variant-filtering
# #chr=Chr1
# #threads=10
# #SnpGap=10
#
# for chr in Chr{1..8}
# do
#     for SnpGap in 0 5 10
#     do
#         sbatch -J ${chr}-filter3-removeMonoSNPs ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_filter3-removeMonoSNPs.sbatch \
#         ~/snap_hap/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_SnpGap${SnpGap}_allSNPs.vcf.gz \
#         ~/snap_hap/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_SnpGap${SnpGap}_polySNPs.vcf.gz \
#         $threads
#     done
# done
#
# ## Run bcftools stats
# cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/3-stats
# for inVCF in ~/snap_hap/variants/vcf_bcftools_Am_all/*/Am_all_bcftools_*_polySNPs.vcf.gz
# do
#     echo $inVCF
#     sbatch -J vcf-stats ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_stats.sbatch $inVCF $threads
# done

# %% [markdown]
# ### Filter4: Remove multiallelic SNPs

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/4-variant-filtering
#chr=Chr1
#threads=10
#SnpGap=10

for chr in Chr{1..8}
do
    for SnpGap in 0 5 10
    do 
        echo $chr SnpGap$SnpGap
        sbatch -J ${chr}-filter4-removeMultiSNPs ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_filter4-removeMultiSNPs.sbatch \
            ~/snap_hap/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_SnpGap${SnpGap}_polySNPs.vcf.gz \
            ~/snap_hap/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_SnpGap${SnpGap}_biSNPs.vcf.gz \
            $threads
    done
done


## Run bcftools stats
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/3-stats
threads=10
for inVCF in ~/snap_hap/variants/vcf_bcftools_Am_all/*/Am_all_bcftools_*_biSNPs.vcf.gz
do
    echo $inVCF
    sbatch -J vcf-stats ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_stats.sbatch $inVCF $threads
done


## Run bcftools query to extract params
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/5-extract-params
threads=10
for inVCF in ~/snap_hap/variants/vcf_bcftools_Am_all/*/Am_all_bcftools_*_SnpGap*_biSNPs.vcf.gz
do
    echo $inVCF
    sbatch -J extract-params-biSNPs ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_extract-params.sbatch $inVCF
done

# %% [markdown]
# <br/>
#
# #### Checking filtered variants

# %%
cat ~/snap_hap/variants/vcf_bcftools_Am_all/Chr1/Am_all_bcftools_Chr1_SnpGap5_biSNPs_params.txt | \
    grep -w -e 955185 \
            -e 45535107 \
            -e 47381180 \
            -e 51252783 \
            -e 60537705 \
            -e 71126303
cat ~/snap_hap/variants/vcf_bcftools_Am_all/Chr2/Am_all_bcftools_Chr2_SnpGap5_biSNPs_params.txt |  grep -w -e 55473945 -e 58751341
cat ~/snap_hap/variants/vcf_bcftools_Am_all/Chr3/Am_all_bcftools_Chr3_SnpGap5_biSNPs_params.txt | grep -w -e 1055959 -e 3488331 -e 44197469
cat ~/snap_hap/variants/vcf_bcftools_Am_all/Chr4/Am_all_bcftools_Chr4_SnpGap5_biSNPs_params.txt | grep -w -e 7115521 -e 38397179 -e 44460308 -e 50972302
cat ~/snap_hap/variants/vcf_bcftools_Am_all/Chr6/Am_all_bcftools_Chr6_SnpGap5_biSNPs_params.txt | grep -w -e 15125731 -e 32503688 -e 52921613 -e 52922047 \
    -e 52966811 -e 52999112 -e 53016551 -e 53061080 -e 53083229 -e 53090212 -e 53094790 -e 53104387 -e 53195127 -e 53944185
cat ~/snap_hap/variants/vcf_bcftools_Am_all/Chr7/Am_all_bcftools_Chr7_SnpGap5_biSNPs_params.txt | grep -w -e 49828363
cat ~/snap_hap/variants/vcf_bcftools_Am_all/Chr8/Am_all_bcftools_Chr8_SnpGap5_biSNPs_params.txt | grep -w -e 27807304 -e 31864104 -e 38142268 -e 44933278 -e 53715058
# Out:
# Chr1	955185	C	A	26533.4	2130	853	1246	0	42
# Chr1	45535107	C	A	28863.3	2464	836	1336	0	54
# Chr1	47381180	C	A	16317.9	2576	314	1330	0	52
# Chr1	51252783	A	C	18432.5	2946	388	1364	0	53
# Chr1	60537705	T	C	14255.6	2498	311	1304	0	46
# Chr1	71126303	T	G	34834.4	2830	909	1432	0	54
# Chr2	55473945	A	G	22973.6	2175	445	1324	0	57
# Chr2	58751341	A	G	8338.71	1981	221	1110	0	49
# Chr3	1055959	T	A	25268.3	2470	813	1316	0	41
# Chr3	3488331	C	T	29029.6	2497	845	1350	0	48
# Chr3	44197469	G	C	18392.9	2598	368	1368	0	50
# Chr4	7115521	T	G	32824.4	2682	948	1408	0	48
# Chr4	38397179	T	A	20768.1	1917	471	1214	0	54
# Chr4	44460308	A	G	26240.1	3136	462	1494	0	55
# Chr4	50972302	G	A	30206.3	2642	831	1364	0	53
# Chr6	15125731	A	T	33795.9	2614	965	1440	0	53
# Chr6	32503688	A	G	25119.7	2748	457	1398	0	54
# Chr6	52921613	C	G	18310.3	2466	369	1346	0	55
# Chr6	52922047	G	T	22605	2515	458	1334	0	51
# Chr6	52966811	T	A	12147	1920	313	1208	0	49
# Chr6	52999112	C	T	14710.1	2106	346	1200	0	50
# Chr6	53016551	C	G	18626.9	2535	318	1364	0	57
# Chr6	53061080	A	G	22587.6	2113	482	1258	0	50
# Chr6	53083229	G	A	14730.8	2455	249	1352	0	56
# Chr6	53090212	T	C	27083.1	2081	870	1338	0	55
# Chr6	53094790	C	A	14456.7	2600	239	1396	0	55
# Chr6	53104387	A	C	19319	2586	433	1358	0	53
# Chr6	53195127	C	T	41505.6	2618	1089	1410	0	55
# Chr6	53944185	G	A	11483.1	2610	197	1400	0	52
# Chr7	49828363	T	A	18419.7	3023	426	1434	0	48
# Chr8	27807304	T	G	17404.8	2532	381	1390	0	50
# Chr8	31864104	C	G	41056.8	2686	991	1414	0	56
# Chr8	38142268	C	G	27897.2	2567	546	1376	0	56
# Chr8	44933278	C	T	726.422	1955	26	1242	0	33
# Chr8	53715058	C	T	25028.9	2617	498	1378	0	51

# %% [markdown]
# <br>
#
# ### Filter5: Filter SNPs based on QUAL, DEPTH and MQ

# %% [markdown]
# Only SnpGap5 is retained.
#
#
# The average read depth for all samples (n=1074) is 3.6. So, maximum depth allowed = 3.6x1074x2 = 7732.8
# Theoretically, the total expected depth should be -  (130x2)+(120x1)+(30x6)+(20x12)+(12x152)+(2x787)+(1x48)+(1x38)+(4x15)+(4x13) = 4396
#
# `bcftools filter --threads $threads -e "INFO/DP<500 | INFO/DP>7732 | QUAL<20 | MQ<30" -Oz -o $outVCF $inVCF`

# %% [raw]
# cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/4-variant-filtering
# WORKDIR=~/snap_hap
# threads=10
# SnpGap=5
#
# for chr in Chr{1..8}
# do
#     for SnpGap in 5
#     do
#         echo $chr SnpGap$SnpGap
#         sbatch -J ${chr}-filter5-filterSNPs $WORKDIR/_scripts/sbatch/vcf-utils/job-bcftools_filter5-DP_QUAL_MQ.sbatch \
#             $WORKDIR/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_SnpGap${SnpGap}_biSNPs.vcf.gz \
#             $WORKDIR/variants/vcf_bcftools_Am_all/${chr}/Am_all_bcftools_${chr}_SnpGap${SnpGap}_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz \
#             $threads
#     done
# done
#
#
# ## Run bcftools stats
# cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/bcftools/3-stats
# threads=10
# for inVCF in ~/snap_hap/variants/vcf_bcftools_Am_all/*/Am_all_bcftools_*_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
# do
#     echo $inVCF
#     sbatch -J vcf-stats ~/snap_hap/_scripts/sbatch/vcf-utils/job-bcftools_stats.sbatch $inVCF $threads
# done

# %% [markdown]
# ## No. of SNPs per sample

# %% [raw]
# CHROM	biSNPs	filtered_biSNPs
# LG1     5962580	3781002
# LG2	    6625191	4287044
# LG3	    5547817	3400629
# LG4	    4444178	3059258
# LG5	    6441785	4295411
# LG6	    4716478	3361343
# LG7	    4568689	3079991
# LG8	    5395028	3692065

# %% [markdown]
# ## Extract mpileup genotypes for validation against 30 KASP markers

# %% [markdown]
# ### Chr1

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all
KASPcoords=./KASPcoords.pos

chrom=Chr1
vcf=./${chrom}/Am_all_bcftools_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
outDIR=./validation

for snpID in {1..6}
do
    markerID=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f3)
    pos=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f4)
    outVCF=mpileup-${markerID}-${chrom}-${pos}
    outGT=${markerID#*_}-${chrom}-${pos}
    echo -e "\n"$chrom"\t"$markerID"\t"$pos"\t"$outGT"\n"
    
    ## No Filter
    echo -e '\nNo Filter'
    time bcftools view -r ${chrom}:${pos} -Oz -o $outDIR/$outVCF.noFilter.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.noFilter.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.noFilter.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_noFilter

    ## Softmask FORMAT/DP<6 
    echo -e '\nSoftmask FORMAT/DP<6'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<6" -Oz -o $outDIR/$outVCF.DP6.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP6.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP6.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP6

    ## Softmask FORMAT/DP<10
    echo -e '\nSoftmask FORMAT/DP<10'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<10" -Oz -o $outDIR/$outVCF.DP10.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP10.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP10.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP10

    ## Change longFormat sample names to shortFormat
    echo -e '\nChange longFormat sample names to shortFormat'
    cat $outDIR/${markerID#*_}-${chrom}-${pos}_DP10.012.indv | \
        sed 's/\(10x_\|10x2_\|10xNEW_\|Pla_\|Ave_\|GH_\|60x_\|60x2_\|2x_\)//g; s/\(TRIO-\|n96-\)//g' > $outDIR/${outGT}.shortFormat.indv

    ## Create file with stitch genotypes
    echo -e '\nCreate combined GT file'
    paste $outDIR/${outGT}.shortFormat.indv \
        <(cut -f2 $outDIR/${outGT}_noFilter.012) \
        <(cut -f2 $outDIR/${outGT}_DP6.012) \
        <(cut -f2 $outDIR/${outGT}_DP10.012) > $outDIR/mpileup_$outGT.gt
done
# Out:
# Chr1	1_1	955185	1-Chr1-955185
#
#
# No Filter
#
# real	0m0.108s
# user	0m0.098s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_1-Chr1-955185.noFilter.vcf.gz
# 	--chr Chr1
# 	--to-bp 955187
# 	--012
# 	--out ./validation/1-Chr1-955185_noFilter
# 	--from-bp 955183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.087s
# user	0m0.078s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_1-Chr1-955185.DP6.vcf.gz
# 	--chr Chr1
# 	--to-bp 955187
# 	--012
# 	--out ./validation/1-Chr1-955185_DP6
# 	--from-bp 955183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.108s
# user	0m0.101s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_1-Chr1-955185.DP10.vcf.gz
# 	--chr Chr1
# 	--to-bp 955187
# 	--012
# 	--out ./validation/1-Chr1-955185_DP10
# 	--from-bp 955183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr1	1_2	45535107	2-Chr1-45535107
#
#
# No Filter
#
# real	0m0.053s
# user	0m0.045s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_2-Chr1-45535107.noFilter.vcf.gz
# 	--chr Chr1
# 	--to-bp 45535109
# 	--012
# 	--out ./validation/2-Chr1-45535107_noFilter
# 	--from-bp 45535105
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.051s
# user	0m0.040s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_2-Chr1-45535107.DP6.vcf.gz
# 	--chr Chr1
# 	--to-bp 45535109
# 	--012
# 	--out ./validation/2-Chr1-45535107_DP6
# 	--from-bp 45535105
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.066s
# user	0m0.052s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_2-Chr1-45535107.DP10.vcf.gz
# 	--chr Chr1
# 	--to-bp 45535109
# 	--012
# 	--out ./validation/2-Chr1-45535107_DP10
# 	--from-bp 45535105
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr1	1_3	47381180	3-Chr1-47381180
#
#
# No Filter
#
# real	0m0.116s
# user	0m0.101s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_3-Chr1-47381180.noFilter.vcf.gz
# 	--chr Chr1
# 	--to-bp 47381182
# 	--012
# 	--out ./validation/3-Chr1-47381180_noFilter
# 	--from-bp 47381178
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.113s
# user	0m0.102s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_3-Chr1-47381180.DP6.vcf.gz
# 	--chr Chr1
# 	--to-bp 47381182
# 	--012
# 	--out ./validation/3-Chr1-47381180_DP6
# 	--from-bp 47381178
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.105s
# user	0m0.098s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_3-Chr1-47381180.DP10.vcf.gz
# 	--chr Chr1
# 	--to-bp 47381182
# 	--012
# 	--out ./validation/3-Chr1-47381180_DP10
# 	--from-bp 47381178
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr1	1_4	51252783	4-Chr1-51252783
#
#
# No Filter
#
# real	0m0.028s
# user	0m0.026s
# sys	0m0.000s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_4-Chr1-51252783.noFilter.vcf.gz
# 	--chr Chr1
# 	--to-bp 51252785
# 	--012
# 	--out ./validation/4-Chr1-51252783_noFilter
# 	--from-bp 51252781
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.027s
# user	0m0.018s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_4-Chr1-51252783.DP6.vcf.gz
# 	--chr Chr1
# 	--to-bp 51252785
# 	--012
# 	--out ./validation/4-Chr1-51252783_DP6
# 	--from-bp 51252781
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.053s
# user	0m0.028s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_4-Chr1-51252783.DP10.vcf.gz
# 	--chr Chr1
# 	--to-bp 51252785
# 	--012
# 	--out ./validation/4-Chr1-51252783_DP10
# 	--from-bp 51252781
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr1	1_5	60537705	5-Chr1-60537705
#
#
# No Filter
#
# real	0m0.190s
# user	0m0.169s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_5-Chr1-60537705.noFilter.vcf.gz
# 	--chr Chr1
# 	--to-bp 60537707
# 	--012
# 	--out ./validation/5-Chr1-60537705_noFilter
# 	--from-bp 60537703
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.239s
# user	0m0.227s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_5-Chr1-60537705.DP6.vcf.gz
# 	--chr Chr1
# 	--to-bp 60537707
# 	--012
# 	--out ./validation/5-Chr1-60537705_DP6
# 	--from-bp 60537703
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.239s
# user	0m0.225s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_5-Chr1-60537705.DP10.vcf.gz
# 	--chr Chr1
# 	--to-bp 60537707
# 	--012
# 	--out ./validation/5-Chr1-60537705_DP10
# 	--from-bp 60537703
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr1	1_6	71126303	6-Chr1-71126303
#
#
# No Filter
#
# real	0m0.039s
# user	0m0.026s
# sys	0m0.011s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_6-Chr1-71126303.noFilter.vcf.gz
# 	--chr Chr1
# 	--to-bp 71126305
# 	--012
# 	--out ./validation/6-Chr1-71126303_noFilter
# 	--from-bp 71126301
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.049s
# user	0m0.038s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_6-Chr1-71126303.DP6.vcf.gz
# 	--chr Chr1
# 	--to-bp 71126305
# 	--012
# 	--out ./validation/6-Chr1-71126303_DP6
# 	--from-bp 71126301
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.048s
# user	0m0.037s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-1_6-Chr1-71126303.DP10.vcf.gz
# 	--chr Chr1
# 	--to-bp 71126305
# 	--012
# 	--out ./validation/6-Chr1-71126303_DP10
# 	--from-bp 71126301
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file

# %% [markdown]
# ### Chr2

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all
KASPcoords=./KASPcoords.pos

chrom=Chr2
vcf=./${chrom}/Am_all_bcftools_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
outDIR=./validation

for snpID in {1..2}
do
    markerID=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f3)
    pos=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f4)
    outVCF=mpileup-${markerID}-${chrom}-${pos}
    outGT=${markerID#*_}-${chrom}-${pos}
    echo -e "\n"$chrom"\t"$markerID"\t"$pos"\t"$outGT"\n"
    
    ## No Filter
    echo -e '\nNo Filter'
    time bcftools view -r ${chrom}:${pos} -Oz -o $outDIR/$outVCF.noFilter.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.noFilter.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.noFilter.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_noFilter

    ## Softmask FORMAT/DP<6 
    echo -e '\nSoftmask FORMAT/DP<6'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<6" -Oz -o $outDIR/$outVCF.DP6.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP6.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP6.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP6

    ## Softmask FORMAT/DP<10
    echo -e '\nSoftmask FORMAT/DP<10'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<10" -Oz -o $outDIR/$outVCF.DP10.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP10.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP10.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP10

    ## Change longFormat sample names to shortFormat
    echo -e '\nChange longFormat sample names to shortFormat'
    cat $outDIR/${markerID#*_}-${chrom}-${pos}_DP10.012.indv | \
        sed 's/\(10x_\|10x2_\|10xNEW_\|Pla_\|Ave_\|GH_\|60x_\|60x2_\|2x_\)//g; s/\(TRIO-\|n96-\)//g' > $outDIR/${outGT}.shortFormat.indv

    ## Create file with stitch genotypes
    echo -e '\nCreate combined GT file'
    paste $outDIR/${outGT}.shortFormat.indv \
        <(cut -f2 $outDIR/${outGT}_noFilter.012) \
        <(cut -f2 $outDIR/${outGT}_DP6.012) \
        <(cut -f2 $outDIR/${outGT}_DP10.012) > $outDIR/mpileup_$outGT.gt
done
# Out:
# Chr2	2_1	55473945	1-Chr2-55473945
#
#
# No Filter
#
# real	0m0.088s
# user	0m0.074s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-2_1-Chr2-55473945.noFilter.vcf.gz
# 	--chr Chr2
# 	--to-bp 55473947
# 	--012
# 	--out ./validation/1-Chr2-55473945_noFilter
# 	--from-bp 55473943
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.090s
# user	0m0.080s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-2_1-Chr2-55473945.DP6.vcf.gz
# 	--chr Chr2
# 	--to-bp 55473947
# 	--012
# 	--out ./validation/1-Chr2-55473945_DP6
# 	--from-bp 55473943
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.088s
# user	0m0.078s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-2_1-Chr2-55473945.DP10.vcf.gz
# 	--chr Chr2
# 	--to-bp 55473947
# 	--012
# 	--out ./validation/1-Chr2-55473945_DP10
# 	--from-bp 55473943
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr2	2_2	58751341	2-Chr2-58751341
#
#
# No Filter
#
# real	0m0.178s
# user	0m0.168s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-2_2-Chr2-58751341.noFilter.vcf.gz
# 	--chr Chr2
# 	--to-bp 58751343
# 	--012
# 	--out ./validation/2-Chr2-58751341_noFilter
# 	--from-bp 58751339
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.184s
# user	0m0.168s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-2_2-Chr2-58751341.DP6.vcf.gz
# 	--chr Chr2
# 	--to-bp 58751343
# 	--012
# 	--out ./validation/2-Chr2-58751341_DP6
# 	--from-bp 58751339
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.142s
# user	0m0.131s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-2_2-Chr2-58751341.DP10.vcf.gz
# 	--chr Chr2
# 	--to-bp 58751343
# 	--012
# 	--out ./validation/2-Chr2-58751341_DP10
# 	--from-bp 58751339
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file

# %% [markdown]
# ### Chr3

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all
KASPcoords=./KASPcoords.pos

chrom=Chr3
vcf=./${chrom}/Am_all_bcftools_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
outDIR=./validation

for snpID in {1..3}
do
    markerID=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f3)
    pos=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f4)
    outVCF=mpileup-${markerID}-${chrom}-${pos}
    outGT=${markerID#*_}-${chrom}-${pos}
    echo -e "\n"$chrom"\t"$markerID"\t"$pos"\t"$outGT"\n"
    
    ## No Filter
    echo -e '\nNo Filter'
    time bcftools view -r ${chrom}:${pos} -Oz -o $outDIR/$outVCF.noFilter.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.noFilter.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.noFilter.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_noFilter

    ## Softmask FORMAT/DP<6 
    echo -e '\nSoftmask FORMAT/DP<6'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<6" -Oz -o $outDIR/$outVCF.DP6.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP6.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP6.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP6

    ## Softmask FORMAT/DP<10
    echo -e '\nSoftmask FORMAT/DP<10'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<10" -Oz -o $outDIR/$outVCF.DP10.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP10.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP10.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP10

    ## Change longFormat sample names to shortFormat
    echo -e '\nChange longFormat sample names to shortFormat'
    cat $outDIR/${markerID#*_}-${chrom}-${pos}_DP10.012.indv | \
        sed 's/\(10x_\|10x2_\|10xNEW_\|Pla_\|Ave_\|GH_\|60x_\|60x2_\|2x_\)//g; s/\(TRIO-\|n96-\)//g' > $outDIR/${outGT}.shortFormat.indv

    ## Create file with stitch genotypes
    echo -e '\nCreate combined GT file'
    paste $outDIR/${outGT}.shortFormat.indv \
        <(cut -f2 $outDIR/${outGT}_noFilter.012) \
        <(cut -f2 $outDIR/${outGT}_DP6.012) \
        <(cut -f2 $outDIR/${outGT}_DP10.012) > $outDIR/mpileup_$outGT.gt
done
# Out:
# Chr3	3_1	1055959	1-Chr3-1055959
#
#
# No Filter
#
# real	0m0.097s
# user	0m0.091s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_1-Chr3-1055959.noFilter.vcf.gz
# 	--chr Chr3
# 	--to-bp 1055961
# 	--012
# 	--out ./validation/1-Chr3-1055959_noFilter
# 	--from-bp 1055957
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.088s
# user	0m0.082s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_1-Chr3-1055959.DP6.vcf.gz
# 	--chr Chr3
# 	--to-bp 1055961
# 	--012
# 	--out ./validation/1-Chr3-1055959_DP6
# 	--from-bp 1055957
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.088s
# user	0m0.078s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_1-Chr3-1055959.DP10.vcf.gz
# 	--chr Chr3
# 	--to-bp 1055961
# 	--012
# 	--out ./validation/1-Chr3-1055959_DP10
# 	--from-bp 1055957
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr3	3_2	3488331	2-Chr3-3488331
#
#
# No Filter
#
# real	0m0.186s
# user	0m0.175s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_2-Chr3-3488331.noFilter.vcf.gz
# 	--chr Chr3
# 	--to-bp 3488333
# 	--012
# 	--out ./validation/2-Chr3-3488331_noFilter
# 	--from-bp 3488329
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.184s
# user	0m0.178s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_2-Chr3-3488331.DP6.vcf.gz
# 	--chr Chr3
# 	--to-bp 3488333
# 	--012
# 	--out ./validation/2-Chr3-3488331_DP6
# 	--from-bp 3488329
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.229s
# user	0m0.210s
# sys	0m0.017s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_2-Chr3-3488331.DP10.vcf.gz
# 	--chr Chr3
# 	--to-bp 3488333
# 	--012
# 	--out ./validation/2-Chr3-3488331_DP10
# 	--from-bp 3488329
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr3	3_3	44197469	3-Chr3-44197469
#
#
# No Filter
#
# real	0m0.172s
# user	0m0.144s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_3-Chr3-44197469.noFilter.vcf.gz
# 	--chr Chr3
# 	--to-bp 44197471
# 	--012
# 	--out ./validation/3-Chr3-44197469_noFilter
# 	--from-bp 44197467
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.163s
# user	0m0.137s
# sys	0m0.024s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_3-Chr3-44197469.DP6.vcf.gz
# 	--chr Chr3
# 	--to-bp 44197471
# 	--012
# 	--out ./validation/3-Chr3-44197469_DP6
# 	--from-bp 44197467
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.157s
# user	0m0.142s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-3_3-Chr3-44197469.DP10.vcf.gz
# 	--chr Chr3
# 	--to-bp 44197471
# 	--012
# 	--out ./validation/3-Chr3-44197469_DP10
# 	--from-bp 44197467
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file

# %% [markdown]
# ### Chr4

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all
KASPcoords=./KASPcoords.pos

chrom=Chr4
vcf=./${chrom}/Am_all_bcftools_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
outDIR=./validation

for snpID in {1..3}
do
    markerID=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f3)
    pos=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f4)
    outVCF=mpileup-${markerID}-${chrom}-${pos}
    outGT=${markerID#*_}-${chrom}-${pos}
    echo -e "\n"$chrom"\t"$markerID"\t"$pos"\t"$outGT"\n"
    
    ## No Filter
    echo -e '\nNo Filter'
    time bcftools view -r ${chrom}:${pos} -Oz -o $outDIR/$outVCF.noFilter.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.noFilter.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.noFilter.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_noFilter

    ## Softmask FORMAT/DP<6 
    echo -e '\nSoftmask FORMAT/DP<6'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<6" -Oz -o $outDIR/$outVCF.DP6.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP6.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP6.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP6

    ## Softmask FORMAT/DP<10
    echo -e '\nSoftmask FORMAT/DP<10'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<10" -Oz -o $outDIR/$outVCF.DP10.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP10.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP10.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP10

    ## Change longFormat sample names to shortFormat
    echo -e '\nChange longFormat sample names to shortFormat'
    cat $outDIR/${markerID#*_}-${chrom}-${pos}_DP10.012.indv | \
        sed 's/\(10x_\|10x2_\|10xNEW_\|Pla_\|Ave_\|GH_\|60x_\|60x2_\|2x_\)//g; s/\(TRIO-\|n96-\)//g' > $outDIR/${outGT}.shortFormat.indv

    ## Create file with stitch genotypes
    echo -e '\nCreate combined GT file'
    paste $outDIR/${outGT}.shortFormat.indv \
        <(cut -f2 $outDIR/${outGT}_noFilter.012) \
        <(cut -f2 $outDIR/${outGT}_DP6.012) \
        <(cut -f2 $outDIR/${outGT}_DP10.012) > $outDIR/mpileup_$outGT.gt
done
# Out:
# Chr4	4_1	7115521	1-Chr4-7115521
#
#
# No Filter
#
# real	0m0.061s
# user	0m0.055s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_1-Chr4-7115521.noFilter.vcf.gz
# 	--chr Chr4
# 	--to-bp 7115523
# 	--012
# 	--out ./validation/1-Chr4-7115521_noFilter
# 	--from-bp 7115519
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.061s
# user	0m0.048s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_1-Chr4-7115521.DP6.vcf.gz
# 	--chr Chr4
# 	--to-bp 7115523
# 	--012
# 	--out ./validation/1-Chr4-7115521_DP6
# 	--from-bp 7115519
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.060s
# user	0m0.041s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_1-Chr4-7115521.DP10.vcf.gz
# 	--chr Chr4
# 	--to-bp 7115523
# 	--012
# 	--out ./validation/1-Chr4-7115521_DP10
# 	--from-bp 7115519
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr4	4_3	44460308	3-Chr4-44460308
#
#
# No Filter
#
# real	0m0.145s
# user	0m0.131s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_3-Chr4-44460308.noFilter.vcf.gz
# 	--chr Chr4
# 	--to-bp 44460310
# 	--012
# 	--out ./validation/3-Chr4-44460308_noFilter
# 	--from-bp 44460306
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.112s
# user	0m0.109s
# sys	0m0.000s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_3-Chr4-44460308.DP6.vcf.gz
# 	--chr Chr4
# 	--to-bp 44460310
# 	--012
# 	--out ./validation/3-Chr4-44460308_DP6
# 	--from-bp 44460306
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.145s
# user	0m0.138s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_3-Chr4-44460308.DP10.vcf.gz
# 	--chr Chr4
# 	--to-bp 44460310
# 	--012
# 	--out ./validation/3-Chr4-44460308_DP10
# 	--from-bp 44460306
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr4	4_4	50972302	4-Chr4-50972302
#
#
# No Filter
#
# real	0m0.036s
# user	0m0.026s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_4-Chr4-50972302.noFilter.vcf.gz
# 	--chr Chr4
# 	--to-bp 50972304
# 	--012
# 	--out ./validation/4-Chr4-50972302_noFilter
# 	--from-bp 50972300
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.037s
# user	0m0.023s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_4-Chr4-50972302.DP6.vcf.gz
# 	--chr Chr4
# 	--to-bp 50972304
# 	--012
# 	--out ./validation/4-Chr4-50972302_DP6
# 	--from-bp 50972300
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.034s
# user	0m0.027s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-4_4-Chr4-50972302.DP10.vcf.gz
# 	--chr Chr4
# 	--to-bp 50972304
# 	--012
# 	--out ./validation/4-Chr4-50972302_DP10
# 	--from-bp 50972300
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file

# %% [markdown]
# ### Chr6

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all
KASPcoords=./KASPcoords.pos

chrom=Chr6
vcf=./${chrom}/Am_all_bcftools_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
outDIR=./validation

for snpID in {1..13}
do
    markerID=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f3)
    pos=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f4)
    outVCF=mpileup-${markerID}-${chrom}-${pos}
    outGT=${markerID#*_}-${chrom}-${pos}
    echo -e "\n"$chrom"\t"$markerID"\t"$pos"\t"$outGT"\n"
    
    ## No Filter
    echo -e '\nNo Filter'
    time bcftools view -r ${chrom}:${pos} -Oz -o $outDIR/$outVCF.noFilter.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.noFilter.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.noFilter.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_noFilter

    ## Softmask FORMAT/DP<6 
    echo -e '\nSoftmask FORMAT/DP<6'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<6" -Oz -o $outDIR/$outVCF.DP6.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP6.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP6.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP6

    ## Softmask FORMAT/DP<10
    echo -e '\nSoftmask FORMAT/DP<10'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<10" -Oz -o $outDIR/$outVCF.DP10.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP10.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP10.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP10

    ## Change longFormat sample names to shortFormat
    echo -e '\nChange longFormat sample names to shortFormat'
    cat $outDIR/${markerID#*_}-${chrom}-${pos}_DP10.012.indv | \
        sed 's/\(10x_\|10x2_\|10xNEW_\|Pla_\|Ave_\|GH_\|60x_\|60x2_\|2x_\)//g; s/\(TRIO-\|n96-\)//g' > $outDIR/${outGT}.shortFormat.indv

    ## Create file with stitch genotypes
    echo -e '\nCreate combined GT file'
    paste $outDIR/${outGT}.shortFormat.indv \
        <(cut -f2 $outDIR/${outGT}_noFilter.012) \
        <(cut -f2 $outDIR/${outGT}_DP6.012) \
        <(cut -f2 $outDIR/${outGT}_DP10.012) > $outDIR/mpileup_$outGT.gt
done
# Out:
# Chr6	6_1	15125731	1-Chr6-15125731
#
#
# No Filter
#
# real	0m0.043s
# user	0m0.039s
# sys	0m0.000s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_1-Chr6-15125731.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 15125733
# 	--012
# 	--out ./validation/1-Chr6-15125731_noFilter
# 	--from-bp 15125729
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.050s
# user	0m0.031s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_1-Chr6-15125731.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 15125733
# 	--012
# 	--out ./validation/1-Chr6-15125731_DP6
# 	--from-bp 15125729
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.046s
# user	0m0.021s
# sys	0m0.022s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_1-Chr6-15125731.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 15125733
# 	--012
# 	--out ./validation/1-Chr6-15125731_DP10
# 	--from-bp 15125729
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_2	32503688	2-Chr6-32503688
#
#
# No Filter
#
# real	0m0.087s
# user	0m0.076s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_2-Chr6-32503688.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 32503690
# 	--012
# 	--out ./validation/2-Chr6-32503688_noFilter
# 	--from-bp 32503686
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.086s
# user	0m0.072s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_2-Chr6-32503688.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 32503690
# 	--012
# 	--out ./validation/2-Chr6-32503688_DP6
# 	--from-bp 32503686
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.084s
# user	0m0.074s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_2-Chr6-32503688.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 32503690
# 	--012
# 	--out ./validation/2-Chr6-32503688_DP10
# 	--from-bp 32503686
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_4	52922047	4-Chr6-52922047
#
#
# No Filter
#
# real	0m0.040s
# user	0m0.031s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_4-Chr6-52922047.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 52922049
# 	--012
# 	--out ./validation/4-Chr6-52922047_noFilter
# 	--from-bp 52922045
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.038s
# user	0m0.024s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_4-Chr6-52922047.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 52922049
# 	--012
# 	--out ./validation/4-Chr6-52922047_DP6
# 	--from-bp 52922045
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.040s
# user	0m0.025s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_4-Chr6-52922047.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 52922049
# 	--012
# 	--out ./validation/4-Chr6-52922047_DP10
# 	--from-bp 52922045
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_5	52966811	5-Chr6-52966811
#
#
# No Filter
#
# real	0m0.125s
# user	0m0.119s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_5-Chr6-52966811.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 52966813
# 	--012
# 	--out ./validation/5-Chr6-52966811_noFilter
# 	--from-bp 52966809
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.109s
# user	0m0.094s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_5-Chr6-52966811.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 52966813
# 	--012
# 	--out ./validation/5-Chr6-52966811_DP6
# 	--from-bp 52966809
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.129s
# user	0m0.115s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_5-Chr6-52966811.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 52966813
# 	--012
# 	--out ./validation/5-Chr6-52966811_DP10
# 	--from-bp 52966809
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_6	52999112	6-Chr6-52999112
#
#
# No Filter
#
# real	0m0.239s
# user	0m0.223s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_6-Chr6-52999112.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 52999114
# 	--012
# 	--out ./validation/6-Chr6-52999112_noFilter
# 	--from-bp 52999110
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.182s
# user	0m0.175s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_6-Chr6-52999112.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 52999114
# 	--012
# 	--out ./validation/6-Chr6-52999112_DP6
# 	--from-bp 52999110
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.184s
# user	0m0.177s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_6-Chr6-52999112.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 52999114
# 	--012
# 	--out ./validation/6-Chr6-52999112_DP10
# 	--from-bp 52999110
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_7	53016551	7-Chr6-53016551
#
#
# No Filter
#
# real	0m0.179s
# user	0m0.168s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_7-Chr6-53016551.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 53016553
# 	--012
# 	--out ./validation/7-Chr6-53016551_noFilter
# 	--from-bp 53016549
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.227s
# user	0m0.225s
# sys	0m0.001s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_7-Chr6-53016551.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 53016553
# 	--012
# 	--out ./validation/7-Chr6-53016551_DP6
# 	--from-bp 53016549
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.228s
# user	0m0.213s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_7-Chr6-53016551.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 53016553
# 	--012
# 	--out ./validation/7-Chr6-53016551_DP10
# 	--from-bp 53016549
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_8	53061080	8-Chr6-53061080
#
#
# No Filter
#
# real	0m0.096s
# user	0m0.083s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_8-Chr6-53061080.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 53061082
# 	--012
# 	--out ./validation/8-Chr6-53061080_noFilter
# 	--from-bp 53061078
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.114s
# user	0m0.096s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_8-Chr6-53061080.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 53061082
# 	--012
# 	--out ./validation/8-Chr6-53061080_DP6
# 	--from-bp 53061078
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.110s
# user	0m0.100s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_8-Chr6-53061080.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 53061082
# 	--012
# 	--out ./validation/8-Chr6-53061080_DP10
# 	--from-bp 53061078
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_9	53083229	9-Chr6-53083229
#
#
# No Filter
#
# real	0m0.184s
# user	0m0.181s
# sys	0m0.000s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_9-Chr6-53083229.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 53083231
# 	--012
# 	--out ./validation/9-Chr6-53083229_noFilter
# 	--from-bp 53083227
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.183s
# user	0m0.169s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_9-Chr6-53083229.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 53083231
# 	--012
# 	--out ./validation/9-Chr6-53083229_DP6
# 	--from-bp 53083227
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.197s
# user	0m0.167s
# sys	0m0.016s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_9-Chr6-53083229.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 53083231
# 	--012
# 	--out ./validation/9-Chr6-53083229_DP10
# 	--from-bp 53083227
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_10	53090212	10-Chr6-53090212
#
#
# No Filter
#
# real	0m0.092s
# user	0m0.082s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_10-Chr6-53090212.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 53090214
# 	--012
# 	--out ./validation/10-Chr6-53090212_noFilter
# 	--from-bp 53090210
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.090s
# user	0m0.083s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_10-Chr6-53090212.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 53090214
# 	--012
# 	--out ./validation/10-Chr6-53090212_DP6
# 	--from-bp 53090210
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.093s
# user	0m0.083s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_10-Chr6-53090212.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 53090214
# 	--012
# 	--out ./validation/10-Chr6-53090212_DP10
# 	--from-bp 53090210
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_11	53094790	11-Chr6-53094790
#
#
# No Filter
#
# real	0m0.150s
# user	0m0.144s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_11-Chr6-53094790.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 53094792
# 	--012
# 	--out ./validation/11-Chr6-53094790_noFilter
# 	--from-bp 53094788
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.154s
# user	0m0.151s
# sys	0m0.001s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_11-Chr6-53094790.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 53094792
# 	--012
# 	--out ./validation/11-Chr6-53094790_DP6
# 	--from-bp 53094788
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.152s
# user	0m0.145s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_11-Chr6-53094790.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 53094792
# 	--012
# 	--out ./validation/11-Chr6-53094790_DP10
# 	--from-bp 53094788
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_12	53104387	12-Chr6-53104387
#
#
# No Filter
#
# real	0m0.064s
# user	0m0.058s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_12-Chr6-53104387.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 53104389
# 	--012
# 	--out ./validation/12-Chr6-53104387_noFilter
# 	--from-bp 53104385
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.078s
# user	0m0.068s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_12-Chr6-53104387.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 53104389
# 	--012
# 	--out ./validation/12-Chr6-53104387_DP6
# 	--from-bp 53104385
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.080s
# user	0m0.074s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_12-Chr6-53104387.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 53104389
# 	--012
# 	--out ./validation/12-Chr6-53104387_DP10
# 	--from-bp 53104385
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_13	53195127	13-Chr6-53195127
#
#
# No Filter
#
# real	0m0.174s
# user	0m0.160s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_13-Chr6-53195127.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 53195129
# 	--012
# 	--out ./validation/13-Chr6-53195127_noFilter
# 	--from-bp 53195125
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.171s
# user	0m0.161s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_13-Chr6-53195127.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 53195129
# 	--012
# 	--out ./validation/13-Chr6-53195127_DP6
# 	--from-bp 53195125
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.174s
# user	0m0.152s
# sys	0m0.020s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_13-Chr6-53195127.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 53195129
# 	--012
# 	--out ./validation/13-Chr6-53195127_DP10
# 	--from-bp 53195125
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr6	6_14	53944185	14-Chr6-53944185
#
#
# No Filter
#
# real	0m0.144s
# user	0m0.133s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_14-Chr6-53944185.noFilter.vcf.gz
# 	--chr Chr6
# 	--to-bp 53944187
# 	--012
# 	--out ./validation/14-Chr6-53944185_noFilter
# 	--from-bp 53944183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.155s
# user	0m0.129s
# sys	0m0.012s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_14-Chr6-53944185.DP6.vcf.gz
# 	--chr Chr6
# 	--to-bp 53944187
# 	--012
# 	--out ./validation/14-Chr6-53944185_DP6
# 	--from-bp 53944183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.145s
# user	0m0.130s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-6_14-Chr6-53944185.DP10.vcf.gz
# 	--chr Chr6
# 	--to-bp 53944187
# 	--012
# 	--out ./validation/14-Chr6-53944185_DP10
# 	--from-bp 53944183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file

# %% [markdown]
# ### Chr7

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all
KASPcoords=./KASPcoords.pos

chrom=Chr7
vcf=./${chrom}/Am_all_bcftools_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
outDIR=./validation

for snpID in 1
do
    markerID=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f3)
    pos=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f4)
    outVCF=mpileup-${markerID}-${chrom}-${pos}
    outGT=${markerID#*_}-${chrom}-${pos}
    echo -e "\n"$chrom"\t"$markerID"\t"$pos"\t"$outGT"\n"
    
    ## No Filter
    echo -e '\nNo Filter'
    time bcftools view -r ${chrom}:${pos} -Oz -o $outDIR/$outVCF.noFilter.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.noFilter.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.noFilter.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_noFilter

    ## Softmask FORMAT/DP<6 
    echo -e '\nSoftmask FORMAT/DP<6'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<6" -Oz -o $outDIR/$outVCF.DP6.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP6.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP6.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP6

    ## Softmask FORMAT/DP<10
    echo -e '\nSoftmask FORMAT/DP<10'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<10" -Oz -o $outDIR/$outVCF.DP10.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP10.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP10.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP10

    ## Change longFormat sample names to shortFormat
    echo -e '\nChange longFormat sample names to shortFormat'
    cat $outDIR/${markerID#*_}-${chrom}-${pos}_DP10.012.indv | \
        sed 's/\(10x_\|10x2_\|10xNEW_\|Pla_\|Ave_\|GH_\|60x_\|60x2_\|2x_\)//g; s/\(TRIO-\|n96-\)//g' > $outDIR/${outGT}.shortFormat.indv

    ## Create file with stitch genotypes
    echo -e '\nCreate combined GT file'
    paste $outDIR/${outGT}.shortFormat.indv \
        <(cut -f2 $outDIR/${outGT}_noFilter.012) \
        <(cut -f2 $outDIR/${outGT}_DP6.012) \
        <(cut -f2 $outDIR/${outGT}_DP10.012) > $outDIR/mpileup_$outGT.gt
done
# Out:
# Chr7	7_1	49828363	1-Chr7-49828363
#
#
# No Filter
#
# real	0m0.107s
# user	0m0.083s
# sys	0m0.013s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-7_1-Chr7-49828363.noFilter.vcf.gz
# 	--chr Chr7
# 	--to-bp 49828365
# 	--012
# 	--out ./validation/1-Chr7-49828363_noFilter
# 	--from-bp 49828361
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.085s
# user	0m0.075s
# sys	0m0.009s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-7_1-Chr7-49828363.DP6.vcf.gz
# 	--chr Chr7
# 	--to-bp 49828365
# 	--012
# 	--out ./validation/1-Chr7-49828363_DP6
# 	--from-bp 49828361
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.108s
# user	0m0.098s
# sys	0m0.008s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-7_1-Chr7-49828363.DP10.vcf.gz
# 	--chr Chr7
# 	--to-bp 49828365
# 	--012
# 	--out ./validation/1-Chr7-49828363_DP10
# 	--from-bp 49828361
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file

# %% [markdown]
# ### Chr8

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/vcf_bcftools_Am_all
KASPcoords=./KASPcoords.pos

chrom=Chr8
vcf=./${chrom}/Am_all_bcftools_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
outDIR=./validation

for snpID in {1..2}
do
    markerID=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f3)
    pos=$(grep -w $chrom $KASPcoords | sed -n "${snpID}p" | cut -f4)
    outVCF=mpileup-${markerID}-${chrom}-${pos}
    outGT=${markerID#*_}-${chrom}-${pos}
    echo -e "\n"$chrom"\t"$markerID"\t"$pos"\t"$outGT"\n"
    
    ## No Filter
    echo -e '\nNo Filter'
    time bcftools view -r ${chrom}:${pos} -Oz -o $outDIR/$outVCF.noFilter.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.noFilter.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.noFilter.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_noFilter

    ## Softmask FORMAT/DP<6 
    echo -e '\nSoftmask FORMAT/DP<6'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<6" -Oz -o $outDIR/$outVCF.DP6.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP6.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP6.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP6

    ## Softmask FORMAT/DP<10
    echo -e '\nSoftmask FORMAT/DP<10'
    time bcftools filter -r ${chrom}:${pos} -S . -e "FMT/DP<10" -Oz -o $outDIR/$outVCF.DP10.vcf.gz $vcf
    bcftools tabix -f $outDIR/$outVCF.DP10.vcf.gz
    vcftools --gzvcf $outDIR/$outVCF.DP10.vcf.gz --chr $chrom --from-bp $((pos-2)) --to-bp $((pos+2)) --012 --out $outDIR/${outGT}_DP10

    ## Change longFormat sample names to shortFormat
    echo -e '\nChange longFormat sample names to shortFormat'
    cat $outDIR/${markerID#*_}-${chrom}-${pos}_DP10.012.indv | \
        sed 's/\(10x_\|10x2_\|10xNEW_\|Pla_\|Ave_\|GH_\|60x_\|60x2_\|2x_\)//g; s/\(TRIO-\|n96-\)//g' > $outDIR/${outGT}.shortFormat.indv

    ## Create file with stitch genotypes
    echo -e '\nCreate combined GT file'
    paste $outDIR/${outGT}.shortFormat.indv \
        <(cut -f2 $outDIR/${outGT}_noFilter.012) \
        <(cut -f2 $outDIR/${outGT}_DP6.012) \
        <(cut -f2 $outDIR/${outGT}_DP10.012) > $outDIR/mpileup_$outGT.gt
done
# Out:
# Chr8	8_1	27807304	1-Chr8-27807304
#
#
# No Filter
#
# real	0m0.048s
# user	0m0.043s
# sys	0m0.004s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-8_1-Chr8-27807304.noFilter.vcf.gz
# 	--chr Chr8
# 	--to-bp 27807306
# 	--012
# 	--out ./validation/1-Chr8-27807304_noFilter
# 	--from-bp 27807302
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.052s
# user	0m0.046s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-8_1-Chr8-27807304.DP6.vcf.gz
# 	--chr Chr8
# 	--to-bp 27807306
# 	--012
# 	--out ./validation/1-Chr8-27807304_DP6
# 	--from-bp 27807302
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.064s
# user	0m0.041s
# sys	0m0.010s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-8_1-Chr8-27807304.DP10.vcf.gz
# 	--chr Chr8
# 	--to-bp 27807306
# 	--012
# 	--out ./validation/1-Chr8-27807304_DP10
# 	--from-bp 27807302
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
#
# Chr8	8_3	38142268	3-Chr8-38142268
#
#
# No Filter
#
# real	0m0.024s
# user	0m0.011s
# sys	0m0.011s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-8_3-Chr8-38142268.noFilter.vcf.gz
# 	--chr Chr8
# 	--to-bp 38142270
# 	--012
# 	--out ./validation/3-Chr8-38142268_noFilter
# 	--from-bp 38142266
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Softmask FORMAT/DP<6
#
# real	0m0.027s
# user	0m0.020s
# sys	0m0.005s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-8_3-Chr8-38142268.DP6.vcf.gz
# 	--chr Chr8
# 	--to-bp 38142270
# 	--012
# 	--out ./validation/3-Chr8-38142268_DP6
# 	--from-bp 38142266
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Softmask FORMAT/DP<10
#
# real	0m0.025s
# user	0m0.009s
# sys	0m0.014s
#
# VCFtools - 0.1.16
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf ./validation/mpileup-8_3-Chr8-38142268.DP10.vcf.gz
# 	--chr Chr8
# 	--to-bp 38142270
# 	--012
# 	--out ./validation/3-Chr8-38142268_DP10
# 	--from-bp 38142266
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in INFO entry: ID=AC,Number=A,Type=Integer,Description="Allele count in genotypes for each ALT allele, in the same order as listed">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# Warning: Expected at least 2 parts in INFO entry: ID=DP4,Number=4,Type=Integer,Description="Number of high-quality ref-forward , ref-reverse, alt-forward and alt-reverse bases">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create combined GT file
