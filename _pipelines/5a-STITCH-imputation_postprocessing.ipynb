# %% [markdown]
# # Postprocessing STITCH output

# %% [markdown]
# - Step 1 - Extract all genotypes from high-confidence STITCH output VCF based on posterior genotype prob.
# - Step 2 - Merge all chrom_segment VCFs into one VCF per chromosome
# - Step 3 - Extract VCF stats

# %%
module load bcftools/1.18 vcftools/0.1.16 parallel
module list
# Out:
# Currently Loaded Modules:
#   1) git/2.35.1         7) R/4.3.1-b                  13) GSL/2.7
#   2) java/17            8) rstudio/2023.06.1-524      14) htslib/1.18
#   3) texlive/20211108   9) nodejs/18.16.1        (T)  15) perl/5.36.0
#   4) hdf5/1.14.2       10) julia/1.10.1               16) bcftools/1.18
#   5) gdal/3.4.2        11) proj/8.1.1                 17) vcftools/0.1.16
#   6) glpk/5.0          12) JupyterPython/2.0     (T)  18) parallel/20220222
#
#   Where:
#    T:  Testing

# %% [markdown]
# ## Steps for postprocessing STITCH VCF output

# %% [markdown]
# *NB: Change the baseDIR for stitch Run 2.*

# %% [markdown]
# ### Initiate variables

# %%
## Input variable
chrom=Chr6
baseDIR=~/snap_hap/variants/stitch/${chrom}

echo -e "\n"
echo chrom: $chrom
echo baseDIR: $baseDIR 
echo -e '\n'
# Out:
# chrom: Chr6
# baseDIR: /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr6
# outVCF: /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr6/Am_all_stitch_Chr6_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz

# %% [markdown]
# ### Extract all genotypes from high-confidence stitch output

# %%
echo -e '\nExtract all genotypes from STITCH'
realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*[^PL].vcf.gz > ${baseDIR}/stitchVcfs.highConf.list

## Execute in parallel mode
#time parallel -j10 "bash ~/snap_hap/_scripts/bash/stitch/add_PG_PL.sh {}" ::: ${baseDIR}/stitch_chromSegments/*/stitch.${chrom}.*.*[^PL].vcf.gz

## Execute one-by-one (parallel array job in cluster)
SLURM_ARRAY_TASK_ID=1
inVCF=$(sed -n "${SLURM_ARRAY_TASK_ID}p" $stitchVcfList)
echo $inVCF
time bash ~/snap_hap/_scripts/bash/stitch/add_PG_PL.sh $inVCF

# %% [markdown]
# ### Merge vcfs

# %%
## Make stitch-highConf-VCF list
echo -e '\nMerge highConf stitch VCFs'

realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*[^PL].vcf.gz > ${baseDIR}/stitchVcfs.highConf.list
stitchVcfList_highConf=${baseDIR}/stitchVcfs.highConf.list
outVCF_highConf=$baseDIR/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz

time bcftools concat -a -Oz -o ${outVCF_highConf} -f ${stitchVcfList_highConf}
time bcftools stats --threads 10 -s- --af-bins <(seq 0 0.1 1) --depth 0,25000,25 ${outVCF_highConf} > ${outVCF_highConf/.vcf.gz/.stats}

# %%
## Make stitch-ALL-VCF list
echo -e '\nMerge ALL stitch VCFs'

realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*.PL.vcf.gz > ${baseDIR}/stitchVcfs.ALL.list
stitchVcfList_ALL=${baseDIR}/stitchVcfs.ALL.list
outVCF_ALL=$baseDIR/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz

time bcftools concat -a -Oz -o ${outVCF_ALL} -f ${stitchVcfList_ALL}
time bcftools stats --threads 10 -s- --af-bins <(seq 0 0.1 1) --depth 0,25000,25 ${outVCF_ALL} > ${outVCF_ALL/.vcf.gz/.stats}

# %% [markdown]
# ### Add AC,AN annotations

# %%
#inputVCF = ...
bash ~/snap_hap/_scripts/bash/fill-AC-AN_vcfgzFormat.sh $inputVCF

# %% [markdown]
# ### Create VCF statitics

# %%
## Calculate missing genotypes per site and individual
echo -e '\nCalculating fraction of missing data'
time vcftools --gzvcf $outVCF --missing-indv --out ${chrom}_missing-indv
time vcftools --gzvcf $outVCF --missing-site --out ${chrom}_missing-site

## Calculate heterozygosity per individual
echo -e '\nCalculating heterozygosity'
time vcftools --gzvcf $outVCF --het --out ${chrom}_het-indv

# %% [markdown]
# ## Cluster implementation: postprocessing STITCH output

# %% [markdown]
# ### Make list of high-conf STITCH vcfs

# %%
for chrom in Chr{1..8}
do
    baseDIR=~/snap_hap/variants/stitch/${chrom}
    echo -e $chrom'\t'$baseDIR'\t'$(realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*[^PL].vcf.gz | wc -l) files
    realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*[^PL].vcf.gz > ${baseDIR}/stitchVcfs.highConf.list
    echo -e ${baseDIR}/stitchVcfs.highConf.list'\n'
done
# Out:
# Chr1	/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr1	72 files
# /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr1/stitchVcfs.highConf.list
#
# Chr2	/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr2	78 files
# /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr2/stitchVcfs.highConf.list
#
# Chr3	/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr3	66 files
# /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr3/stitchVcfs.highConf.list
#
# Chr4	/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr4	55 files
# /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr4/stitchVcfs.highConf.list
#
# Chr5	/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr5	71 files
# /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr5/stitchVcfs.highConf.list
#
# Chr6	/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr6	56 files
# /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr6/stitchVcfs.highConf.list
#
# Chr7	/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr7	56 files
# /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr7/stitchVcfs.highConf.list
#
# Chr8	/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr8	58 files
# /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr8/stitchVcfs.highConf.list

# %% [markdown]
# ### Extract all genotypes from high-confidence stitch output

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/postSTITCH/extractGT

# Chr1
chrom=Chr1
baseDIR=~/snap_hap/variants/stitch/${chrom}
sbatch --array=1-72 -J postSTITCH-extractGT_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch $chrom ${baseDIR}/stitchVcfs.highConf.list
# Chr2
chrom=Chr2
baseDIR=~/snap_hap/variants/stitch/${chrom}
sbatch --array=1-78 -J postSTITCH-extractGT_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch $chrom ${baseDIR}/stitchVcfs.highConf.list
# Chr3
chrom=Chr3
baseDIR=~/snap_hap/variants/stitch/${chrom}
sbatch --array=1-66 -J postSTITCH-extractGT_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch $chrom ${baseDIR}/stitchVcfs.highConf.list
# Chr4
chrom=Chr4
baseDIR=~/snap_hap/variants/stitch/${chrom}
sbatch --array=1-55 -J postSTITCH-extractGT_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch $chrom ${baseDIR}/stitchVcfs.highConf.list
# Chr5
chrom=Chr5
baseDIR=~/snap_hap/variants/stitch/${chrom}
sbatch --array=1-71 -J postSTITCH-extractGT_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch $chrom ${baseDIR}/stitchVcfs.highConf.list
# Chr6
chrom=Chr6
baseDIR=~/snap_hap/variants/stitch/${chrom}
sbatch --array=1-56 -J postSTITCH-extractGT_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch $chrom ${baseDIR}/stitchVcfs.highConf.list
# Chr7
chrom=Chr7
baseDIR=~/snap_hap/variants/stitch/${chrom}
sbatch --array=1-56 -J postSTITCH-extractGT_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch $chrom ${baseDIR}/stitchVcfs.highConf.list
# Chr8
chrom=Chr8
baseDIR=~/snap_hap/variants/stitch/${chrom}
sbatch --array=1-58 -J postSTITCH-extractGT_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch $chrom ${baseDIR}/stitchVcfs.highConf.list

# %% [markdown]
# ```
# #SBATCH --partition=defaultp
# #SBATCH --time=00:30:00
# #SBATCH --ntasks=1
# #SBATCH --ntasks-per-node=1
# #SBATCH --cpus-per-task=1
# #SBATCH --mem-per-cpu=4G
# ```

# %% [markdown]
# It takes slightly longer time if run with `time srun ...` instead of `srun time ...` with the SLURM script. Generally, takes around ~10-15 mins.

# %% [markdown]
# ### Concat VCFs

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/postSTITCH/concatVcfs

for chrom in Chr{1..8}
do 
    baseDIR=~/snap_hap/variants/stitch/${chrom}
    echo -e $chrom'\t'$baseDIR

    #highConf#
    realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*[^PL].vcf.gz > ${baseDIR}/stitchVcfs.highConf.list
    stitchVcfList_highConf=${baseDIR}/stitchVcfs.highConf.list
    outVCF_highConf=$baseDIR/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
    sbatch -J postSTITCH-concatVcfs-highConf_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-concatVcfs.sbatch.sh ${chrom} ${stitchVcfList_highConf} ${outVCF_highConf}

    #ALL#
    realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*.PL.vcf.gz > ${baseDIR}/stitchVcfs.ALL.list
    stitchVcfList_ALL=${baseDIR}/stitchVcfs.ALL.list
    outVCF_ALL=$baseDIR/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz
    sbatch -J postSTITCH-concatVcfs-ALL_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-concatVcfs.sbatch.sh ${chrom} ${stitchVcfList_ALL} ${outVCF_ALL}
done

# %% [markdown]
# ```
# #SBATCH --partition=defaultp
# #SBATCH --time=3:00:00
# #SBATCH --nodes=1
# #SBATCH --ntasks=1
# #SBATCH --ntasks-per-node=1
# #SBATCH --cpus-per-task=5
# #SBATCH --mem-per-cpu=4G
# ```

# %%
User    Account      State        JobID    JobName  AllocCPUS AllocNodes    CPUTime     ReqMem     MaxRSS    Elapsed  AllocTRES 
--------- ---------- ---------- ------------ ---------- ---------- ---------- ---------- ---------- ---------- ---------- ---------- 
     apal   bartogrp     FAILED 9568345      postSTITC+          1          1   00:50:34       16Gc              00:50:34 billing=1+ 
            bartogrp  COMPLETED 9568345.0          time          1          1   00:50:25       16Gc     30228K   00:50:25 cpu=1,mem+

# %% [markdown]
# ### Add AC, AN annotations

# %% [markdown]
# **NB:** Don't run AC,AN fill on cluster due to incompatibilities of bcftools libraries.

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/postSTITCH/annotateVcfs

for chrom in Chr{1..8}
do 
    baseDIR=~/snap_hap/variants/stitch/${chrom}
    echo -e $chrom'\t'$baseDIR

    #highConf#
    inputVCF_highConf=$baseDIR/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
    sbatch -J ${chrom}_highConf_tagVCFs ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-fill_AC_AN.sbatch ${inputVCF_highConf}

    #ALL#
    inputVCF_ALL=$baseDIR/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz
    sbatch -J ${chrom}_highConf_tagVCFs ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-fill_AC_AN.sbatch ${inputVCF_ALL}
done

# %% [markdown]
# ## stitch VCF statistics

# %%
basedir="/nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch"

echo -e 'No. of stitched records'
for chrom in Chr{1..8}; do records=`grep "number of records:" $basedir/$chrom/*PL.stats | cut -f4`; echo -e $chrom"\t"$records; done
# Out:
# No. of stitched records
# Chr1	3781002
# Chr2	4287044
# Chr3	3400629
# Chr4	3059258
# Chr5	4295411
# Chr6	3361343
# Chr7	3079991
# Chr8	3692065

# %% [markdown]
# ## Extract imputed genotypes for validation against 30 KASP markers

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/validation

# %%
## Read KASP coords positions
KASPcoords=~/snap_hap/impute/stitch_tests/coords/coords_for_stitch_longVersion_corrected_200kb.txt
cat $KASPcoords | cut -f1,4,8
# Out:
# snpID	CHROM	POS
# 1	Chr1	955185
# 2	Chr1	45535107
# 3	Chr1	47381180
# 4	Chr1	51252783
# 5	Chr1	60537705
# 6	Chr1	71126303
# 1	Chr2	55473945
# 2	Chr2	58751341
# 1	Chr3	1055959
# 2	Chr3	3488331
# 3	Chr3	44197469
# 1	Chr4	7115521
# 2	Chr4	38397179
# 3	Chr4	44460308
# 4	Chr4	50972302
# 1	Chr6	15125731
# 2	Chr6	32503688
# 3	Chr6	52921613
# 4	Chr6	52922047
# 5	Chr6	52966811
# 6	Chr6	52999112
# 7	Chr6	53016551
# 8	Chr6	53061080
# 9	Chr6	53083229
# 10	Chr6	53090212
# 11	Chr6	53094790
# 12	Chr6	53104387
# 13	Chr6	53195127
# 14	Chr6	53944185
# 1	Chr7	49828363
# 1	Chr8	27807304
# 2	Chr8	31864104
# 3	Chr8	38142268
# 4	Chr8	44933278
# 5	Chr8	53715058

# %%
## Chr1
chrom=Chr1
KASPcoords=~/snap_hap/impute/stitch_tests/coords/coords_for_stitch_longVersion_corrected_200kb.txt
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
for snpID in {1..6}
do
    markerID=${chrom/Chr}_${snpID}
    pos=$(grep -w $markerID $KASPcoords | cut -f8)
    echo -e "\n"$chrom"\t"$snpID"\t"$markerID"\t"$pos"\n"
    # Subset VCF with bcftools
    echo "Subsetting VCF with bcftools"
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.vcf.gz $vcf
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.PL.vcf.gz ${vcf/.vcf.gz/.PL.vcf.gz}    
    # Extract genotypes
    echo "Extracting stitch genotypes"
    time bash ~/snap_hap/_scripts/bash/stitch/extract_stitchGT.sh $chrom $snpID $pos ${snpID}_${chrom}_${pos}.vcf.gz
    rm ${snpID}_${chrom}_${pos}*.vcf.gz*
done
# Out:
# Chr1	1	1_1	955185
#
# Subsetting VCF with bcftools
#
# real	0m0.139s
# user	0m0.044s
# sys	0m0.041s
#
# real	0m0.099s
# user	0m0.058s
# sys	0m0.036s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr1_955185.vcf.gz
# 	--chr Chr1
# 	--to-bp 955187
# 	--012
# 	--out 1-Chr1-955185_highConf
# 	--from-bp 955183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.172s
# user	0m0.052s
# sys	0m0.121s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr1_955185.PL.vcf.gz
# 	--chr Chr1
# 	--to-bp 955187
# 	--012
# 	--out 1-Chr1-955185_ALL
# 	--from-bp 955183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m3.703s
# user	0m1.003s
# sys	0m1.158s
#
# Chr1	2	1_2	45535107
#
# Subsetting VCF with bcftools
#
# real	0m0.057s
# user	0m0.030s
# sys	0m0.023s
#
# real	0m0.093s
# user	0m0.049s
# sys	0m0.017s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr1_45535107.vcf.gz
# 	--chr Chr1
# 	--to-bp 45535109
# 	--012
# 	--out 2-Chr1-45535107_highConf
# 	--from-bp 45535105
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.159s
# user	0m0.064s
# sys	0m0.101s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr1_45535107.PL.vcf.gz
# 	--chr Chr1
# 	--to-bp 45535109
# 	--012
# 	--out 2-Chr1-45535107_ALL
# 	--from-bp 45535105
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m3.231s
# user	0m0.890s
# sys	0m0.983s
#
# Chr1	3	1_3	47381180
#
# Subsetting VCF with bcftools
#
# real	0m0.093s
# user	0m0.058s
# sys	0m0.030s
#
# real	0m0.445s
# user	0m0.082s
# sys	0m0.037s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr1_47381180.vcf.gz
# 	--chr Chr1
# 	--to-bp 47381182
# 	--012
# 	--out 3-Chr1-47381180_highConf
# 	--from-bp 47381178
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.156s
# user	0m0.053s
# sys	0m0.107s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr1_47381180.PL.vcf.gz
# 	--chr Chr1
# 	--to-bp 47381182
# 	--012
# 	--out 3-Chr1-47381180_ALL
# 	--from-bp 47381178
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.471s
# user	0m0.913s
# sys	0m0.854s
#
# Chr1	4	1_4	51252783
#
# Subsetting VCF with bcftools
#
# real	0m0.041s
# user	0m0.017s
# sys	0m0.021s
#
# real	0m0.282s
# user	0m0.015s
# sys	0m0.030s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 4_Chr1_51252783.vcf.gz
# 	--chr Chr1
# 	--to-bp 51252785
# 	--012
# 	--out 4-Chr1-51252783_highConf
# 	--from-bp 51252781
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.160s
# user	0m0.053s
# sys	0m0.112s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 4_Chr1_51252783.PL.vcf.gz
# 	--chr Chr1
# 	--to-bp 51252785
# 	--012
# 	--out 4-Chr1-51252783_ALL
# 	--from-bp 51252781
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.548s
# user	0m0.838s
# sys	0m0.971s
#
# Chr1	5	1_5	60537705
#
# Subsetting VCF with bcftools
#
# real	0m0.129s
# user	0m0.085s
# sys	0m0.039s
#
# real	0m0.487s
# user	0m0.156s
# sys	0m0.017s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 5_Chr1_60537705.vcf.gz
# 	--chr Chr1
# 	--to-bp 60537707
# 	--012
# 	--out 5-Chr1-60537705_highConf
# 	--from-bp 60537703
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.163s
# user	0m0.060s
# sys	0m0.111s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 5_Chr1_60537705.PL.vcf.gz
# 	--chr Chr1
# 	--to-bp 60537707
# 	--012
# 	--out 5-Chr1-60537705_ALL
# 	--from-bp 60537703
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.530s
# user	0m0.864s
# sys	0m0.979s
#
# Chr1	6	1_6	71126303
#
# Subsetting VCF with bcftools
#
# real	0m0.041s
# user	0m0.022s
# sys	0m0.017s
#
# real	0m0.127s
# user	0m0.039s
# sys	0m0.016s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 6_Chr1_71126303.vcf.gz
# 	--chr Chr1
# 	--to-bp 71126305
# 	--012
# 	--out 6-Chr1-71126303_highConf
# 	--from-bp 71126301
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.157s
# user	0m0.066s
# sys	0m0.101s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 6_Chr1_71126303.PL.vcf.gz
# 	--chr Chr1
# 	--to-bp 71126305
# 	--012
# 	--out 6-Chr1-71126303_ALL
# 	--from-bp 71126301
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.245s
# user	0m0.906s
# sys	0m0.855s

# %%
## Chr2
chrom=Chr2
KASPcoords=~/snap_hap/impute/stitch_tests/coords/coords_for_stitch_longVersion_corrected_200kb.txt
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
for snpID in {1..2}
do
    markerID=${chrom/Chr}_${snpID}
    pos=$(grep -w $markerID $KASPcoords | cut -f8)
    echo -e "\n"$chrom"\t"$snpID"\t"$markerID"\t"$pos"\n"
    # Subset VCF with bcftools
    echo "Subsetting VCF with bcftools"
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.vcf.gz $vcf
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.PL.vcf.gz ${vcf/.vcf.gz/.PL.vcf.gz}    
    # Extract genotypes
    echo "Extracting stitch genotypes"
    time bash ~/snap_hap/_scripts/bash/stitch/extract_stitchGT.sh $chrom $snpID $pos ${snpID}_${chrom}_${pos}.vcf.gz
    rm ${snpID}_${chrom}_${pos}*.vcf.gz*
done
# Out:
# Chr2	1	2_1	55473945
#
# Subsetting VCF with bcftools
#
# real	0m0.060s
# user	0m0.033s
# sys	0m0.022s
#
# real	0m0.093s
# user	0m0.064s
# sys	0m0.013s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr2_55473945.vcf.gz
# 	--chr Chr2
# 	--to-bp 55473947
# 	--012
# 	--out 1-Chr2-55473945_highConf
# 	--from-bp 55473943
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.188s
# user	0m0.053s
# sys	0m0.110s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr2_55473945.PL.vcf.gz
# 	--chr Chr2
# 	--to-bp 55473947
# 	--012
# 	--out 1-Chr2-55473945_ALL
# 	--from-bp 55473943
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.241s
# user	0m0.832s
# sys	0m0.931s
#
# Chr2	2	2_2	58751341
#
# Subsetting VCF with bcftools
#
# real	0m0.102s
# user	0m0.083s
# sys	0m0.016s
#
# real	0m0.172s
# user	0m0.129s
# sys	0m0.025s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr2_58751341.vcf.gz
# 	--chr Chr2
# 	--to-bp 58751343
# 	--012
# 	--out 2-Chr2-58751341_highConf
# 	--from-bp 58751339
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.163s
# user	0m0.065s
# sys	0m0.106s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr2_58751341.PL.vcf.gz
# 	--chr Chr2
# 	--to-bp 58751343
# 	--012
# 	--out 2-Chr2-58751341_ALL
# 	--from-bp 58751339
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.523s
# user	0m0.858s
# sys	0m0.907s

# %%
## Chr2
chrom=Chr3
KASPcoords=~/snap_hap/impute/stitch_tests/coords/coords_for_stitch_longVersion_corrected_200kb.txt
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
for snpID in {1..3}
do
    markerID=${chrom/Chr}_${snpID}
    pos=$(grep -w $markerID $KASPcoords | cut -f8)
    echo -e "\n"$chrom"\t"$snpID"\t"$markerID"\t"$pos"\n"
    # Subset VCF with bcftools
    echo "Subsetting VCF with bcftools"
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.vcf.gz $vcf
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.PL.vcf.gz ${vcf/.vcf.gz/.PL.vcf.gz}    
    # Extract genotypes
    echo "Extracting stitch genotypes"
    time bash ~/snap_hap/_scripts/bash/stitch/extract_stitchGT.sh $chrom $snpID $pos ${snpID}_${chrom}_${pos}.vcf.gz
    rm ${snpID}_${chrom}_${pos}*.vcf.gz*
done
# Out:
# Chr3	1	3_1	1055959
#
# Subsetting VCF with bcftools
#
# real	0m0.194s
# user	0m0.058s
# sys	0m0.018s
#
# real	0m0.370s
# user	0m0.071s
# sys	0m0.034s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr3_1055959.vcf.gz
# 	--chr Chr3
# 	--to-bp 1055961
# 	--012
# 	--out 1-Chr3-1055959_highConf
# 	--from-bp 1055957
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.177s
# user	0m0.054s
# sys	0m0.123s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr3_1055959.PL.vcf.gz
# 	--chr Chr3
# 	--to-bp 1055961
# 	--012
# 	--out 1-Chr3-1055959_ALL
# 	--from-bp 1055957
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.273s
# user	0m0.860s
# sys	0m0.930s
#
# Chr3	2	3_2	3488331
#
# Subsetting VCF with bcftools
#
# real	0m0.139s
# user	0m0.092s
# sys	0m0.025s
#
# real	0m0.313s
# user	0m0.127s
# sys	0m0.020s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr3_3488331.vcf.gz
# 	--chr Chr3
# 	--to-bp 3488333
# 	--012
# 	--out 2-Chr3-3488331_highConf
# 	--from-bp 3488329
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.163s
# user	0m0.048s
# sys	0m0.116s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr3_3488331.PL.vcf.gz
# 	--chr Chr3
# 	--to-bp 3488333
# 	--012
# 	--out 2-Chr3-3488331_ALL
# 	--from-bp 3488329
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.639s
# user	0m0.894s
# sys	0m0.935s
#
# Chr3	3	3_3	44197469
#
# Subsetting VCF with bcftools
#
# real	0m0.127s
# user	0m0.077s
# sys	0m0.033s
#
# real	0m0.466s
# user	0m0.133s
# sys	0m0.020s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr3_44197469.vcf.gz
# 	--chr Chr3
# 	--to-bp 44197471
# 	--012
# 	--out 3-Chr3-44197469_highConf
# 	--from-bp 44197467
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.169s
# user	0m0.053s
# sys	0m0.118s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr3_44197469.PL.vcf.gz
# 	--chr Chr3
# 	--to-bp 44197471
# 	--012
# 	--out 3-Chr3-44197469_ALL
# 	--from-bp 44197467
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m3.013s
# user	0m0.933s
# sys	0m0.947s

# %%
## Chr4
chrom=Chr4
KASPcoords=~/snap_hap/impute/stitch_tests/coords/coords_for_stitch_longVersion_corrected_200kb.txt
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
for snpID in {1..4}
do
    markerID=${chrom/Chr}_${snpID}
    pos=$(grep -w $markerID $KASPcoords | cut -f8)
    echo -e "\n"$chrom"\t"$snpID"\t"$markerID"\t"$pos"\n"
    # Subset VCF with bcftools
    echo "Subsetting VCF with bcftools"
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.vcf.gz $vcf
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.PL.vcf.gz ${vcf/.vcf.gz/.PL.vcf.gz}    
    # Extract genotypes
    echo "Extracting stitch genotypes"
    time bash ~/snap_hap/_scripts/bash/stitch/extract_stitchGT.sh $chrom $snpID $pos ${snpID}_${chrom}_${pos}.vcf.gz
    rm ${snpID}_${chrom}_${pos}*.vcf.gz*
done
# Out:
# Chr4	1	4_1	7115521
#
# Subsetting VCF with bcftools
#
# real	0m0.050s
# user	0m0.031s
# sys	0m0.012s
#
# real	0m0.570s
# user	0m0.039s
# sys	0m0.027s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr4_7115521.vcf.gz
# 	--chr Chr4
# 	--to-bp 7115523
# 	--012
# 	--out 1-Chr4-7115521_highConf
# 	--from-bp 7115519
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.151s
# user	0m0.046s
# sys	0m0.108s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr4_7115521.PL.vcf.gz
# 	--chr Chr4
# 	--to-bp 7115523
# 	--012
# 	--out 1-Chr4-7115521_ALL
# 	--from-bp 7115519
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.214s
# user	0m0.887s
# sys	0m0.834s
#
# Chr4	2	4_2	38397179
#
# Subsetting VCF with bcftools
#
# real	0m0.080s
# user	0m0.041s
# sys	0m0.023s
#
# real	0m0.416s
# user	0m0.074s
# sys	0m0.021s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr4_38397179.vcf.gz
# 	--chr Chr4
# 	--to-bp 38397181
# 	--012
# 	--out 2-Chr4-38397179_highConf
# 	--from-bp 38397177
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.156s
# user	0m0.050s
# sys	0m0.113s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr4_38397179.PL.vcf.gz
# 	--chr Chr4
# 	--to-bp 38397181
# 	--012
# 	--out 2-Chr4-38397179_ALL
# 	--from-bp 38397177
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.676s
# user	0m0.815s
# sys	0m0.949s
#
# Chr4	3	4_3	44460308
#
# Subsetting VCF with bcftools
#
# real	0m0.115s
# user	0m0.078s
# sys	0m0.017s
#
# real	0m0.359s
# user	0m0.104s
# sys	0m0.014s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr4_44460308.vcf.gz
# 	--chr Chr4
# 	--to-bp 44460310
# 	--012
# 	--out 3-Chr4-44460308_highConf
# 	--from-bp 44460306
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.157s
# user	0m0.041s
# sys	0m0.123s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr4_44460308.PL.vcf.gz
# 	--chr Chr4
# 	--to-bp 44460310
# 	--012
# 	--out 3-Chr4-44460308_ALL
# 	--from-bp 44460306
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.463s
# user	0m0.884s
# sys	0m0.945s
#
# Chr4	4	4_4	50972302
#
# Subsetting VCF with bcftools
#
# real	0m0.047s
# user	0m0.023s
# sys	0m0.020s
#
# real	0m0.217s
# user	0m0.029s
# sys	0m0.026s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 4_Chr4_50972302.vcf.gz
# 	--chr Chr4
# 	--to-bp 50972304
# 	--012
# 	--out 4-Chr4-50972302_highConf
# 	--from-bp 50972300
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.163s
# user	0m0.050s
# sys	0m0.119s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 4_Chr4_50972302.PL.vcf.gz
# 	--chr Chr4
# 	--to-bp 50972304
# 	--012
# 	--out 4-Chr4-50972302_ALL
# 	--from-bp 50972300
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.540s
# user	0m0.889s
# sys	0m0.983s

# %%
## Chr6
chrom=Chr6
KASPcoords=~/snap_hap/impute/stitch_tests/coords/coords_for_stitch_longVersion_corrected_200kb.txt
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
for snpID in {1..14}
do
    markerID=${chrom/Chr}_${snpID}
    pos=$(grep -w $markerID $KASPcoords | cut -f8)
    echo -e "\n"$chrom"\t"$snpID"\t"$markerID"\t"$pos"\n"
    # Subset VCF with bcftools
    echo "Subsetting VCF with bcftools"
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.vcf.gz $vcf
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.PL.vcf.gz ${vcf/.vcf.gz/.PL.vcf.gz}    
    # Extract genotypes
    echo "Extracting stitch genotypes"
    time bash ~/snap_hap/_scripts/bash/stitch/extract_stitchGT.sh $chrom $snpID $pos ${snpID}_${chrom}_${pos}.vcf.gz
    rm ${snpID}_${chrom}_${pos}*.vcf.gz*
done
# Out:
# Chr6	1	6_1	15125731
#
# Subsetting VCF with bcftools
#
# real	0m0.663s
# user	0m0.032s
# sys	0m0.014s
#
# real	0m0.182s
# user	0m0.025s
# sys	0m0.017s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr6_15125731.vcf.gz
# 	--chr Chr6
# 	--to-bp 15125733
# 	--012
# 	--out 1-Chr6-15125731_highConf
# 	--from-bp 15125729
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.169s
# user	0m0.063s
# sys	0m0.102s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr6_15125731.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 15125733
# 	--012
# 	--out 1-Chr6-15125731_ALL
# 	--from-bp 15125729
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.580s
# user	0m0.849s
# sys	0m0.842s
#
# Chr6	2	6_2	32503688
#
# Subsetting VCF with bcftools
#
# real	0m0.199s
# user	0m0.042s
# sys	0m0.015s
#
# real	0m0.067s
# user	0m0.047s
# sys	0m0.015s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr6_32503688.vcf.gz
# 	--chr Chr6
# 	--to-bp 32503690
# 	--012
# 	--out 2-Chr6-32503688_highConf
# 	--from-bp 32503686
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.151s
# user	0m0.033s
# sys	0m0.123s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr6_32503688.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 32503690
# 	--012
# 	--out 2-Chr6-32503688_ALL
# 	--from-bp 32503686
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.025s
# user	0m0.763s
# sys	0m0.847s
#
# Chr6	3	6_3	52921613
#
# Subsetting VCF with bcftools
#
# real	0m0.057s
# user	0m0.013s
# sys	0m0.022s
#
# real	0m0.169s
# user	0m0.020s
# sys	0m0.021s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr6_52921613.vcf.gz
# 	--chr Chr6
# 	--to-bp 52921615
# 	--012
# 	--out 3-Chr6-52921613_highConf
# 	--from-bp 52921611
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 2.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.155s
# user	0m0.044s
# sys	0m0.119s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr6_52921613.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 52921615
# 	--012
# 	--out 3-Chr6-52921613_ALL
# 	--from-bp 52921611
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m3.231s
# user	0m0.812s
# sys	0m1.004s
#
# Chr6	4	6_4	52922047
#
# Subsetting VCF with bcftools
#
# real	0m0.037s
# user	0m0.017s
# sys	0m0.018s
#
# real	0m0.040s
# user	0m0.020s
# sys	0m0.017s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 4_Chr6_52922047.vcf.gz
# 	--chr Chr6
# 	--to-bp 52922049
# 	--012
# 	--out 4-Chr6-52922047_highConf
# 	--from-bp 52922045
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.156s
# user	0m0.038s
# sys	0m0.121s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 4_Chr6_52922047.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 52922049
# 	--012
# 	--out 4-Chr6-52922047_ALL
# 	--from-bp 52922045
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.241s
# user	0m0.811s
# sys	0m0.857s
#
# Chr6	5	6_5	52966811
#
# Subsetting VCF with bcftools
#
# real	0m0.230s
# user	0m0.068s
# sys	0m0.020s
#
# real	0m0.273s
# user	0m0.082s
# sys	0m0.027s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 5_Chr6_52966811.vcf.gz
# 	--chr Chr6
# 	--to-bp 52966813
# 	--012
# 	--out 5-Chr6-52966811_highConf
# 	--from-bp 52966809
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.174s
# user	0m0.060s
# sys	0m0.103s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 5_Chr6_52966811.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 52966813
# 	--012
# 	--out 5-Chr6-52966811_ALL
# 	--from-bp 52966809
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.318s
# user	0m0.881s
# sys	0m0.906s
#
# Chr6	6	6_6	52999112
#
# Subsetting VCF with bcftools
#
# real	0m0.261s
# user	0m0.083s
# sys	0m0.036s
#
# real	0m0.184s
# user	0m0.150s
# sys	0m0.028s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 6_Chr6_52999112.vcf.gz
# 	--chr Chr6
# 	--to-bp 52999114
# 	--012
# 	--out 6-Chr6-52999112_highConf
# 	--from-bp 52999110
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.199s
# user	0m0.057s
# sys	0m0.115s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 6_Chr6_52999112.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 52999114
# 	--012
# 	--out 6-Chr6-52999112_ALL
# 	--from-bp 52999110
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.511s
# user	0m0.915s
# sys	0m0.895s
#
# Chr6	7	6_7	53016551
#
# Subsetting VCF with bcftools
#
# real	0m0.168s
# user	0m0.089s
# sys	0m0.029s
#
# real	0m0.198s
# user	0m0.148s
# sys	0m0.036s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 7_Chr6_53016551.vcf.gz
# 	--chr Chr6
# 	--to-bp 53016553
# 	--012
# 	--out 7-Chr6-53016551_highConf
# 	--from-bp 53016549
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.149s
# user	0m0.063s
# sys	0m0.093s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 7_Chr6_53016551.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 53016553
# 	--012
# 	--out 7-Chr6-53016551_ALL
# 	--from-bp 53016549
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.694s
# user	0m0.914s
# sys	0m0.968s
#
# Chr6	8	6_8	53061080
#
# Subsetting VCF with bcftools
#
# real	0m0.177s
# user	0m0.063s
# sys	0m0.024s
#
# real	0m0.389s
# user	0m0.083s
# sys	0m0.026s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 8_Chr6_53061080.vcf.gz
# 	--chr Chr6
# 	--to-bp 53061082
# 	--012
# 	--out 8-Chr6-53061080_highConf
# 	--from-bp 53061078
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.161s
# user	0m0.042s
# sys	0m0.118s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 8_Chr6_53061080.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 53061082
# 	--012
# 	--out 8-Chr6-53061080_ALL
# 	--from-bp 53061078
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.715s
# user	0m0.867s
# sys	0m0.987s
#
# Chr6	9	6_9	53083229
#
# Subsetting VCF with bcftools
#
# real	0m0.101s
# user	0m0.085s
# sys	0m0.012s
#
# real	0m0.173s
# user	0m0.120s
# sys	0m0.029s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 9_Chr6_53083229.vcf.gz
# 	--chr Chr6
# 	--to-bp 53083231
# 	--012
# 	--out 9-Chr6-53083229_highConf
# 	--from-bp 53083227
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.157s
# user	0m0.036s
# sys	0m0.129s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 9_Chr6_53083229.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 53083231
# 	--012
# 	--out 9-Chr6-53083229_ALL
# 	--from-bp 53083227
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.229s
# user	0m0.857s
# sys	0m0.913s
#
# Chr6	10	6_10	53090212
#
# Subsetting VCF with bcftools
#
# real	0m0.083s
# user	0m0.054s
# sys	0m0.024s
#
# real	0m0.098s
# user	0m0.069s
# sys	0m0.025s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 10_Chr6_53090212.vcf.gz
# 	--chr Chr6
# 	--to-bp 53090214
# 	--012
# 	--out 10-Chr6-53090212_highConf
# 	--from-bp 53090210
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.159s
# user	0m0.060s
# sys	0m0.105s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 10_Chr6_53090212.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 53090214
# 	--012
# 	--out 10-Chr6-53090212_ALL
# 	--from-bp 53090210
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.220s
# user	0m0.831s
# sys	0m0.912s
#
# Chr6	11	6_11	53094790
#
# Subsetting VCF with bcftools
#
# real	0m0.119s
# user	0m0.087s
# sys	0m0.017s
#
# real	0m0.154s
# user	0m0.134s
# sys	0m0.013s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 11_Chr6_53094790.vcf.gz
# 	--chr Chr6
# 	--to-bp 53094792
# 	--012
# 	--out 11-Chr6-53094790_highConf
# 	--from-bp 53094788
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.155s
# user	0m0.085s
# sys	0m0.079s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 11_Chr6_53094790.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 53094792
# 	--012
# 	--out 11-Chr6-53094790_ALL
# 	--from-bp 53094788
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.607s
# user	0m0.928s
# sys	0m0.879s
#
# Chr6	12	6_12	53104387
#
# Subsetting VCF with bcftools
#
# real	0m0.059s
# user	0m0.029s
# sys	0m0.026s
#
# real	0m0.072s
# user	0m0.045s
# sys	0m0.023s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 12_Chr6_53104387.vcf.gz
# 	--chr Chr6
# 	--to-bp 53104389
# 	--012
# 	--out 12-Chr6-53104387_highConf
# 	--from-bp 53104385
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.163s
# user	0m0.062s
# sys	0m0.107s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 12_Chr6_53104387.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 53104389
# 	--012
# 	--out 12-Chr6-53104387_ALL
# 	--from-bp 53104385
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.499s
# user	0m0.881s
# sys	0m0.954s
#
# Chr6	13	6_13	53195127
#
# Subsetting VCF with bcftools
#
# real	0m0.238s
# user	0m0.084s
# sys	0m0.017s
#
# real	0m0.235s
# user	0m0.101s
# sys	0m0.033s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 13_Chr6_53195127.vcf.gz
# 	--chr Chr6
# 	--to-bp 53195129
# 	--012
# 	--out 13-Chr6-53195127_highConf
# 	--from-bp 53195125
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.162s
# user	0m0.050s
# sys	0m0.115s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 13_Chr6_53195127.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 53195129
# 	--012
# 	--out 13-Chr6-53195127_ALL
# 	--from-bp 53195125
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.515s
# user	0m0.951s
# sys	0m0.911s
#
# Chr6	14	6_14	53944185
#
# Subsetting VCF with bcftools
#
# real	0m0.392s
# user	0m0.056s
# sys	0m0.034s
#
# real	0m0.185s
# user	0m0.088s
# sys	0m0.029s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 14_Chr6_53944185.vcf.gz
# 	--chr Chr6
# 	--to-bp 53944187
# 	--012
# 	--out 14-Chr6-53944185_highConf
# 	--from-bp 53944183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.149s
# user	0m0.041s
# sys	0m0.113s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 14_Chr6_53944185.PL.vcf.gz
# 	--chr Chr6
# 	--to-bp 53944187
# 	--012
# 	--out 14-Chr6-53944185_ALL
# 	--from-bp 53944183
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.126s
# user	0m0.792s
# sys	0m0.904s

# %%
## Chr7
chrom=Chr7
KASPcoords=~/snap_hap/impute/stitch_tests/coords/coords_for_stitch_longVersion_corrected_200kb.txt
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
for snpID in 1
do
    markerID=${chrom/Chr}_${snpID}
    pos=$(grep -w $markerID $KASPcoords | cut -f8)
    echo -e "\n"$chrom"\t"$snpID"\t"$markerID"\t"$pos"\n"
    # Subset VCF with bcftools
    echo "Subsetting VCF with bcftools"
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.vcf.gz $vcf
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.PL.vcf.gz ${vcf/.vcf.gz/.PL.vcf.gz}    
    # Extract genotypes
    echo "Extracting stitch genotypes"
    time bash ~/snap_hap/_scripts/bash/stitch/extract_stitchGT.sh $chrom $snpID $pos ${snpID}_${chrom}_${pos}.vcf.gz
    rm ${snpID}_${chrom}_${pos}*.vcf.gz*
done
# Out:
# Chr7	1	7_1	49828363
#
# Subsetting VCF with bcftools
#
# real	0m0.169s
# user	0m0.082s
# sys	0m0.015s
#
# real	0m0.194s
# user	0m0.078s
# sys	0m0.021s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr7_49828363.vcf.gz
# 	--chr Chr7
# 	--to-bp 49828365
# 	--012
# 	--out 1-Chr7-49828363_highConf
# 	--from-bp 49828361
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.156s
# user	0m0.045s
# sys	0m0.116s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr7_49828363.PL.vcf.gz
# 	--chr Chr7
# 	--to-bp 49828365
# 	--012
# 	--out 1-Chr7-49828363_ALL
# 	--from-bp 49828361
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.350s
# user	0m0.858s
# sys	0m0.911s

# %%
## Chr8
chrom=Chr8
KASPcoords=~/snap_hap/impute/stitch_tests/coords/coords_for_stitch_longVersion_corrected_200kb.txt
vcf=~/snap_hap/variants/stitch/${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
for snpID in {1..5}
do
    markerID=${chrom/Chr}_${snpID}
    pos=$(grep -w $markerID $KASPcoords | cut -f8)
    echo -e "\n"$chrom"\t"$snpID"\t"$markerID"\t"$pos"\n"
    # Subset VCF with bcftools
    echo "Subsetting VCF with bcftools"
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.vcf.gz $vcf
    time bcftools view -r ${chrom}:$pos -Oz -o ${snpID}_${chrom}_${pos}.PL.vcf.gz ${vcf/.vcf.gz/.PL.vcf.gz}    
    # Extract genotypes
    echo "Extracting stitch genotypes"
    time bash ~/snap_hap/_scripts/bash/stitch/extract_stitchGT.sh $chrom $snpID $pos ${snpID}_${chrom}_${pos}.vcf.gz
    rm ${snpID}_${chrom}_${pos}*.vcf.gz*
done
# Out:
# Chr8	1	8_1	27807304
#
# Subsetting VCF with bcftools
#
# real	0m0.327s
# user	0m0.040s
# sys	0m0.016s
#
# real	0m0.250s
# user	0m0.031s
# sys	0m0.031s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr8_27807304.vcf.gz
# 	--chr Chr8
# 	--to-bp 27807306
# 	--012
# 	--out 1-Chr8-27807304_highConf
# 	--from-bp 27807302
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.153s
# user	0m0.032s
# sys	0m0.125s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 1_Chr8_27807304.PL.vcf.gz
# 	--chr Chr8
# 	--to-bp 27807306
# 	--012
# 	--out 1-Chr8-27807304_ALL
# 	--from-bp 27807302
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.929s
# user	0m0.916s
# sys	0m0.962s
#
# Chr8	2	8_2	31864104
#
# Subsetting VCF with bcftools
#
# real	0m0.304s
# user	0m0.061s
# sys	0m0.020s
#
# real	0m0.263s
# user	0m0.088s
# sys	0m0.024s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr8_31864104.vcf.gz
# 	--chr Chr8
# 	--to-bp 31864106
# 	--012
# 	--out 2-Chr8-31864104_highConf
# 	--from-bp 31864102
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.156s
# user	0m0.061s
# sys	0m0.101s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 2_Chr8_31864104.PL.vcf.gz
# 	--chr Chr8
# 	--to-bp 31864106
# 	--012
# 	--out 2-Chr8-31864104_ALL
# 	--from-bp 31864102
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.060s
# user	0m0.782s
# sys	0m0.932s
#
# Chr8	3	8_3	38142268
#
# Subsetting VCF with bcftools
#
# real	0m0.077s
# user	0m0.008s
# sys	0m0.028s
#
# real	0m0.054s
# user	0m0.022s
# sys	0m0.016s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr8_38142268.vcf.gz
# 	--chr Chr8
# 	--to-bp 38142270
# 	--012
# 	--out 3-Chr8-38142268_highConf
# 	--from-bp 38142266
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.160s
# user	0m0.049s
# sys	0m0.117s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 3_Chr8_38142268.PL.vcf.gz
# 	--chr Chr8
# 	--to-bp 38142270
# 	--012
# 	--out 3-Chr8-38142268_ALL
# 	--from-bp 38142266
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m3.593s
# user	0m0.956s
# sys	0m0.979s
#
# Chr8	4	8_4	44933278
#
# Subsetting VCF with bcftools
#
# real	0m0.216s
# user	0m0.070s
# sys	0m0.015s
#
# real	0m0.229s
# user	0m0.079s
# sys	0m0.028s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 4_Chr8_44933278.vcf.gz
# 	--chr Chr8
# 	--to-bp 44933280
# 	--012
# 	--out 4-Chr8-44933278_highConf
# 	--from-bp 44933276
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.161s
# user	0m0.043s
# sys	0m0.116s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 4_Chr8_44933278.PL.vcf.gz
# 	--chr Chr8
# 	--to-bp 44933280
# 	--012
# 	--out 4-Chr8-44933278_ALL
# 	--from-bp 44933276
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.783s
# user	0m0.917s
# sys	0m1.021s
#
# Chr8	5	8_5	53715058
#
# Subsetting VCF with bcftools
#
# real	0m0.350s
# user	0m0.060s
# sys	0m0.025s
#
# real	0m0.238s
# user	0m0.080s
# sys	0m0.022s
# Extracting stitch genotypes
#
# The following have been reloaded with a version change:
#   1) bcftools/1.18 => bcftools/1.16     3) perl/5.36.0 => perl/5.34.0
#   2) htslib/1.18 => htslib/1.13         4) vcftools/0.1.16 => vcftools/20210912
#
#
# Indexing highConf-stitch VCF
#
# Get 012 values from stitch-highconfidence VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 5_Chr8_53715058.vcf.gz
# 	--chr Chr8
# 	--to-bp 53715060
# 	--012
# 	--out 5-Chr8-53715058_highConf
# 	--from-bp 53715056
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 1.00 seconds
#
# Extract all genotypes from STITCH
#
# real	0m0.153s
# user	0m0.035s
# sys	0m0.122s
#
# Get 012 values from stitch-ALL VCF
#
# VCFtools - 0.1.17
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf 5_Chr8_53715058.PL.vcf.gz
# 	--chr Chr8
# 	--to-bp 53715060
# 	--012
# 	--out 5-Chr8-53715058_ALL
# 	--from-bp 53715056
#
# Using zlib version: 1.2.11
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=GP,Number=3,Type=Float,Description="Posterior genotype probability of 0/0, 0/1, and 1/1">
# Warning: Expected at least 2 parts in FORMAT entry: ID=PL,Number=G,Type=Integer,Description="Normalized, Phred-scaled likelihoods for genotypes as defined in the VCF specification">
# After filtering, kept 1074 out of 1074 Individuals
# Writing 012 matrix files ... Done.
# After filtering, kept 1 out of a possible 1 Sites
# Run Time = 0.00 seconds
#
# Change longFormat sample names to shortFormat
#
# Create stitch GT file
#
# real	0m2.369s
# user	0m0.836s
# sys	0m0.953s

# %% [markdown]
# ## Extract INFO, DEPTH and QUAL for each of these KASP markers

# %%
## INFO from mpileup output

cd ~/snap_hap/variants/vcf_bcftools_Am_all/
for chrom in Chr{1..8}
do
    bcftools view -H -R ../stitch/KASP_validation.pos ${chrom}/Am_all_bcftools_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz | cut -f1-2,4-6,8
done
# Out:
# Chr1	955185	C	A	26533.4	DP=2130;VDB=0.0403254;SGB=236.2;RPBZ=-4.67188;MQBZ=-3.6874;MQSBZ=-1.6169;BQBZ=0.448842;NMBZ=2.80605;SCBZ=-5.19645;FS=0;MQ0F=0.00892019;AC=853;AN=1246;DP4=388,266,563,415;MQ=42
# Chr1	45535107	C	A	28863.3	DP=2464;VDB=0.00249496;SGB=270.867;RPBZ=0.0313099;MQBZ=-22.493;MQSBZ=-3.56976;BQBZ=-1.41371;NMBZ=22.3821;SCBZ=-0.146563;FS=0;MQ0F=0.000811688;AC=836;AN=1336;DP4=452,406,454,615;MQ=54
# Chr1	47381180	C	A	16317.9	DP=2576;VDB=0.830319;SGB=237.663;RPBZ=2.0871;MQBZ=-12.9647;MQSBZ=-0.44103;BQBZ=0.708826;NMBZ=21.905;SCBZ=-0.106792;FS=0;MQ0F=0.00194099;AC=314;AN=1330;DP4=685,646,287,333;MQ=52
# Chr1	51252783	A	C	18432.5	DP=2946;VDB=0.858512;SGB=259.479;RPBZ=0.499348;MQBZ=-16.429;MQSBZ=1.76715;BQBZ=0.737209;NMBZ=26.3499;SCBZ=0.468853;FS=0;MQ0F=0.00305499;AC=388;AN=1364;DP4=714,708,362,332;MQ=53
# Chr1	60537705	T	C	14255.6	DP=2498;VDB=0.787776;SGB=291.111;RPBZ=0.954798;MQBZ=-9.90877;MQSBZ=3.08892;BQBZ=-2.68247;NMBZ=5.17687;SCBZ=4.84531;FS=0;MQ0F=0.0424339;AC=311;AN=1304;DP4=573,601,345,330;MQ=46
# Chr1	71126303	T	G	34834.4	DP=2830;VDB=0.99977;SGB=401.123;RPBZ=-0.701631;MQBZ=-23.7337;MQSBZ=3.1658;BQBZ=0.830345;NMBZ=15.8517;SCBZ=0.0802863;FS=0;MQ0F=0.00353357;AC=909;AN=1432;DP4=539,405,723,514;MQ=54
# Chr2	55473945	A	G	22973.6	DP=2175;VDB=0.955049;SGB=277.042;RPBZ=1.02531;MQBZ=-17.2302;MQSBZ=0.835852;BQBZ=-0.589419;NMBZ=-1.51153;SCBZ=-0.351318;FS=0;MQ0F=0.00183908;AC=445;AN=1324;DP4=450,516,377,437;MQ=57
# Chr2	58751341	A	G	8338.71	DP=1981;VDB=0.00571555;SGB=173.942;RPBZ=5.04386;MQBZ=-15.7799;MQSBZ=-3.81457;BQBZ=9.62796;NMBZ=26.5719;SCBZ=21.1719;FS=0;MQ0F=0.04947;AC=221;AN=1110;DP4=511,487,130,262;MQ=49
# Chr3	1055959	T	A	25268.3	DP=2470;VDB=0.855583;SGB=280.184;RPBZ=-0.358449;MQBZ=-1.14029;MQSBZ=0.487623;BQBZ=1.19652;NMBZ=-4.26463;SCBZ=0.0605525;FS=0;MQ0F=0.0105263;AC=813;AN=1316;DP4=470,377,588,457;MQ=41
# Chr3	3488331	C	T	29029.6	DP=2497;VDB=0.791244;SGB=245.268;RPBZ=0.156619;MQBZ=-2.48471;MQSBZ=0.600968;BQBZ=1.11659;NMBZ=-7.71364;SCBZ=-0.353553;FS=0;MQ0F=0.000800961;AC=845;AN=1350;DP4=362,528,458,600;MQ=48
# Chr3	44197469	G	C	18392.9	DP=2598;VDB=0.000425153;SGB=266.048;RPBZ=1.06044;MQBZ=9.26583;MQSBZ=-0.928831;BQBZ=-0.128311;NMBZ=-25.4601;SCBZ=-0.262521;FS=0;MQ0F=0.00153965;AC=368;AN=1368;DP4=761,502,439,251;MQ=50
# Chr4	7115521	T	G	32824.4	DP=2682;VDB=0.316996;SGB=210.915;RPBZ=2.68549;MQBZ=1.28276;MQSBZ=2.03991;BQBZ=-4.22425;NMBZ=-13.6579;SCBZ=0.042898;FS=0;MQ0F=0.00149142;AC=948;AN=1408;DP4=379,557,438,688;MQ=48
# Chr4	44460308	A	G	26240.1	DP=3136;VDB=0.999532;SGB=401.818;RPBZ=-0.202911;MQBZ=-6.49517;MQSBZ=1.30932;BQBZ=-0.111074;NMBZ=-13.1346;SCBZ=-0.360726;FS=0;MQ0F=0.00223214;AC=462;AN=1494;DP4=765,717,494,428;MQ=55
# Chr4	50972302	G	A	30206.3	DP=2642;VDB=0.591301;SGB=268.314;RPBZ=-0.616136;MQBZ=-10.9921;MQSBZ=0.0504069;BQBZ=-1.62883;NMBZ=5.20243;SCBZ=0.872342;FS=0;MQ0F=0.00794852;AC=831;AN=1364;DP4=458,466,584,489;MQ=53
# Chr6	15125731	A	T	33795.9	DP=2614;VDB=0.274234;SGB=297.331;RPBZ=0.645304;MQBZ=-23.8513;MQSBZ=2.2333;BQBZ=2.2461;NMBZ=18.8144;SCBZ=8.55267;FS=0;MQ0F=0.00229533;AC=965;AN=1440;DP4=405,368,663,577;MQ=53
# Chr6	32503688	A	G	25119.7	DP=2748;VDB=0.365316;SGB=297.939;RPBZ=1.39349;MQBZ=-8.30178;MQSBZ=3.42896;BQBZ=-0.670485;NMBZ=-0.938114;SCBZ=1.18807;FS=0;MQ0F=0.0014556;AC=457;AN=1398;DP4=645,560,516,387;MQ=54
# Chr6	52922047	G	T	22605	DP=2515;VDB=0.991365;SGB=252.517;RPBZ=0.524613;MQBZ=-6.53819;MQSBZ=1.02016;BQBZ=-0.153546;NMBZ=0.666596;SCBZ=-1.53605;FS=0;MQ0F=0.012326;AC=458;AN=1334;DP4=675,483,506,298;MQ=51
# Chr6	52966811	T	A	12147	DP=1920;VDB=1.8251e-06;SGB=221.867;RPBZ=-1.92614;MQBZ=-3.48684;MQSBZ=-1.77815;BQBZ=-2.40476;NMBZ=-1.74185;SCBZ=1.81988;FS=0;MQ0F=0.0671875;AC=313;AN=1208;DP4=611,405,282,221;MQ=49
# Chr6	52999112	C	T	14710.1	DP=2106;VDB=1;SGB=286.296;RPBZ=-1.15063;MQBZ=-19.194;MQSBZ=-1.34566;BQBZ=0.293295;NMBZ=27.9925;SCBZ=0.879052;FS=0;MQ0F=0.0014245;AC=346;AN=1200;DP4=533,481,270,324;MQ=50
# Chr6	53016551	C	G	18626.9	DP=2535;VDB=0.623731;SGB=301.739;RPBZ=-0.265078;MQBZ=-13.144;MQSBZ=0.216468;BQBZ=-1.0142;NMBZ=-3.79224;SCBZ=-0.215135;FS=0;MQ0F=0.00118343;AC=318;AN=1364;DP4=669,649,325,321;MQ=57
# Chr6	53061080	A	G	22587.6	DP=2113;VDB=0.156514;SGB=259.041;RPBZ=-2.76314;MQBZ=-15.4462;MQSBZ=0.942265;BQBZ=-0.152451;NMBZ=22.2517;SCBZ=2.91907;FS=0;MQ0F=0.00520587;AC=482;AN=1258;DP4=421,374,454,356;MQ=50
# Chr6	53083229	G	A	14730.8	DP=2455;VDB=0.887193;SGB=322.291;RPBZ=-1.76965;MQBZ=-13.4262;MQSBZ=0.483341;BQBZ=-2.16984;NMBZ=-0.753788;SCBZ=0.185285;FS=0;MQ0F=0.00244399;AC=249;AN=1352;DP4=936,469,370,204;MQ=56
# Chr6	53090212	T	C	27083.1	DP=2081;VDB=0.0654626;SGB=214.716;RPBZ=-0.475041;MQBZ=-20.2337;MQSBZ=2.50682;BQBZ=0.279777;NMBZ=10.5338;SCBZ=3.43208;FS=0;MQ0F=0.00576646;AC=870;AN=1338;DP4=400,324,612,349;MQ=55
# Chr6	53094790	C	A	14456.7	DP=2600;VDB=0.269369;SGB=350.434;RPBZ=-1.56544;MQBZ=-4.93324;MQSBZ=-1.57145;BQBZ=-0.0860416;NMBZ=-3.97467;SCBZ=-0.00329092;FS=0;MQ0F=0.00269231;AC=239;AN=1396;DP4=863,616,319,234;MQ=55
# Chr6	53104387	A	C	19319	DP=2586;VDB=0.829882;SGB=253.813;RPBZ=0.17564;MQBZ=-25.4735;MQSBZ=-0.57573;BQBZ=-2.02122;NMBZ=34.3926;SCBZ=1.23405;FS=0;MQ0F=0.00116009;AC=433;AN=1358;DP4=544,593,347,399;MQ=53
# Chr6	53195127	C	T	41505.6	DP=2618;VDB=0.989784;SGB=252.215;RPBZ=-1.26149;MQBZ=-20.2318;MQSBZ=-0.597156;BQBZ=2.41543;NMBZ=7.03615;SCBZ=-0.523486;FS=0;MQ0F=0.00229183;AC=1089;AN=1410;DP4=417,261,756,589;MQ=55
# Chr6	53944185	G	A	11483.1	DP=2610;VDB=0.237318;SGB=285.538;RPBZ=2.17298;MQBZ=-7.01265;MQSBZ=-2.1303;BQBZ=-1.02699;NMBZ=-6.65154;SCBZ=-0.156828;FS=0;MQ0F=0.00229885;AC=197;AN=1400;DP4=715,882,194,267;MQ=52
# Chr7	49828363	T	A	18419.7	DP=3023;VDB=0.947225;SGB=265.743;RPBZ=-0.914265;MQBZ=-13.2196;MQSBZ=0.467364;BQBZ=-3.10809;NMBZ=17.5788;SCBZ=5.40965;FS=0;MQ0F=0.00793913;AC=426;AN=1434;DP4=804,736,453,308;MQ=48
# Chr8	27807304	T	G	17404.8	DP=2532;VDB=0.970465;SGB=206.139;RPBZ=-0.850395;MQBZ=-7.93494;MQSBZ=1.05989;BQBZ=-0.856474;NMBZ=-1.21687;SCBZ=-0.00943756;FS=0;MQ0F=0.00276461;AC=381;AN=1390;DP4=737,611,337,292;MQ=50
# Chr8	38142268	C	G	27897.2	DP=2567;VDB=0.304821;SGB=245.05;RPBZ=0.61162;MQBZ=-20.6605;MQSBZ=-1.27325;BQBZ=-0.549615;NMBZ=1.38198;SCBZ=-0.27221;FS=0;MQ0F=0.0019478;AC=546;AN=1376;DP4=395,599,394,584;MQ=56

# %%
## INFO from stitch finalRun output

cd ~/snap_hap/variants/stitch
for chrom in Chr{1..8}
do
    bcftools view -H -R KASP_validation.pos ${chrom}/*.PL.vcf.gz | cut -f1,2,4,5,8
done
# Out:
# Chr1	955185	C	A	EAF=0.61127;INFO_SCORE=0.69969;HWE=0.000312;ERC=1044.39;EAC=578.828;PAF=0.64341
# Chr1	45535107	C	A	EAF=0.53496;INFO_SCORE=0.8312;HWE=0.625;ERC=1051.56;EAC=862.859;PAF=0.54928
# Chr1	47381180	C	A	EAF=0.29956;INFO_SCORE=0.72775;HWE=0.236;ERC=658.886;EAC=1351.61;PAF=0.32772
# Chr1	51252783	A	C	EAF=0.36975;INFO_SCORE=0.80042;HWE=0.503;ERC=809.807;EAC=1355.39;PAF=0.37401
# Chr1	60537705	T	C	EAF=0.34552;INFO_SCORE=0.5466;HWE=0.173;ERC=613.451;EAC=1163.09;PAF=0.34531
# Chr1	71126303	T	G	EAF=0.53355;INFO_SCORE=0.79213;HWE=0.854;ERC=1221.66;EAC=954.728;PAF=0.56133
# Chr2	55473945	A	G	EAF=0.4309;INFO_SCORE=0.7368;HWE=0.9;ERC=787.793;EAC=947.772;PAF=0.45391
# Chr2	58751341	A	G	EAF=0.38488;INFO_SCORE=0.61493;HWE=0.655;ERC=396.784;EAC=977.689;PAF=0.28868
# Chr3	1055959	T	A	EAF=0.53935;INFO_SCORE=0.37925;HWE=5.79e-06;ERC=1016.29;EAC=841.455;PAF=0.54706
# Chr3	3488331	C	T	EAF=0.56796;INFO_SCORE=0.61748;HWE=0.448;ERC=1122.85;EAC=928.436;PAF=0.54739
# Chr3	44197469	G	C	EAF=0.37939;INFO_SCORE=0.76898;HWE=0.692;ERC=710.888;EAC=1356.5;PAF=0.34386
# Chr4	7115521	T	G	EAF=0.6432;INFO_SCORE=0.82656;HWE=0.424;ERC=1236.62;EAC=953.787;PAF=0.56456
# Chr4	44460308	A	G	EAF=0.38262;INFO_SCORE=0.66304;HWE=0.649;ERC=969.835;EAC=1486.49;PAF=0.39483
# Chr4	50972302	G	A	EAF=0.52154;INFO_SCORE=0.59632;HWE=0.0659;ERC=1126.53;EAC=976.853;PAF=0.53558
# Chr6	15125731	A	T	EAF=0.58775;INFO_SCORE=0.89667;HWE=0.0886;ERC=1235.17;EAC=775.926;PAF=0.61418
# Chr6	32503688	A	G	EAF=0.41623;INFO_SCORE=0.87169;HWE=0.489;ERC=920.796;EAC=1259.66;PAF=0.4223
# Chr6	52922047	G	T	EAF=0.42833;INFO_SCORE=0.60069;HWE=0.901;ERC=867.785;EAC=1073.66;PAF=0.44698
# Chr6	52966811	T	A	EAF=0.32062;INFO_SCORE=0.59027;HWE=2.44e-05;ERC=491.794;EAC=917.532;PAF=0.34896
# Chr6	52999112	C	T	EAF=0.39177;INFO_SCORE=0.80443;HWE=3.42e-20;ERC=673.702;EAC=1025.7;PAF=0.39643
# Chr6	53016551	C	G	EAF=0.31391;INFO_SCORE=0.81158;HWE=1.28e-12;ERC=674.91;EAC=1382.58;PAF=0.32803
# Chr6	53061080	A	G	EAF=0.48159;INFO_SCORE=0.71482;HWE=1.81e-13;ERC=862.369;EAC=818.918;PAF=0.51292
# Chr6	53083229	G	A	EAF=0.22171;INFO_SCORE=0.61022;HWE=9.79e-07;ERC=531.921;EAC=1350.58;PAF=0.28256
# Chr6	53090212	T	C	EAF=0.55551;INFO_SCORE=0.53495;HWE=0.179;ERC=926.636;EAC=748.844;PAF=0.55306
# Chr6	53094790	C	A	EAF=0.23235;INFO_SCORE=0.79063;HWE=2.17e-05;ERC=531.993;EAC=1543.47;PAF=0.25632
# Chr6	53104387	A	C	EAF=0.39253;INFO_SCORE=0.69188;HWE=0.00945;ERC=767.775;EAC=1179.61;PAF=0.39426
# Chr6	53195127	C	T	EAF=0.68807;INFO_SCORE=0.4721;HWE=0.54;ERC=1401.47;EAC=673.861;PAF=0.6753
# Chr6	53944185	G	A	EAF=0.1986;INFO_SCORE=0.7492;HWE=0.135;ERC=460.049;EAC=1570.45;PAF=0.22657
# Chr7	49828363	T	A	EAF=0.31702;INFO_SCORE=0.59881;HWE=0.228;ERC=810.614;EAC=1523.43;PAF=0.3473
# Chr8	27807304	T	G	EAF=0.31806;INFO_SCORE=0.80568;HWE=0.307;ERC=696.932;EAC=1288.48;PAF=0.35103
# Chr8	38142268	C	G	EAF=0.51054;INFO_SCORE=0.67239;HWE=0.501;ERC=1029.6;EAC=1035.76;PAF=0.49851

# %%
## INFO from stitch validation output

cd ~/snap_hap/impute/stitch_tests
for vcf in */run3.1*/run3_*-chr?_*K75_cov20*/*.PL.vcf.gz
do
    # echo $vcf
    # bash ~/snap_hap/_scripts/bash/stitch/add_PG_PL.sh $vcf
    bcftools view -H -R ~/snap_hap/variants/stitch/KASP_validation.pos $vcf | cut -f1,2,4,5,8
done
# Out:
# Chr1	955185	C	A	EAF=0.61852;INFO_SCORE=0.71681;HWE=6.78e-05;ERC=1069.38;EAC=598.826;PAF=0.64104
# Chr1	45535107	C	A	EAF=0.5282;INFO_SCORE=0.7465;HWE=0.143;ERC=1094.52;EAC=899.864;PAF=0.5488
# Chr1	47381180	C	A	EAF=0.31531;INFO_SCORE=0.62547;HWE=0.0201;ERC=672.887;EAC=1400.6;PAF=0.32452
# Chr1	51252783	A	C	EAF=0.36165;INFO_SCORE=0.72718;HWE=0.841;ERC=824.806;EAC=1377.38;PAF=0.37454
# Chr1	60537705	T	C	EAF=0.34305;INFO_SCORE=0.58476;HWE=0.685;ERC=633.438;EAC=1188.07;PAF=0.34775
# Chr1	71126303	T	G	EAF=0.54114;INFO_SCORE=0.72912;HWE=0.157;ERC=1273.65;EAC=982.725;PAF=0.56447
# Chr2	55473945	A	G	EAF=0.42485;INFO_SCORE=0.76758;HWE=0.851;ERC=824.781;EAC=991.766;PAF=0.45404
# Chr2	58751341	A	G	EAF=0.34912;INFO_SCORE=0.52485;HWE=0.351;ERC=431.774;EAC=1014.69;PAF=0.2985
# Chr3	1055959	T	A	EAF=0.53891;INFO_SCORE=0.42271;HWE=0.0111;ERC=1037.29;EAC=871.45;PAF=0.54344
# Chr3	3488331	C	T	EAF=0.54822;INFO_SCORE=0.61503;HWE=0.118;ERC=1132.85;EAC=952.426;PAF=0.54326
# Chr3	44197469	G	C	EAF=0.37404;INFO_SCORE=0.7342;HWE=0.507;ERC=736.885;EAC=1424.48;PAF=0.34093
# Chr4	7115521	T	G	EAF=0.63899;INFO_SCORE=0.71536;HWE=0.505;ERC=1272.62;EAC=972.786;PAF=0.56677
# Chr4	44460308	A	G	EAF=0.37706;INFO_SCORE=0.66146;HWE=0.645;ERC=1009.83;EAC=1548.47;PAF=0.39473
# Chr4	50972302	G	A	EAF=0.52218;INFO_SCORE=0.6085;HWE=0.244;ERC=1131.54;EAC=976.852;PAF=0.53668
# Chr6	53061080	A	G	EAF=0.47829;INFO_SCORE=0.73748;HWE=1.07e-14;ERC=871.373;EAC=840.91;PAF=0.5089
# Chr6	53083229	G	A	EAF=0.2255;INFO_SCORE=0.63891;HWE=1.19e-10;ERC=534.927;EAC=1389.56;PAF=0.27796
# Chr6	53090212	T	C	EAF=0.56283;INFO_SCORE=0.53206;HWE=0.713;ERC=952.633;EAC=765.84;PAF=0.55435
# Chr6	53094790	C	A	EAF=0.24184;INFO_SCORE=0.7273;HWE=4.13e-07;ERC=547.994;EAC=1590.45;PAF=0.25626
# Chr6	53104387	A	C	EAF=0.39604;INFO_SCORE=0.66533;HWE=0.0122;ERC=786.774;EAC=1196.6;PAF=0.39669
# Chr6	53061080	A	G	EAF=0.46806;INFO_SCORE=0.72134;HWE=2.13e-13;ERC=873.367;EAC=838.913;PAF=0.51006
# Chr6	53083229	G	A	EAF=0.23408;INFO_SCORE=0.67904;HWE=2.98e-08;ERC=534.927;EAC=1387.56;PAF=0.27825
# Chr6	53090212	T	C	EAF=0.55192;INFO_SCORE=0.56116;HWE=0.582;ERC=950.633;EAC=764.84;PAF=0.55415
# Chr6	53094790	C	A	EAF=0.24816;INFO_SCORE=0.75962;HWE=1.44e-07;ERC=547.994;EAC=1584.45;PAF=0.25698
# Chr6	53104387	A	C	EAF=0.40307;INFO_SCORE=0.68729;HWE=0.0213;ERC=786.774;EAC=1194.6;PAF=0.39709
# Chr6	53061080	A	G	EAF=0.48087;INFO_SCORE=0.72805;HWE=2.75e-12;ERC=895.358;EAC=868.903;PAF=0.5075
# Chr6	53083229	G	A	EAF=0.22995;INFO_SCORE=0.62714;HWE=4.26e-05;ERC=554.932;EAC=1433.53;PAF=0.27908
# Chr6	53090212	T	C	EAF=0.56279;INFO_SCORE=0.56534;HWE=0.243;ERC=979.624;EAC=777.835;PAF=0.55741
# Chr6	53094790	C	A	EAF=0.23498;INFO_SCORE=0.78314;HWE=1.07e-07;ERC=557.997;EAC=1627.43;PAF=0.25533
# Chr6	53104387	A	C	EAF=0.39608;INFO_SCORE=0.65289;HWE=0.000618;ERC=802.781;EAC=1240.57;PAF=0.39287
# Chr6	53195127	C	T	EAF=0.68265;INFO_SCORE=0.53762;HWE=0.309;ERC=1503.43;EAC=705.857;PAF=0.68051
# Chr6	53944185	G	A	EAF=0.20263;INFO_SCORE=0.67289;HWE=0.0923;ERC=483.056;EAC=1689.41;PAF=0.22235
# Chr6	15125731	A	T	EAF=0.58887;INFO_SCORE=0.76969;HWE=0.571;ERC=1252.16;EAC=790.923;PAF=0.61288
# Chr6	32503688	A	G	EAF=0.41814;INFO_SCORE=0.80637;HWE=0.801;ERC=951.793;EAC=1309.64;PAF=0.42088
# Chr6	52922047	G	T	EAF=0.42854;INFO_SCORE=0.58307;HWE=0.709;ERC=901.773;EAC=1112.65;PAF=0.44766
# Chr6	52966811	T	A	EAF=0.31322;INFO_SCORE=0.57991;HWE=5.78e-06;ERC=513.786;EAC=953.526;PAF=0.35015
# Chr6	52922047	G	T	EAF=0.42374;INFO_SCORE=0.61915;HWE=0.458;ERC=899.774;EAC=1110.65;PAF=0.44755
# Chr6	52966811	T	A	EAF=0.30093;INFO_SCORE=0.57729;HWE=0.00512;ERC=513.786;EAC=953.526;PAF=0.35015
# Chr6	52922047	G	T	EAF=0.43447;INFO_SCORE=0.64695;HWE=0.0104;ERC=899.775;EAC=1115.65;PAF=0.44644
# Chr6	52966811	T	A	EAF=0.30828;INFO_SCORE=0.66708;HWE=3.33e-08;ERC=515.785;EAC=966.521;PAF=0.34796
# Chr6	52999112	C	T	EAF=0.38385;INFO_SCORE=0.83148;HWE=3.53e-20;ERC=692.704;EAC=1074.68;PAF=0.39194
# Chr6	53016551	C	G	EAF=0.32384;INFO_SCORE=0.73648;HWE=2.55e-11;ERC=714.907;EAC=1465.56;PAF=0.32787
# Chr6	52966811	T	A	EAF=0.34618;INFO_SCORE=0.67324;HWE=3.06e-10;ERC=521.787;EAC=964.503;PAF=0.35107
# Chr6	52999112	C	T	EAF=0.37899;INFO_SCORE=0.76275;HWE=3.12e-22;ERC=693.704;EAC=1073.68;PAF=0.3925
# Chr6	53016551	C	G	EAF=0.3286;INFO_SCORE=0.78592;HWE=1.39e-14;ERC=705.908;EAC=1453.56;PAF=0.32689
# Chr6	52966811	T	A	EAF=0.32869;INFO_SCORE=0.51052;HWE=0.0428;ERC=496.793;EAC=936.516;PAF=0.34661
# Chr6	52999112	C	T	EAF=0.37977;INFO_SCORE=0.85462;HWE=1e-19;ERC=676.699;EAC=1031.7;PAF=0.3961
# Chr6	53016551	C	G	EAF=0.32569;INFO_SCORE=0.75283;HWE=1.71e-14;ERC=692.903;EAC=1395.58;PAF=0.33177
# Chr6	53061080	A	G	EAF=0.50333;INFO_SCORE=0.73336;HWE=1.26e-12;ERC=885.36;EAC=855.909;PAF=0.50846
# Chr6	53016551	C	G	EAF=0.32003;INFO_SCORE=0.86596;HWE=8.76e-14;ERC=687.904;EAC=1383.58;PAF=0.33208
# Chr6	53061080	A	G	EAF=0.49063;INFO_SCORE=0.66725;HWE=1.05e-14;ERC=880.365;EAC=841.913;PAF=0.51116
# Chr6	53083229	G	A	EAF=0.21946;INFO_SCORE=0.62912;HWE=1.4e-06;ERC=535.928;EAC=1396.56;PAF=0.27733
# Chr6	53090212	T	C	EAF=0.54529;INFO_SCORE=0.55224;HWE=0.175;ERC=952.63;EAC=768.84;PAF=0.55338
# Chr6	53094790	C	A	EAF=0.23298;INFO_SCORE=0.72796;HWE=1.43e-06;ERC=547.995;EAC=1594.45;PAF=0.25578
# Chr6	53104387	A	C	EAF=0.41596;INFO_SCORE=0.66143;HWE=0.0683;ERC=801.767;EAC=1221.59;PAF=0.39626
# Chr6	53061080	A	G	EAF=0.47901;INFO_SCORE=0.70637;HWE=5.23e-16;ERC=872.367;EAC=837.913;PAF=0.51007
# Chr6	53083229	G	A	EAF=0.22607;INFO_SCORE=0.6225;HWE=4.94e-05;ERC=534.927;EAC=1388.56;PAF=0.2781
# Chr6	53090212	T	C	EAF=0.55976;INFO_SCORE=0.56115;HWE=0.806;ERC=949.633;EAC=765.84;PAF=0.55357
# Chr6	53094790	C	A	EAF=0.22933;INFO_SCORE=0.78499;HWE=7.09e-08;ERC=547.994;EAC=1588.45;PAF=0.2565
# Chr6	53104387	A	C	EAF=0.38993;INFO_SCORE=0.63795;HWE=0.00175;ERC=786.774;EAC=1196.6;PAF=0.39669
# Chr7	49828363	T	A	EAF=0.35735;INFO_SCORE=0.62015;HWE=0.0597;ERC=820.608;EAC=1560.42;PAF=0.34464
# Chr8	27807304	T	G	EAF=0.31018;INFO_SCORE=0.73593;HWE=0.167;ERC=718.936;EAC=1334.45;PAF=0.35012
# Chr8	38142268	C	G	EAF=0.52933;INFO_SCORE=0.67069;HWE=0.713;ERC=1058.58;EAC=1050.75;PAF=0.50186

# %% [markdown]
# ## Extract stitch INFO, freqs, genotypes and  positions in all 30 KASP positions + 100kb around.

# %%
## Extract stitch INFO, params, GTs final Runs
cd ~/snap_hap/variants/stitch
for chrom in Chr{1..8}
do
    vcf=${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz
    bcftools query -R ./INFO_acrossRuns/KASP_validation_100kb.pos --format "%CHROM\t%POS\t%EAF\t%INFO_SCORE\t%HWE\t%ERC\t%EAC\t%PAF[\t%GT]\n" $vcf >> ~/snap_hap/variants/stitch/INFO_acrossRuns/stitch.final.params
done

## Extract stitch INFO, params, GTs validation runs
cd ~/snap_hap/impute/stitch_tests
for vcf in ./Chr?/run3.1*/run3_*-chr?_*K75_cov20*/*.PL.vcf.gz
do
    bcftools query -R ~/snap_hap/variants/stitch/INFO_acrossRuns/KASP_validation_100kb.pos --format "%CHROM\t%POS\t%EAF\t%INFO_SCORE\t%HWE\t%ERC\t%EAC\t%PAF[\t%GT]\n" $vcf >> ~/snap_hap/variants/stitch/INFO_acrossRuns/stitch.validation.params
done

# %%
wc -l ~/snap_hap/variants/stitch/INFO_acrossRuns/stitch.final.params
wc -l ~/snap_hap/variants/stitch/INFO_acrossRuns/stitch.validation.params
# Out:
# 142836 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/INFO_acrossRuns/stitch.final.params
# 197169 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/INFO_acrossRuns/stitch.validation.params

# %% [markdown]
# ## Getting final STITCH parameters

# %%
cd ~/snap_hap/variants/stitch/

for chrom in Chr{1..8}
do    
    time bcftools query --format "%CHROM\t%POS\t%EAF\t%INFO_SCORE\t%HWE\t%ERC\t%EAC\t%PAF" ${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz > ${chrom}/Am_all_stitch_${chrom}.params
done

# %% [markdown]
# ## Extract allele frequencies and counts for stitched VCFs

# %%
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch

for chrom in Chr{1..8}
do
    sbatch -J stat${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-statVcfs.sbatch.sh ${chrom}/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.vcf.gz ${chrom}/Am_all_stitch_${chrom}
done

# %% [markdown]
# ## Remove invariant sites from final VCFs

# %%
stitchRun=stitch
baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/$stitchRun
outPrefixRun=stitchRun1

cd $baseDIR
for chrom in Chr6
do
    inVCF=$baseDIR/$chrom/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.tagged.vcf.gz
    outVCF=$baseDIR/$chrom/Am_all_${outPrefixRun}_${chrom}.final.vcf.gz
    time bcftools view -e 'AC==0 | AC==AN' -Oz -o $outVCF $inVCF
    time bcftools tabix -f $outVCF
done

# %%
## Cluster implmentation
stitchRun=stitch ## Run1
baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/$stitchRun
outPrefixRun=stitchRun1

cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/postSTITCH_run1/removeSites
# NB. array information is the chromosome no.
sbatch -J removeInvariantSites --array=1-8 ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-remove_InvariantSites.sbatch.sh $stitchRun $outPrefixRun

# %%
## No. of sites for stitch Run 1
stitchRun=stitch
baseDIR=/nfs/scistore18/bartogrp/apal/snap_hap/variants/$stitchRun

for chrom in Chr{1..8}
do
    vcf=$baseDIR/$chrom/*final.vcf.gz
    echo $chrom $vcf
    zgrep -c ^Chr $vcf
done

# %% [markdown]
# Chr1 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr1/Am_all_stitchRun1_Chr1.final.vcf.gz
# 2940701
#
# Chr2 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr2/Am_all_stitchRun1_Chr2.final.vcf.gz
# 3301920
#
# Chr3 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr3/Am_all_stitchRun1_Chr3.final.vcf.gz
# 2600018
#
# Chr4 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr4/Am_all_stitchRun1_Chr4.final.vcf.gz
# 2317799
#
# Chr5 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr5/Am_all_stitchRun1_Chr5.final.vcf.gz
# 3277515
#
# Chr6 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr6/Am_all_stitchRun1_Chr6.final.vcf.gz
# 2533823
#
# Chr7 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr7/Am_all_stitchRun1_Chr7.final.vcf.gz
# 2358818
#
# Chr8 /nfs/scistore18/bartogrp/apal/snap_hap/variants/stitch/Chr8/Am_all_stitchRun1_Chr8.final.vcf.gz
# 2765149

# %% [markdown]
# # Postprocessing stitch Run2 and Run3

# %%
## Always initiate this cell!!!
stitchRun=stitch_run2
run=run2
# stitchRun=stitch_run3 ### Run3

# %%
## Make a list of stitch highConfidence chromSegment files
for chrom in Chr{1..8}
do
    baseDIR=~/snap_hap/variants/$stitchRun/${chrom}
    echo -e $chrom'\t'$baseDIR'\t'$(realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*[^PL].vcf.gz | wc -l) files
    realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*[^PL].vcf.gz > ${baseDIR}/stitchVcfs.highConf.list
    echo -e ${baseDIR}/stitchVcfs.highConf.list'\n'
done

# %%
## Extract all GTs from stitch highConfidence output
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/postSTITCH_$run/extractGT

# Chr1 DONE
chrom=Chr1
sbatch --array=1-72 -J ${chrom}_postSTITCH-extractGT ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch.sh \
    $chrom $stitchRun ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.highConf.list

# Chr2 DONE
chrom=Chr2
sbatch --array=1-78 -J ${chrom}_postSTITCH-extractGT ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch.sh \
    $chrom $stitchRun ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.highConf.list

# Chr3
chrom=Chr3
sbatch --array=1-65 -J ${chrom}_postSTITCH-extractGT ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch.sh \
    $chrom $stitchRun ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.highConf.list


# Chr4
chrom=Chr4
sbatch --array=1-55 -J ${chrom}_postSTITCH-extractGT ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch.sh \
    $chrom $stitchRun ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.highConf.list

# Chr5
chrom=Chr5
sbatch --array=1-71 -J ${chrom}_postSTITCH-extractGT ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch.sh \
    $chrom $stitchRun ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.highConf.list


# Chr6 DONE
chrom=Chr6
sbatch --array=1-56 -J ${chrom}_postSTITCH-extractGT ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch.sh \
    $chrom $stitchRun ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.highConf.list

# Chr7
chrom=Chr7
sbatch --array=1-56 -J ${chrom}_postSTITCH-extractGT ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch.sh \
    $chrom $stitchRun ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.highConf.list


# Chr8
chrom=Chr8
sbatch --array=1-54 -J ${chrom}_postSTITCH-extractGT ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-extractGT.sbatch.sh \
    $chrom $stitchRun ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.highConf.list

# %%
## Make a list of stitch all chromSegment files
for chrom in Chr1 #done: Chr6
do
    baseDIR=~/snap_hap/variants/$stitchRun/${chrom}
    echo -e $chrom'\t'$baseDIR'\t'$(realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*.PL.vcf.gz | wc -l) files
    realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*.PL.vcf.gz > ${baseDIR}/stitchVcfs.ALL.list
    echo -e ${baseDIR}/stitchVcfs.ALL.list'\n'
done

# %%
## Add AC,AN annotations to stitch ALL vcf file
for chrom in Chr1 #done: Chr6
do
    while read inputVCF
    do
        echo $inputVCF
        time bash ~/snap_hap/_scripts/bash/fill-AC-AN_vcfgzFormat.sh $inputVCF
    done < ~/snap_hap/variants/$stitchRun/$chrom/stitchVcfs.ALL.list
done

# %%
## Make a list of tagged (AC,AN) stitch all chromSegment files
for chrom in Chr{1..8}
do
    baseDIR=~/snap_hap/variants/$stitchRun/${chrom}
    echo -e $chrom'\t'$baseDIR'\t'$(realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*.PL.tagged.vcf.gz | wc -l) files
    realpath $baseDIR/stitch_chromSegments/*/stitch.${chrom}.*.*.PL.tagged.vcf.gz > ${baseDIR}/stitchVcfs.ALL.tagged.list
    echo -e ${baseDIR}/stitchVcfs.highConf.list'\n'
done

# %%
#### NOT DONE yet

## Merge VCF files
cd /nfs/scistore18/bartogrp/apal/snap_hap/variants/jobs/postSTITCH_$run/mergeVCF

for chrom in Chr{1..8}
do 
    baseDIR=~/snap_hap/variants/$stitchRun/$chrom
    echo -e $chrom'\t'$baseDIR

    #highConf#
    stitchVcfList_highConf=${baseDIR}/stitchVcfs.highConf.list
    outVCF_highConf=$baseDIR/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.vcf.gz
    sbatch -J postSTITCH-concatVcfs-highConf_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-concatVcfs.sbatch.sh ${chrom} ${stitchVcfList_highConf} ${outVCF_highConf}

    #ALL Tagged#
    stitchVcfList_ALL=${baseDIR}/stitchVcfs.ALL.tagged.list
    outVCF_ALL=$baseDIR/Am_all_stitch_${chrom}_SnpGap5_biSNPs_filtered-DP_500-7732_QUAL20_MQ30.PL.tagged.vcf.gz
    sbatch -J postSTITCH-concatVcfs-ALL_${chrom} ~/snap_hap/_scripts/sbatch/impute/job-postSTITCH-concatVcfs.sbatch.sh ${chrom} ${stitchVcfList_ALL} ${outVCF_ALL}
done

# %%
## Remove monomorphic SNPs to make final VCF
