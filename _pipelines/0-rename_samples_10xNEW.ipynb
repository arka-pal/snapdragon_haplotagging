# %% [markdown]
# # Preprocessing samples (10xNEW_n160_2023)

# %%
#%%bash
pwd
# Out:
# /nfs/scistore18/bartogrp/apal/snap_hap/_pipelines

# %%
## Set variables
fastqDIR='/nfs/scistore18/bartogrp/apal/snap_hap/fastq/haplotag_10xNEW_2023'
sample_list=/nfs/scistore18/bartogrp/apal/snap_hap/sample_info/samples_10xNEW_n160_2023/samples_10xNEW_n160_2023.txt

#ls $fastqDIR
cat $sample_list
# Out:
# ID	barcode	location	species
# PB1000	Plate9_C33	Pla	Amajus
# PB1042	Plate9_C34	Pla	Amajus
# PB1046	Plate9_C35	Pla	Amajus
# PB1047	Plate9_C36	Pla	Amajus
# PB1048	Plate9_C37	Pla	Amajus
# PB1053	Plate9_C38	Pla	Amajus
# PB1060	Plate9_C39	Pla	Amajus
# PB1253	Plate9_C40	Pla	Amajus
# PB1469	Plate9_C41	Pla	Amajus
# PB1470	Plate9_C42	Pla	Amajus
# PB1512	Plate9_C43	Pla	Amajus
# PB1522	Plate9_C44	Pla	Amajus
# PB1561	Plate9_C45	Pla	Amajus
# PB1569	Plate9_C46	Pla	Amajus
# PB1591	Plate9_C47	Pla	Amajus
# PB1602	Plate9_C48	Pla	Amajus
# PB1606	Plate9_C49	Pla	Amajus
# PB2943	Plate9_C50	Pla	Amajus
# PB2944	Plate9_C51	Pla	Amajus
# PB2945	Plate9_C52	Pla	Amajus
# PB2946	Plate9_C53	Pla	Amajus
# PB2948	Plate9_C54	Pla	Amajus
# PB0810	Plate9_C55	Pla	Amajus
# PB0836	Plate9_C56	Pla	Amajus
# PB0854	Plate9_C57	Pla	Amajus
# PB0860	Plate9_C58	Pla	Amajus
# PB0861	Plate9_C59	Pla	Amajus
# PB0866	Plate9_C60	Pla	Amajus
# PB0868	Plate9_C61	Pla	Amajus
# PB0869	Plate9_C62	Pla	Amajus
# PB0871	Plate9_C63	Pla	Amajus
# ...

# %%
#%%bash

# ## Change file names from barcode info to plantID info
# while read PlantID barcode location species; 
# do 
#     for file in $(find $fastqDIR/*/$barcode*)
#     do 
#         new_filename=${file/$barcode/$PlantID}
#         mv $file $new_filename    
#     done
# done < $sample_list
# Out:
# find: ‘/nfs/scistore18/bartogrp/apal/snap_hap/fastq/haplotag_10xNEW_2023/*/barcode*’: No such file or directory
